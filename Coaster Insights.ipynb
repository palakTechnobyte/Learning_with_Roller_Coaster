# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import requests
from bs4 import BeautifulSoup as bs

# %%
pd.set_option("display.max_columns", 100)

# %%
df = pd.read_csv("coaster_db.csv")

# %%
df.shape
# Out:
# (1087, 56)

# %% [markdown]
# There are 1087 rows and 56 columns in the dataset

# %% [markdown]
# ## Understanding Data

# %%
df.sample(5)
# Out:
#                           coaster_name                Length  \
# 524  Flashback (Six Flags New England)        935 ft (285 m)
# 811               Fiorano GT Challenge  3,543 ft (1,079.9 m)
# 997  The Joker (Six Flags New England)      1,019 ft (311 m)
# 378               The Great Nor'easter      2,170 ft (660 m)
# 739                       Mystery Mine  1,804.5 ft (550.0 m)
#
#                     Speed       Location     Status      Opening date  \
# 524      47 mph (76 km/h)          Other        NaN               NaN
# 811    59 mph (95.0 km/h)          Other  Operating  November 4, 2010
# 997      38 mph (61 km/h)          Other        NaN               NaN
# 378      55 mph (89 km/h)  Morey's Piers  Operating      May 26, 1995
# 739  43.5 mph (70.0 km/h)      Dollywood  Operating    April 13, 2007
#
#                                      Type               Manufacturer  \
# 524                       Steel – Shuttle                     Vekoma
# 811            Steel – Launched – Dueling                  Maurer AG
# 997  Steel – 4th Dimension – Wing Coaster  S&S – Sansei Technologies
# 378                      Steel – Inverted                     Vekoma
# 739                  Steel – Euro-Fighter                 Gerstlauer
#
#         Height restriction                             Model  \
# 524         48 in (122 cm)                         Boomerang
# 811         51 in (130 cm)                               NaN
# 997         48 in (122 cm)                      4D Free Spin
# 378         52 in (132 cm)  Suspended Looping Coaster-Custom
# 739  48–76 in (122–193 cm)             Euro-Fighter (Custom)
#
#                Height  Inversions    Lift/launch system            Cost  \
# 524     117 ft (36 m)         3.0                 Chain             NaN
# 811               NaN         0.0                   NaN             NaN
# 997     120 ft (37 m)         6.0       Chain lift hill             NaN
# 378     115 ft (35 m)         5.0       Chain lift hill  $5,500,000 USD
# 739  85.3 ft (26.0 m)         2.0  Two Chain lift hills   $17.5 million
#
#                                                 Trains   Park section  \
# 524                                                NaN      North End
# 811  4 trains with 3 cars. Riders are arranged 2 ac...            NaN
# 997  5 trains with a single car. Riders are arrange...            NaN
# 378  2 trains with 10 cars. Riders are arranged 2 a...  Surfside Pier
# 739  7 trains with a single car. Riders are arrange...  Timber Canyon
#
#     Duration              Capacity G-force               Designer  \
# 524     1:48   760 riders per hour     5.2                    NaN
# 811      NaN                   NaN     1.5  Jack Rouse Associates
# 997      NaN   720 riders per hour     NaN           Alan Schilke
# 378     2:05  1200 riders per hour     NaN                    NaN
# 739     2:30  1000 riders per hour     NaN         Werner Stengel
#
#     Max vertical angle          Drop Soft opening date Fast Lane available  \
# 524                NaN           NaN               NaN                 NaN
# 811                NaN           NaN               NaN                 NaN
# 997                NaN  54 ft (16 m)               NaN                 NaN
# 378                NaN  95 ft (29 m)               NaN                 NaN
# 739                95°           NaN    March 31, 2007                 NaN
#
#     Replaced Track layout Fastrack available Soft opening date.1 Closing date  \
# 524      NaN          NaN                NaN                 NaN          NaN
# 811      NaN          NaN                NaN                 NaN          NaN
# 997      NaN          NaN                NaN                 NaN          NaN
# 378      NaN          NaN                NaN                 NaN          NaN
# 739      NaN      Terrain                NaN      March 31, 2007          NaN
#
#     Opened Replaced by Website Flash Pass Available  \
# 524    NaN         NaN     NaN                  NaN
# 811    NaN         NaN     NaN                  NaN
# 997    NaN         NaN     NaN                  NaN
# 378    NaN         NaN     NaN                  NaN
# 739    NaN         NaN     NaN                  NaN
#
#      Must transfer from wheelchair Theme  Single rider line available  \
# 524                            NaN   NaN  Single rider line available
# 811                            NaN   NaN                          NaN
# 997                            NaN   NaN  Single rider line available
# 378                            NaN   NaN                          NaN
# 739  Must transfer from wheelchair   NaN                          NaN
#
#     Restraint Style  Flash Pass available Acceleration Restraints Name  \
# 524             NaN  Flash Pass available          NaN        NaN  NaN
# 811             NaN                   NaN          NaN        NaN  NaN
# 997             NaN  Flash Pass available          NaN        NaN  NaN
# 378             NaN                   NaN          NaN        NaN  NaN
# 739             NaN                   NaN          NaN        NaN  NaN
#
#      year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 524             2000       NaN        NaN     Steel                NaN
# 811             2010   24.4864    54.6042     Steel         2010-11-04
# 997             2017       NaN        NaN     Steel                NaN
# 378             1995   38.9893   -74.8023     Steel         1995-05-26
# 739             2007   35.7956   -83.5301     Steel         2007-04-13
#
#         speed1     speed2  speed1_value speed1_unit  speed_mph  height_value  \
# 524    47 mph     76 km/h          47.0         mph       47.0         117.0
# 811    59 mph   95.0 km/h          59.0         mph       59.0           NaN
# 997    38 mph     61 km/h          38.0         mph       38.0         120.0
# 378    55 mph     89 km/h          55.0         mph       55.0         115.0
# 739  43.5 mph   70.0 km/h          43.5         mph       43.5          85.3
#
#     height_unit  height_ft  Inversions_clean  Gforce_clean
# 524          ft        NaN                 3           5.2
# 811         NaN        NaN                 0           1.5
# 997          ft        NaN                 6           NaN
# 378          ft        NaN                 5           NaN
# 739          ft        NaN                 2           NaN

# %% [markdown]
# We could see that there are number of columns where there a 80% null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
#  12  Lift/launch system             795 non-null    object
#  13  Cost                           382 non-null    object
#  14  Trains                         718 non-null    object
#  15  Park section                   487 non-null    object
#  16  Duration                       765 non-null    object
#  17  Capacity                       575 non-null    object
#  18  G-force                        362 non-null    object
#  19  Designer                       578 non-null    object
#  20  Max vertical angle             357 non-null    object
#  21  Drop                           494 non-null    object
#  22  Soft opening date              96 non-null     object
#  23  Fast Lane available            69 non-null     object
#  24  Replaced                       173 non-null    object
#  25  Track layout                   335 non-null    object
#  26  Fastrack available             19 non-null     object
#  27  Soft opening date.1            96 non-null     object
#  28  Closing date                   236 non-null    object
#  29  Opened                         27 non-null     object
#  30  Replaced by                    88 non-null     object
#  31  Website                        87 non-null     object
#  32  Flash Pass Available           50 non-null     object
#  33  Must transfer from wheelchair  106 non-null    object
#  34  Theme                          44 non-null     object
#  35  Single rider line available    81 non-null     object
#  36  Restraint Style                22 non-null     object
#  37  Flash Pass available           46 non-null     object
#  38  Acceleration                   60 non-null     object
#  39  Restraints                     24 non-null     object
#  40  Name                           35 non-null     object
#  41  year_introduced                1087 non-null   int64
#  42  latitude                       812 non-null    float64
#  43  longitude                      812 non-null    float64
#  44  Type_Main                      1087 non-null   object
#  45  opening_date_clean             837 non-null    object
#  46  speed1                         937 non-null    object
#  47  speed2                         935 non-null    object
#  48  speed1_value                   937 non-null    float64
#  49  speed1_unit                    937 non-null    object
#  50  speed_mph                      937 non-null    float64
#  51  height_value                   965 non-null    float64
#  52  height_unit                    965 non-null    object
#  53  height_ft                      171 non-null    float64
#  54  Inversions_clean               1087 non-null   int64
#  55  Gforce_clean                   362 non-null    float64
# dtypes: float64(8), int64(2), object(46)
# memory usage: 475.7+ KB

# %% [markdown]
# #### Lets get the % of not nulls for each column

# %%
valid_cols = np.round((((~df.isna()).sum() * 100 )/ len(df)).sort_values(ascending=False))
nulls_df = valid_cols.reset_index(name="not_null_percent")
nulls_df
# Out:
#                             index  not_null_percent
# 0                    coaster_name             100.0
# 1                        Location             100.0
# 2                Inversions_clean             100.0
# 3                 year_introduced             100.0
# 4                            Type             100.0
# 5                       Type_Main             100.0
# 6                    Manufacturer              95.0
# 7                          Height              89.0
# 8                     height_unit              89.0
# 9                    height_value              89.0
# 10                         Length              88.0
# 11                      speed_mph              86.0
# 12                         speed1              86.0
# 13                   speed1_value              86.0
# 14                          Speed              86.0
# 15                    speed1_unit              86.0
# 16                         speed2              86.0
# 17                     Inversions              86.0
# 18                         Status              80.0
# 19             opening_date_clean              77.0
# 20                   Opening date              77.0
# 21             Height restriction              76.0
# 22                      longitude              75.0
# 23                       latitude              75.0
# 24             Lift/launch system              73.0
# 25                       Duration              70.0
# 26                          Model              68.0
# 27                         Trains              66.0
# 28                       Designer              53.0
# 29                       Capacity              53.0
# 30                           Drop              45.0
# 31                   Park section              45.0
# 32                           Cost              35.0
# 33                   Gforce_clean              33.0
# 34                        G-force              33.0
# 35             Max vertical angle              33.0
# 36                   Track layout              31.0
# 37                   Closing date              22.0
# 38                       Replaced              16.0
# 39                      height_ft              16.0
# 40  Must transfer from wheelchair              10.0
# 41            Soft opening date.1               9.0
# 42              Soft opening date               9.0
# 43                    Replaced by               8.0
# 44                        Website               8.0
# 45    Single rider line available               7.0
# 46            Fast Lane available               6.0
# 47                   Acceleration               6.0
# 48           Flash Pass Available               5.0
# 49           Flash Pass available               4.0
# 50                          Theme               4.0
# 51                           Name               3.0
# 52                         Opened               2.0
# 53                     Restraints               2.0
# 54                Restraint Style               2.0
# 55             Fastrack available               2.0

# %% [markdown]
# ### Dropping cols that have more than 80% null values

# %%
nulls_df = nulls_df[nulls_df['not_null_percent'] < 20]
nulls_df = nulls_df.rename(columns={"index": "col_name"})
cols = list(nulls_df['col_name'])

# %% [markdown]
# ### Dropping 18 columns as they have more than 80% null values

# %%
df = df.drop(columns=cols, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Length              953 non-null    object
#  2   Speed               937 non-null    object
#  3   Location            1087 non-null   object
#  4   Status              874 non-null    object
#  5   Opening date        837 non-null    object
#  6   Type                1087 non-null   object
#  7   Manufacturer        1028 non-null   object
#  8   Height restriction  831 non-null    object
#  9   Model               744 non-null    object
#  10  Height              965 non-null    object
#  11  Inversions          932 non-null    float64
#  12  Lift/launch system  795 non-null    object
#  13  Cost                382 non-null    object
#  14  Trains              718 non-null    object
#  15  Park section        487 non-null    object
#  16  Duration            765 non-null    object
#  17  Capacity            575 non-null    object
#  18  G-force             362 non-null    object
#  19  Designer            578 non-null    object
#  20  Max vertical angle  357 non-null    object
#  21  Drop                494 non-null    object
#  22  Track layout        335 non-null    object
#  23  Closing date        236 non-null    object
#  24  year_introduced     1087 non-null   int64
#  25  latitude            812 non-null    float64
#  26  longitude           812 non-null    float64
#  27  Type_Main           1087 non-null   object
#  28  opening_date_clean  837 non-null    object
#  29  speed1              937 non-null    object
#  30  speed2              935 non-null    object
#  31  speed1_value        937 non-null    float64
#  32  speed1_unit         937 non-null    object
#  33  speed_mph           937 non-null    float64
#  34  height_value        965 non-null    float64
#  35  height_unit         965 non-null    object
#  36  Inversions_clean    1087 non-null   int64
#  37  Gforce_clean        362 non-null    float64
# dtypes: float64(7), int64(2), object(29)
# memory usage: 322.8+ KB

# %% [markdown]
# ### Fixing Column Names - convert to lowercase, replace separators by _

# %%
df.rename(columns={ col: col.lower() for col in df.columns}, inplace=True)
df.rename(columns={ col: col.replace("-", "_") for col in df.columns}, inplace=True)
df.rename(columns={ col: col.replace("/", "_") for col in df.columns}, inplace=True)
df.rename(columns={ col: col.replace(" ", "_") for col in df.columns}, inplace=True)

# %% [markdown]
# ###  Droping the following 10 columns as those are not required (speed1, speed2, speed1_value, speed1_unit, speed_mph, height_value, height_unit)

# %%
df.drop(columns=["opening_date_clean", "speed1", "speed2", "speed1_value", "speed1_unit", "speed_mph", "height_value", "height_unit", "inversions_clean","gforce_clean"], inplace=True)

# %% [markdown]
# ### Number of columns reduced from 56 to 28 after removing columns with 80% null values and not required columns

# %%
df.shape
# Out:
# (1087, 28)

# %% [markdown]
# ### Total number of fields that don't have value is 9192

# %%
df.isna().sum().sum()
# Out:
# 9192

# %% [markdown]
# ## Get the coaster details from Wikipedia

# %%
def get_coaster_details(coaster_name):
    headers = {"User-Agent": "Whoama"}
    url = f"https://en.wikipedia.org/wiki/{coaster_name}"
    r = requests.get(url, headers=headers)
    sp = bs(r.text, "html.parser")
    table = sp.select_one("table.infobox")
    data = {}
    data["coaster_name"] = coaster_name
    
    infobox_header = sp.find('th', class_='infobox-header')
    if infobox_header:
        anchor_tag = infobox_header.find('a')
        if anchor_tag:
            anchor_text = infobox_header.find('a').get_text()
            data["location"] = anchor_text
    
    if table is None:
        return data
    
    for row in table.find_all("tr"):
        header = row.find("th")
        value = row.find("td")
        if header and value:
            key = header.get_text(" ", strip=True).lower().replace(" ", "_")
            value_text = (
                value.get_text(" ", strip=True)
                .replace("\xa0", " ")
                .replace("\ufeff", "")
            )

            if " / " in value_text:
                value_text = value_text.split(" / ")[-1]

            # value_text = re.sub(r"\s*\(.*?\)\s*", "", value_text)
            res = re.search(r"\((.*?)\)", value_text)
            if res == None:
                data[key] = value_text
            else:
                data[key] = res[0].replace("(", "").replace(")", "").strip()
    return data

# %% [markdown]
# Below code is used to download the roller coaster data from Wiki to enrich our dataset
#
# Code is commented out as we have saved the data from Wiki in a file wiki_data.csv

# %%
# wiki_data = {}
# for index, row in df.iterrows():
#     coaster_name = row['coaster_name']
#     data = get_coaster_details(coaster_name)
#     wiki_data[coaster_name] = data
# 
# df_wiki = pd.DataFrame(wiki_data.values())
# 
# df_wiki.to_csv("wiki_data.csv")

# %% [markdown]
# ### Load the data from Wiki into df_wiki

# %%
df_wiki = pd.read_csv("wiki_data.csv", index_col=0)

# %% [markdown]
# ### Understanding the data loaded from Wiki

# %%
df_wiki.head()
# Out:
#                              coaster_name                          location  \
# 0                      Switchback Railway                      Coney Island
# 1                       Flip Flap Railway                     Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland , Ohio , United States
# 3            Loop the Loop (Coney Island)                      Coney Island
# 4            Loop the Loop (Young's Pier)                     Atlantic City
#
#                 park_section        coordinates   status opening_date   type  \
# 0  Coney Island Cyclone Site    40.574; -73.978  Removed   1884-06-16   Wood
# 1                        NaN    40.578; -73.979  Removed         1895   Wood
# 2                        NaN    41.580; -81.570  Defunct          NaN    NaN
# 3                        NaN   40.5745; -73.978  Removed         1901  Steel
# 4                        NaN  39.3538; -74.4342  Removed         1901  Steel
#
#              manufacturer                designer        model  \
# 0  LaMarcus Adna Thompson  LaMarcus Adna Thompson  Lift Packed
# 1            Lina Beecher            Lina Beecher          NaN
# 2                     NaN                     NaN          NaN
# 3          Edwin Prescott         Edward A. Green          NaN
# 4          Edwin Prescott         Edward A. Green          NaN
#
#              track_layout lift/launch_system height  drop length     speed  \
# 0  Gravity pulled coaster            gravity   15 m  13 m  180 m  9.7 km/h
# 1                     NaN                NaN    NaN   NaN    NaN       NaN
# 2                     NaN                NaN    NaN   NaN    NaN       NaN
# 3                     NaN                NaN    NaN   NaN    NaN       NaN
# 4                     NaN                NaN    NaN   NaN    NaN       NaN
#
#   duration max_vertical_angle              capacity g-force closing_date  \
# 0     1:00                30°  1600 riders per hour     2.9          NaN
# 1      NaN                NaN                   NaN      12         1902
# 2      NaN                NaN                   NaN     NaN          NaN
# 3      NaN                NaN                   NaN     NaN         1910
# 4      NaN                NaN                   NaN     NaN         1912
#
#   inversions                                             trains opened  \
# 0        NaN                                                NaN    NaN
# 1          1  a single car. Riders are arranged 1 across in ...    NaN
# 2        NaN                                                NaN   1895
# 3          1  a single car. Riders are arranged 2 across in ...    NaN
# 4          1                                                NaN    NaN
#
#        closed   general_manager            replaced  replaced_by Unnamed: 29  \
# 0         NaN               NaN                 NaN          NaN         NaN
# 1         NaN               NaN                 NaN          NaN         NaN
# 2  1969-09-28  Jonson McBronson                 NaN          NaN         NaN
# 3         NaN               NaN  Switchback Railway  Giant Racer     Track 1
# 4         NaN               NaN                 NaN          NaN         NaN
#
#   cost height_restriction designated website area  built architect part_of  \
# 0  NaN                NaN        NaN     NaN  NaN    NaN       NaN     NaN
# 1  NaN                NaN        NaN     NaN  NaN    NaN       NaN     NaN
# 2  NaN                NaN        NaN     NaN  NaN    NaN       NaN     NaN
# 3  NaN                NaN        NaN     NaN  NaN    NaN       NaN     NaN
# 4  NaN                NaN        NaN     NaN  NaN    NaN       NaN     NaN
#
#   designated nhldcp  reference no. architectural style nrhp reference_no.  \
# 0               NaN            NaN                 NaN                NaN
# 1               NaN            NaN                 NaN                NaN
# 2               NaN            NaN                 NaN                NaN
# 3               NaN            NaN                 NaN                NaN
# 4               NaN            NaN                 NaN                NaN
#
#   chisl_no.  sdhl_no. added_to_nrhp designated nhl designated sdhl builders  \
# 0       NaN       NaN           NaN            NaN             NaN      NaN
# 1       NaN       NaN           NaN            NaN             NaN      NaN
# 2       NaN       NaN           NaN            NaN             NaN      NaN
# 3       NaN       NaN           NaN            NaN             NaN      NaN
# 4       NaN       NaN           NaN            NaN             NaN      NaN
#
#   date  deaths  non-fatal_injuries  ... operated_by age_restriction  \
# 0  NaN     NaN                 NaN  ...         NaN             NaN
# 1  NaN     NaN                 NaN  ...         NaN             NaN
# 2  NaN     NaN                 NaN  ...         NaN             NaN
# 3  NaN     NaN                 NaN  ...         NaN             NaN
# 4  NaN     NaN                 NaN  ...         NaN             NaN
#
#   handicapped_persons  hangul  hanja revised_romanization mccune–reischauer  \
# 0                 NaN     NaN    NaN                  NaN               NaN
# 1                 NaN     NaN    NaN                  NaN               NaN
# 2                 NaN     NaN    NaN                  NaN               NaN
# 3                 NaN     NaN    NaN                  NaN               NaN
# 4                 NaN     NaN    NaN                  NaN               NaN
#
#    lift_system  public_transit  subcontractor previous_theme current_theme  \
# 0          NaN             NaN            NaN            NaN           NaN
# 1          NaN             NaN            NaN            NaN           NaN
# 2          NaN             NaN            NaN            NaN           NaN
# 3          NaN             NaN            NaN            NaN           NaN
# 4          NaN             NaN            NaN            NaN           NaN
#
#   renamed_to restraint maximum_height vehicle  tunnel_length animatronics  \
# 0        NaN       NaN            NaN     NaN            NaN          NaN
# 1        NaN       NaN            NaN     NaN            NaN          NaN
# 2        NaN       NaN            NaN     NaN            NaN          NaN
# 3        NaN       NaN            NaN     NaN            NaN          NaN
# 4        NaN       NaN            NaN     NaN            NaN          NaN
#
#   time_zone fia_grade operator  major_events  turns race_lap_record  \
# 0       NaN       NaN      NaN           NaN    NaN             NaN
# 1       NaN       NaN      NaN           NaN    NaN             NaN
# 2       NaN       NaN      NaN           NaN    NaN             NaN
# 3       NaN       NaN      NaN           NaN    NaN             NaN
# 4       NaN       NaN      NaN           NaN    NaN             NaN
#
#    queue_host ride_host trains_built_by hosts former_names host  \
# 0         NaN       NaN             NaN   NaN          NaN  NaN
# 1         NaN       NaN             NaN   NaN          NaN  NaN
# 2         NaN       NaN             NaN   NaN          NaN  NaN
# 3         NaN       NaN             NaN   NaN          NaN  NaN
# 4         NaN       NaN             NaN   NaN          NaN  NaN
#
#   original_manufacturer redesigned_by cars audio-animatronics  previous_name  \
# 0                   NaN           NaN  NaN                NaN            NaN
# 1                   NaN           NaN  NaN                NaN            NaN
# 2                   NaN           NaN  NaN                NaN            NaN
# 3                   NaN           NaN  NaN                NaN            NaN
# 4                   NaN           NaN  NaN                NaN            NaN
#
#   sponcor launches  site_area  tagline pre-ride_host official_website  \
# 0     NaN      NaN        NaN      NaN           NaN              NaN
# 1     NaN      NaN        NaN      NaN           NaN              NaN
# 2     NaN      NaN        NaN      NaN           NaN              NaN
# 3     NaN      NaN        NaN      NaN           NaN              NaN
# 4     NaN      NaN        NaN      NaN           NaN              NaN
#
#   virtual_queue physical_length total_length_traversed 1st_launch 2nd_launch  \
# 0           NaN             NaN                    NaN        NaN        NaN
# 1           NaN             NaN                    NaN        NaN        NaN
# 2           NaN             NaN                    NaN        NaN        NaN
# 3           NaN             NaN                    NaN        NaN        NaN
# 4           NaN             NaN                    NaN        NaN        NaN
#
#   pre-show_hosts lift_system_#1 lift_system_#2 ride_hosts
# 0            NaN            NaN            NaN        NaN
# 1            NaN            NaN            NaN        NaN
# 2            NaN            NaN            NaN        NaN
# 3            NaN            NaN            NaN        NaN
# 4            NaN            NaN            NaN        NaN
#
# [5 rows x 141 columns]

# %% [markdown]
# ### Returns the coaster details from wiki based on the coaster name

# %%
def get_coaster_from_wiki(coaster_name):
    coaster = df_wiki.query("coaster_name == @coaster_name")
    return coaster

# %% [markdown]
#  Check if the above function is working fine

# %%
get_coaster_from_wiki("Switchback Railway")
# Out:
#          coaster_name      location               park_section  \
# 0  Switchback Railway  Coney Island  Coney Island Cyclone Site
#
#        coordinates   status opening_date  type            manufacturer  \
# 0  40.574; -73.978  Removed   1884-06-16  Wood  LaMarcus Adna Thompson
#
#                  designer        model            track_layout  \
# 0  LaMarcus Adna Thompson  Lift Packed  Gravity pulled coaster
#
#   lift/launch_system height  drop length     speed duration  \
# 0            gravity   15 m  13 m  180 m  9.7 km/h     1:00
#
#   max_vertical_angle              capacity g-force closing_date inversions  \
# 0                30°  1600 riders per hour     2.9          NaN        NaN
#
#   trains opened closed general_manager replaced replaced_by Unnamed: 29 cost  \
# 0    NaN    NaN    NaN             NaN      NaN         NaN         NaN  NaN
#
#   height_restriction designated website area  built architect part_of  \
# 0                NaN        NaN     NaN  NaN    NaN       NaN     NaN
#
#   designated nhldcp  reference no. architectural style nrhp reference_no.  \
# 0               NaN            NaN                 NaN                NaN
#
#   chisl_no.  sdhl_no. added_to_nrhp designated nhl designated sdhl builders  \
# 0       NaN       NaN           NaN            NaN             NaN      NaN
#
#   date  deaths  non-fatal_injuries  ... operated_by age_restriction  \
# 0  NaN     NaN                 NaN  ...         NaN             NaN
#
#   handicapped_persons  hangul  hanja revised_romanization mccune–reischauer  \
# 0                 NaN     NaN    NaN                  NaN               NaN
#
#    lift_system  public_transit  subcontractor previous_theme current_theme  \
# 0          NaN             NaN            NaN            NaN           NaN
#
#   renamed_to restraint maximum_height vehicle  tunnel_length animatronics  \
# 0        NaN       NaN            NaN     NaN            NaN          NaN
#
#   time_zone fia_grade operator  major_events  turns race_lap_record  \
# 0       NaN       NaN      NaN           NaN    NaN             NaN
#
#    queue_host ride_host trains_built_by hosts former_names host  \
# 0         NaN       NaN             NaN   NaN          NaN  NaN
#
#   original_manufacturer redesigned_by cars audio-animatronics  previous_name  \
# 0                   NaN           NaN  NaN                NaN            NaN
#
#   sponcor launches  site_area  tagline pre-ride_host official_website  \
# 0     NaN      NaN        NaN      NaN           NaN              NaN
#
#   virtual_queue physical_length total_length_traversed 1st_launch 2nd_launch  \
# 0           NaN             NaN                    NaN        NaN        NaN
#
#   pre-show_hosts lift_system_#1 lift_system_#2 ride_hosts
# 0            NaN            NaN            NaN        NaN
#
# [1 rows x 141 columns]

# %% [markdown]
# ### Returns the value of a particular field from wiki by coaster_name

# %%
def get_field_from_wiki_by_coaster_name(coaster_name, field):
    coaster = df_wiki.query("coaster_name == @coaster_name")
    if field in df_wiki.columns:
        return coaster.get(field)
    return None

# %% [markdown]
# Check if the above method is working fine

# %%
print(get_field_from_wiki_by_coaster_name("Switchback Railway", "status"))
# Out:
# 0    Removed
# Name: status, dtype: object

# %%
df.status.value_counts()
# Out:
# Operating                                                         668
# Removed                                                           137
# Closed                                                             24
# Under construction                                                 15
# In Production                                                      11
# Discontinued                                                        7
# Closed in 2021                                                      2
# SBNO December 2019                                                  2
# Chapter 7 bankruptcy; rides dismantled and sold; property sold      2
# Not Currently Operating                                             1
# closed for maintenance as of july 30 no reopening date known        1
# Temporarily Closed                                                  1
# SBNO (Standing But Not Operating)                                   1
# Temporarily closed                                                  1
# Under Maintenance                                                   1
# Name: status, dtype: int64

# %% [markdown]
# ### Retain only operating roller coasters for our analysis - 668 records

# %%
df = df.query("status == 'Operating'")
df.shape
# Out:
# (668, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 668 entries, 6 to 1071
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        668 non-null    object
#  1   length              616 non-null    object
#  2   speed               608 non-null    object
#  3   location            668 non-null    object
#  4   status              668 non-null    object
#  5   opening_date        657 non-null    object
#  6   type                668 non-null    object
#  7   manufacturer        644 non-null    object
#  8   height_restriction  571 non-null    object
#  9   model               463 non-null    object
#  10  height              616 non-null    object
#  11  inversions          603 non-null    float64
#  12  lift_launch_system  520 non-null    object
#  13  cost                280 non-null    object
#  14  trains              484 non-null    object
#  15  park_section        365 non-null    object
#  16  duration            504 non-null    object
#  17  capacity            386 non-null    object
#  18  g_force             237 non-null    object
#  19  designer            338 non-null    object
#  20  max_vertical_angle  245 non-null    object
#  21  drop                324 non-null    object
#  22  track_layout        226 non-null    object
#  23  closing_date        9 non-null      object
#  24  year_introduced     668 non-null    int64
#  25  latitude            619 non-null    float64
#  26  longitude           619 non-null    float64
#  27  type_main           668 non-null    object
# dtypes: float64(3), int64(1), object(24)
# memory usage: 151.3+ KB

# %% [markdown]
# Since we have only Operating roller coaster, the closing date should be na
#
# However we could see that there are around 9 rows that have a value in closing date

# %%
(~df['closing_date'].isna()).sum()
# Out:
# 9

# %% [markdown]
# Checked the cases where the closing_date was present and it was because the roller coaster was closed and then reopened
#
# Hence dropping the column as it is of no use to us

# %%
df.drop(columns='closing_date', axis=1, inplace=True)

# %%
df.shape
# Out:
# (668, 27)

# %%
df.head()
# Out:
#                    coaster_name              length             speed  \
# 6                 Leap-The-Dips    1,452 ft (443 m)  10 mph (16 km/h)
# 13  Racer (1910 roller coaster)  4,500 ft (1,400 m)  40 mph (64 km/h)
# 15     The Great Scenic Railway    967 m (3,173 ft)  60 km/h (37 mph)
# 22      Jack Rabbit (Kennywood)    2,132 ft (650 m)  45 mph (72 km/h)
# 23      Jack Rabbit (Seabreeze)    2,130 ft (650 m)  42 mph (68 km/h)
#
#                     location     status   opening_date                  type  \
# 6              Lakemont Park  Operating           1902  Wood – Side friction
# 13                 Kennywood  Operating           1927         Wood – Racing
# 15       Luna Park Melbourne  Operating  December 1912                  Wood
# 22                 Kennywood  Operating           1920                  Wood
# 23  Seabreeze Amusement Park  Operating           1920                  Wood
#
#                     manufacturer  height_restriction   model  \
# 6   Federal Construction Company                 NaN     NaN
# 13                  Charlie Mach      46 in (117 cm)  Racing
# 15             LaMarcus Thompson  100 cm (3 ft 3 in)     NaN
# 22                Harry C. Baker      42 in (107 cm)     NaN
# 23                Harry C. Baker      48 in (122 cm)     NaN
#
#               height  inversions lift_launch_system         cost  \
# 6       41 ft (12 m)         NaN                NaN          NaN
# 13  72.5 ft (22.1 m)         0.0         Chain lift      $75,000
# 15      16 m (52 ft)         0.0    Cable lift hill          NaN
# 22      40 ft (12 m)         0.0    Chain lift hill  $50,000 USD
# 23      75 ft (23 m)         NaN              chain          NaN
#
#                                                trains park_section duration  \
# 6                                                 NaN          NaN     1:00
# 13  4 trains with 4 cars. Riders are arranged 2 ac...          NaN     1:32
# 15  3 trains with 2 cars. Riders are arranged 2 ac...          NaN      NaN
# 22  3 trains with 3 cars. Riders are arranged 2 ac...          NaN     1:36
# 23                                                NaN          NaN      NaN
#
#                 capacity g_force           designer max_vertical_angle  \
# 6                    NaN     NaN  Edward Joy Morris                25°
# 13  1400 riders per hour     NaN     John A. Miller                NaN
# 15                   NaN     NaN                NaN                NaN
# 22                   NaN     NaN     John A. Miller                45°
# 23                   NaN     NaN     John A. Miller                52°
#
#             drop                          track_layout  year_introduced  \
# 6   9 ft (2.7 m)                                   NaN             1902
# 13  50 ft (15 m)                           Möbius Loop             1910
# 15           NaN                                   NaN             1912
# 22  70 ft (21 m)  Terrain, Out and Back roller coaster             1920
# 23           NaN                 Terrain, Out and Back             1920
#
#     latitude  longitude type_main
# 6        NaN        NaN      Wood
# 13   40.3869   -79.8619      Wood
# 15       NaN        NaN      Wood
# 22   40.3867   -79.8628      Wood
# 23   43.2316   -77.5432      Wood

# %% [markdown]
#  Check for incorrect rows / summary rows etc
#  No such rows were found

# %%
# Check for duplicated rows
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [coaster_name, length, speed, location, status, opening_date, type, manufacturer, height_restriction, model, height, inversions, lift_launch_system, cost, trains, park_section, duration, capacity, g_force, designer, max_vertical_angle, drop, track_layout, year_introduced, latitude, longitude, type_main]
# Index: []

# %%
# Check if there are duplicate records for coaster_name
coaster = df['coaster_name'].value_counts().reset_index(name="count")

# %%
coaster[coaster['count']>1]
# Out:
#                                  index  count
# 0                  Journey to Atlantis      3
# 1                   Lil' Devil Coaster      2
# 2                      The Barnstormer      2
# 3             Untamed (Walibi Holland)      2
# 4                      Twisted Cyclone      2
# 5             Wipeout (roller coaster)      2
# 6              Kraken (roller coaster)      2
# 7                            Hades 360      2
# 8                       Incredicoaster      2
# 9                     Scorpion Express      2
# 10          The Walking Dead: The Ride      2
# 11  Little Dipper (Conneaut Lake Park)      2
# 12           Rougarou (roller coaster)      2
# 13       Storm Chaser (roller coaster)      2
# 14               Wild Mouse (Idlewild)      2
# 15                   Superman The Ride      2
# 16          Afterburn (roller coaster)      2
# 17            Hakugei (roller coaster)      2
# 18        Flying Fish (roller coaster)      2
# 19  Ultra Twister (Nagashima Spa Land)      2
# 20   Thunder Run (Canada's Wonderland)      2

# %% [markdown]
#  - There are 3 occurences of the coaster name - Journey to Atlantis
#
#  - Looking at the data we could see that the year_introduced is the only one that changes
#
#  - We can keep just the first row as that would be having the correct value of year_introduced
#
#  - Removing the other rows as they are duplicates

# %%
df[df['coaster_name'] == "Journey to Atlantis"]
# Out:
#             coaster_name length speed          location     status  \
# 444  Journey to Atlantis    NaN   NaN  SeaWorld Orlando  Operating
# 653  Journey to Atlantis    NaN   NaN  SeaWorld Orlando  Operating
# 732  Journey to Atlantis    NaN   NaN  SeaWorld Orlando  Operating
#
#        opening_date   type manufacturer height_restriction          model  \
# 444  April 17, 1998  Steel   Mack Rides     42 in (107 cm)  Water Coaster
# 653  April 17, 1998  Steel   Mack Rides     42 in (107 cm)  Water Coaster
# 732  April 17, 1998  Steel   Mack Rides     42 in (107 cm)  Water Coaster
#
#     height  inversions lift_launch_system cost trains    park_section  \
# 444    NaN         0.0    Chain lift hill  NaN    NaN  Sea of Legends
# 653    NaN         0.0    Chain lift hill  NaN    NaN  Sea of Legends
# 732    NaN         0.0    Chain lift hill  NaN    NaN  Sea of Legends
#
#     duration capacity g_force designer max_vertical_angle          drop  \
# 444     5:56      NaN     NaN      NaN                NaN  60 ft (18 m)
# 653     5:56      NaN     NaN      NaN                NaN  60 ft (18 m)
# 732     5:56      NaN     NaN      NaN                NaN  60 ft (18 m)
#
#       track_layout  year_introduced  latitude  longitude type_main
# 444  Water Coaster             1998       NaN        NaN     Steel
# 653  Water Coaster             2004       NaN        NaN     Steel
# 732  Water Coaster             2007       NaN        NaN     Steel

# %% [markdown]
# Deleting duplicated rows

# %%
df_deduped = df[~df.drop(columns=['year_introduced']).duplicated(keep="first")].sort_values(by="coaster_name")

# %% [markdown]
# Total of 22 records that were duplicate have been deleted

# %%
print(df.shape)
print(df_deduped.shape)
# Out:
# (668, 27)
# (646, 27)

# %% [markdown]
# Cross check and ensure there are no duplicate coaster_name

# %%
coaster = df_deduped['coaster_name'].value_counts().reset_index(name="count")
coaster[coaster['count']>1]
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
df_deduped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 646 entries, 696 to 434
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        646 non-null    object
#  1   length              598 non-null    object
#  2   speed               591 non-null    object
#  3   location            646 non-null    object
#  4   status              646 non-null    object
#  5   opening_date        635 non-null    object
#  6   type                646 non-null    object
#  7   manufacturer        622 non-null    object
#  8   height_restriction  552 non-null    object
#  9   model               444 non-null    object
#  10  height              598 non-null    object
#  11  inversions          582 non-null    float64
#  12  lift_launch_system  501 non-null    object
#  13  cost                271 non-null    object
#  14  trains              467 non-null    object
#  15  park_section        352 non-null    object
#  16  duration            488 non-null    object
#  17  capacity            376 non-null    object
#  18  g_force             230 non-null    object
#  19  designer            327 non-null    object
#  20  max_vertical_angle  237 non-null    object
#  21  drop                313 non-null    object
#  22  track_layout        217 non-null    object
#  23  year_introduced     646 non-null    int64
#  24  latitude            599 non-null    float64
#  25  longitude           599 non-null    float64
#  26  type_main           646 non-null    object
# dtypes: float64(3), int64(1), object(23)
# memory usage: 141.3+ KB

# %%
df_deduped.head()
# Out:
#                       coaster_name                  length  \
# 696    10 Inversion Roller Coaster    2,788.8 ft (850.0 m)
# 886         Abyss (roller coaster)        630 m (2,070 ft)
# 1057                       Abyssus  4,317.6 ft (1,316.0 m)
# 828   Accelerator (roller coaster)          180 m (590 ft)
# 936       Acrobat (roller coaster)  3,349.8 ft (1,021.0 m)
#
#                      speed            location     status     opening_date  \
# 696       45 mph (72 km/h)  Chimelong Paradise  Operating             2006
# 886       85 km/h (53 mph)     Adventure World  Operating  1 November 2013
# 1057  62.1 mph (99.9 km/h)        Energylandia  Operating    July 14, 2021
# 828       60 km/h (37 mph)       Drayton Manor  Operating    21 April 2011
# 936   55.9 mph (90.0 km/h)  Nagashima Spa Land  Operating    July 18, 2015
#
#                             type          manufacturer  \
# 696                        Steel               Intamin
# 886         Steel – Euro-Fighter            Gerstlauer
# 1057            Steel – Launched                Vekoma
# 828   Steel – Junior – Boomerang                Vekoma
# 936               Steel – Flying  Bolliger & Mabillard
#
#                     height_restriction                       model  \
# 696              54–77 in (137–196 cm)  Looping Coaster (Colossus)
# 886                 125 cm (4 ft 1 in)       Euro-Fighter – Custom
# 1057               120 cm (3 ft 11 in)            Shockwave 1320m+
# 828                 100 cm (3 ft 3 in)            Family Boomerang
# 936   135–198 cm (4 ft 5 in–6 ft 6 in)      Flying Coaster (Manta)
#
#                  height  inversions       lift_launch_system          cost  \
# 696    98.4 ft (30.0 m)        10.0                      NaN           NaN
# 886        30 m (98 ft)         3.0          Chain lift hill  A$12 million
# 1057  126.3 ft (38.5 m)         4.0                      LSM   €11,000,000
# 828        20 m (66 ft)         0.0  Booster Wheel Lift Hill    £2,100,000
# 936   141.1 ft (43.0 m)         4.0          Chain lift hill           NaN
#
#                                                  trains park_section  \
# 696   Single train with 7 cars. Riders are arranged ...          NaN
# 886   4 trains with a single car. Riders are arrange...          NaN
# 1057  3 trains with 4 cars. Riders are arranged 2 ac...   Aqualantis
# 828                                                 NaN  Aerial Park
# 936                                                 NaN          NaN
#
#        duration               capacity g_force              designer  \
# 696        1:32  1,300 riders per hour     NaN        Werner Stengel
# 886   2 minutes                    NaN     4.5                   NaN
# 1057        NaN   1000 riders per hour     4.5  Benjamin Bloemendaal
# 828         NaN    750 riders per hour       3        Meticulous ltd
# 936        3:00                    NaN     NaN                   NaN
#
#      max_vertical_angle             drop track_layout  year_introduced  \
# 696                 NaN              NaN          NaN             2006
# 886                100°  30.5 m (100 ft)       Custom             2013
# 1057                NaN              NaN          NaN             2021
# 828                 NaN              NaN          NaN             2011
# 936                 NaN              NaN          NaN             2015
#
#       latitude  longitude type_main
# 696    23.0044   113.3269     Steel
# 886   -32.0955   115.8170     Steel
# 1057   49.9992    19.4011     Steel
# 828    52.6108    -1.7134     Steel
# 936        NaN        NaN     Steel

# %% [markdown]
# - Remove ft from the column
#
# - Remove the meter part as well
#
# - Change the column type to float64

# %%
df_deduped['length(m)'] = df_deduped['length'].str.extract(r'([\d,\.]+)\s*m').replace(',', '', regex=True).astype(float)

# %%
df_deduped[["length", "length(m)"]]
# Out:
#                       length  length(m)
# 696     2,788.8 ft (850.0 m)      850.0
# 886         630 m (2,070 ft)      630.0
# 1057  4,317.6 ft (1,316.0 m)     1316.0
# 828           180 m (590 ft)      180.0
# 936   3,349.8 ft (1,021.0 m)     1021.0
# ...                      ...        ...
# 364                      NaN        NaN
# 1046      1,316 m (4,318 ft)     1316.0
# 433         2,900 ft (880 m)      880.0
# 56                       NaN        NaN
# 434           935 ft (285 m)      285.0
#
# [646 rows x 2 columns]

# %%
df_deduped['length(m)'].unique()
# Out:
# array([ 850.  ,  630.  , 1316.  ,  180.  , 1021.  ,  320.  ,  903.  ,
#         901.  ,     nan,  264.  , 1167.  ,  719.  , 1417.3 ,  827.  ,
#        1200.  ,  820.  ,  877.  , 1488.  ,  400.  , 1020.  ,  550.  ,
#         670.  ,  354.  ,  207.  , 1070.  , 1099.  , 1560.  , 1257.  ,
#         501.  ,  342.  ,  870.  ,  689.  , 1620.9 , 1456.  , 1000.  ,
#        1215.  ,  768.  , 1056.  ,  780.  ,  765.  ,  986.  ,  285.  ,
#         594.  , 1440.  , 1851.  , 1413.  ,  834.  ,  693.  ,  530.  ,
#         739.  ,  640.  ,  731.  ,  360.  ,  770.  , 1350.  ,  408.  ,
#        1280.  , 1344.  , 1520.  ,  662.  ,  800.  ,  992.  ,  620.  ,
#         590.  ,  135.  , 1174.  ,  390.  ,  853.  , 1010.  ,  580.  ,
#        1400.  ,  709.  , 1193.  ,  490.  ,  420.  ,  520.  ,  525.  ,
#        1610.  ,  794.  , 1050.  ,  972.  ,  380.  ,  270.  , 1036.  ,
#          80.  ,  658.5 , 1285.  , 1700.  ,  230.  ,  453.  ,  361.  ,
#         600.  ,  564.  , 1153.01,  725.1 ,  263.  ,  350.  ,  700.  ,
#         980.  ,  395.  ,  900.  ,  736.  , 1184.  , 1220.  , 1236.  ,
#         410.  ,  413.  ,  405.  , 1079.9 ,  740.  ,  690.  ,  689.01,
#         717.  ,  772.  , 1500.  ,  234.  , 2000.  ,  560.  , 2045.  ,
#         850.01, 2012.  ,  813.  ,  840.  ,  455.  , 1269.  , 1199.4 ,
#         910.  ,  370.  , 1382.  ,  413.3 ,  790.  ,  974.  ,  748.  ,
#        1231.  ,  940.  , 1370.  , 1214.  ,  950.  ,   85.  ,  488.  ,
#         947.  ,  960.  , 1447.  , 1540.  , 1530.  , 1381.  ,  793.  ,
#         909.  ,  881.  ,   60.2 ,  128.  ,  975.  , 1450.  , 1140.  ,
#         602.  ,  816.  , 1620.  , 1554.  ,  646.  ,  995.  ,  650.  ,
#         583.2 ,  810.  ,  891.  ,  785.  ,  860.  , 1600.  ,  755.  ,
#         393.  ,  862.  ,  141.77,  476.  , 1273.  ,  671.4 , 1212.  ,
#         430.  , 1218.  ,  823.  ,  443.  ,  908.  , 1672.  , 1034.2 ,
#         760.  ,  300.  , 1548.  ,  990.  ,  365.  ,  592.  ,  680.  ,
#         386.  ,  383.  , 1556.  , 1030.  , 1024.  ,  864.  ,  620.9 ,
#        1360.  ,  605.  , 1166.8 , 2010.  ,  240.  ,  716.  ,  750.  ,
#        1300.  ,  385.  ,  699.  , 1644.  ,  500.  ,  373.  ,  566.  ,
#         143.  , 1250.  , 1622.  ,  895.  , 1278.  ,  939.  ,  293.  ,
#         824.  ,  937.  ,  217.  ,  426.  , 1234.  ,  928.  , 1026.7 ,
#        1541.  ,  210.  , 1100.  , 1160.  ,  880.  ,  949.  ,  194.  ,
#         181.  ,  730.  ,  982.4 ,  762.  ,  259.  ,  281.  ,  419.74,
#         720.  ,  422.  ,  554.  , 1180.  , 1564.  , 1641.  ,  952.  ,
#         855.  ,  797.  ,  585.  , 1054.  ,  974.1 , 1051.6 ,  424.  ,
#         470.  ,  418.  ,  953.1 ,  477.  , 2479.  , 1750.  ,  190.  ,
#         836.  ,  376.4 , 1227.  ,   70.  , 1104.  , 1320.  , 1098.  ,
#         817.  , 2243.  , 1675.  , 1412.  , 1279.  , 1092.  , 1124.  ,
#         688.8 ,  660.  ,  967.  ,  781.  , 1232.  , 1235.  , 1040.9 ,
#        1330.  ,  920.  , 1170.  ,  775.  ,  278.  , 1964.  , 1066.  ,
#         330.  ,  921.  ,  925.  ,  681.  ,  843.  ,  538.  ,  390.99,
#        1619.  , 1233.  ,  963.  , 1077.2 ,  336.  ,  382.  , 1410.  ,
#        1041.  ,  428.  ,  719.5 ,  619.  ,  625.  ,  795.  ,  953.  ,
#        1660.  ,  970.  ,  837.  , 1265.  ,  304.8 ,  311.  , 1468.  ,
#        1164.  ,  335.  ,  110.  ,  150.  ,  671.  ,  996.  ,  609.6 ,
#        1105.  ])

# %%
df_deduped['length(m)'] = df_deduped['length(m)'].astype(float)

# %% [markdown]
# - Remove mph from the column
#
# - Remove the km/h part as well
#
# - Change the column type to float64

# %%
df_deduped["speed(km/h)"] = df_deduped['speed'].str.extract(r'([\d,\.]+)\s*km/h').replace(',', '', regex=True).astype(float)

# %%
df_deduped[["speed", "speed(km/h)"]].head(5)
# Out:
#                      speed  speed(km/h)
# 696       45 mph (72 km/h)         72.0
# 886       85 km/h (53 mph)         85.0
# 1057  62.1 mph (99.9 km/h)         99.9
# 828       60 km/h (37 mph)         60.0
# 936   55.9 mph (90.0 km/h)         90.0

# %%
df_deduped['speed(km/h)'].unique()
# Out:
# array([ 72.  ,  85.  ,  99.9 ,  60.  ,  90.  ,  56.  , 100.  ,    nan,
#         45.  , 108.  ,  83.  , 106.2 ,  77.  ,  80.  ,  80.6 , 117.  ,
#         31.  ,  75.  ,  88.  ,  34.9 , 109.9 , 109.  ,  89.  ,  82.1 ,
#        124.  ,  64.  ,  98.  ,  82.  ,  50.  ,  76.  ,  97.  , 122.  ,
#        110.  ,  55.  ,  66.  ,  16.  ,  48.  ,  36.  ,  68.  ,  70.  ,
#         50.1 ,  92.  ,  40.  ,  46.5 ,  60.7 ,  93.  , 115.1 ,  47.  ,
#         84.  ,  40.1 ,  69.  ,  68.4 , 130.  ,  78.1 , 126.  , 110.1 ,
#        104.6 ,  73.4 ,  45.9 ,  41.8 ,  87.7 , 120.1 ,  46.8 ,  58.  ,
#         48.9 ,  95.  ,  43.  ,  55.5 ,  79.99,  42.  , 120.  ,  27.  ,
#         39.  , 240.  ,  79.2 , 135.  , 106.6 , 153.  ,  96.6 ,  87.  ,
#         86.4 , 116.  , 137.  , 113.  , 106.  ,  18.  , 114.  ,  42.6 ,
#        107.  , 105.  ,  26.1 ,  30.  , 142.  ,  85.9 , 121.  , 145.  ,
#        101.  ,  48.4 , 104.4 ,  91.  , 206.  , 103.  ,  79.  ,  88.4 ,
#         96.1 , 148.  ,  32.  ,  53.  ,  43.5 ,  89.9 , 150.  ,  61.  ,
#         81.  , 104.9 , 100.1 , 146.  ,  29.9 ,  37.  ,  65.  ,  82.4 ,
#         52.  ,  90.1 ,  62.  , 180.  ,  82.6 ,  98.3 ,  46.  ,  76.9 ,
#         52.9 ,  44.6 , 134.  , 127.  ,  48.3 ,  71.  ,  74.  , 129.  ,
#        152.9 , 119.  , 160.9 , 103.9 , 106.1 ,  40.2 , 104.25, 106.7 ,
#         26.  ,  85.3 ,  41.4 ,  35.  ,  86.9 ,  72.4 ,  71.3 ,  70.2 ,
#          9.7 ,  24.  , 115.  ,  59.9 ,  98.5 ,  21.  , 132.  ,  56.3 ])

# %%
df_deduped.location.value_counts()
# Out:
# Other                         20
# Six Flags Magic Mountain      15
# Cedar Point                   14
# Kings Island                  14
# Carowinds                     13
#                               ..
# Ocean Park Hong Kong           1
# Attractiepark Slagharen        1
# Santa Cruz Beach Boardwalk     1
# Galaxyland                     1
# ZDT's Amusement Park           1
# Name: location, Length: 222, dtype: int64

# %% [markdown]
# There are 20 rows where the location is Other

# %%
len(df_deduped.query("location == 'Other'"))
# Out:
# 20

# %%
def get_location_by_coaster_name(row):
    if row['location'] == None or row['location'] == "Other":
        row['location'] = get_field_from_wiki_by_coaster_name("location", row['coaster_name'])
    return row

# %% [markdown]
# ### Update the location that is having the value of Other by fetching it using the coaster name from Wiki

# %%
df_deduped.loc[df_deduped['location'] == 'Other', 'location'] = df_deduped.query("location == 'Other'").apply(lambda x: get_location_by_coaster_name(x), axis=1)

# %% [markdown]
# As expected, there are no locations with Other after replacement

# %%
df_deduped.query("location == 'Other'")
# Out:
# Empty DataFrame
# Columns: [coaster_name, length, speed, location, status, opening_date, type, manufacturer, height_restriction, model, height, inversions, lift_launch_system, cost, trains, park_section, duration, capacity, g_force, designer, max_vertical_angle, drop, track_layout, year_introduced, latitude, longitude, type_main, length(m), speed(km/h)]
# Index: []

# %% [markdown]
#  There is still one coaster for which the location is None

# %%
df_deduped.location.isna().sum()
# Out:
# 20

# %%
df_deduped.location.unique()
# Out:
# array(['Chimelong Paradise', 'Adventure World', 'Energylandia',
#        'Drayton Manor', 'Nagashima Spa Land', 'Oaks Amusement Park',
#        'Kings Island', 'Carowinds', 'Tampa, Florida, U.S.', 'Europa-Park',
#        'Busch Gardens Williamsburg', 'Nigloland', None,
#        'Six Flags St. Louis', 'Walygator Parc', 'Kings Dominion',
#        'Six Flags Magic Mountain', 'Magic Springs and Crystal Falls',
#        'Lotte World', 'Xetulul Theme Park', 'Blackpool Pleasure Beach',
#        'Nickelodeon Universe', 'Movie Park Germany', 'Liseberg',
#        'Yomiuriland', 'Efteling', 'Lagoon Amusement Park',
#        'Parque Warner Madrid', 'Six Flags New England',
#        'Six Flags Mexico', 'Six Flags America', "Canada's Wonderland",
#        'New York-New York Hotel and Casino', 'Camden Park',
#        'Six Flags Great Adventure', 'Knoebels Amusement Resort',
#        'Phantasialand', 'Cedar Point', 'Gardaland', 'Kemah Boardwalk',
#        'Lagoon', 'Worlds of Fun', 'Toverland', 'Lake Compounce',
#        'Disney California Adventure', 'Hersheypark', 'Lake Winnepesaukah',
#        'Pleasurewood Hills', 'Universal Studios Singapore',
#        'Adventuredome', 'Busch Gardens Tampa Bay', "Knott's Berry Farm",
#        'PowerPark', 'Tivoli Friheden', 'Heide Park', 'Thorpe Park',
#        'Waldameer Park', 'Walibi Holland', 'Luna Park, Coney Island',
#        'Muskegon, Michigan, United States', 'Valleyfair', 'Indiana Beach',
#        'Happy Valley Tianjin', 'Walt Disney Studios Park',
#        'Happy Valley Beijing', 'Lakeside Amusement Park',
#        'Mt. Olympus Water & Theme Park', 'Warner Bros. Movie World',
#        'Six Flags Over Georgia', 'Adlabs Imagica', "Castles N' Coasters",
#        'Himeji Central Park', 'China Dinosaurs Park',
#        'Happy Valley Shanghai', 'Janfusun Fancyworld', "Morey's Piers",
#        'Playland', 'PortAventura Park', 'Marineland of Canada',
#        'Adventureland (Iowa)', 'Chessington World of Adventures',
#        'Dollywood', 'Duinrell', 'Bobbejaanland', 'Tivoli Gardens',
#        'Fuji-Q Highland', 'Freizeitpark Plohn', 'SeaWorld San Diego',
#        'Dreamworld', 'Hansa-Park', 'Zoosafari Fasanolandia',
#        'Funtown Splashtown USA', "Disney's Animal Kingdom",
#        'Holiday Park, Germany', 'Kennywood', 'Silver Dollar City',
#        "California's Great America", 'Heide Park Resort',
#        'Ferrari World Abu Dhabi', 'Drievliet Family Park',
#        'Fun Spot America', 'Alton Towers', 'Galaxyland',
#        'Santa Cruz Beach Boardwalk', 'Attractiepark Slagharen',
#        'La Ronde', 'Six Flags Great America', 'Parc Astérix',
#        "Universal's Islands of Adventure", 'Ocean Park Hong Kong',
#        'Universal Studios Florida', 'Clementon Amusement Park',
#        'Universal Studios Japan', 'Six Flags Darien Lake', 'BonBon-Land',
#        'Belantis',
#        'Orlando, FloridaKissimmee, FloridaFayetteville, GeorgiaUnited States',
#        'Dorney Park & Wildwater Kingdom', 'Casino Pier', 'Mirabilandia',
#        'Disneyland Park (Paris)', 'Gröna Lund', 'Six Flags Fiesta Texas',
#        'Galveston Island Historic Pleasure Pier',
#        'Seabreeze Amusement Park', 'Sea World (Australia)',
#        'SeaWorld Orlando', 'Fantasy Island (UK amusement park)',
#        'Six Flags Over Texas', 'Kijima Kogen', 'Erlebnispark Tripsdrill',
#        'Tobu Zoo', 'Kentucky Kingdom', 'Beech Bend Park',
#        'Dutch Wonderland', 'Linnanmäki', 'Walibi Belgium',
#        'Flamingo Land', 'Lakemont Park', 'Legendia', 'Conneaut Lake Park',
#        'Memphis Kiddie Park', 'Clacton Pier', "Michigan's Adventure",
#        'Six Flags Discovery Kingdom', 'Six Flags México',
#        'Oakwood Theme Park', 'Fantasy Island',
#        'Fun Spot America (Kissimmee)', 'Arlington, Texas, U.S.',
#        'Monte Igueldo Amusement Park', 'Hopi Hari',
#        'Flamingo Land Resort', 'Tibidabo Amusement Park',
#        'Walibi Rhône-Alpes', "Cliff's Amusement Park", 'Imagicaa',
#        'Futuroscope', 'Oktoberfest', 'Fårup Sommarland',
#        'Tokyo Dome City Attractions', 'Chime-Long Ocean Kingdom',
#        'Gyeongju World', 'Legoland Billund',
#        'Parque Espana-Shima Spain Village', 'Adventure Island',
#        'Tokyo DisneySea', 'Alabama Splash Adventure', 'Ferrari Land',
#        'Adventure City', 'Story Land', 'Đại Nam Văn Hiến',
#        'Dam Sen Cultural Park', 'Great Yarmouth Pleasure Beach',
#        'Suoi Tien Amusement Park', 'Idlewild and Soak Zone',
#        'Jackson, New Jersey, United States', 'Pacific Park',
#        'Dreamland Margate', 'Rides At Adventure Cove',
#        'Brean Leisure Park', 'Drayton Manor Theme Park', 'Kennywood Park',
#        'World Joyland', "Disney's Hollywood Studios", 'Disneyland',
#        'Enchanted Kingdom', 'TusenFryd', 'Great Escape',
#        'SeaWorld San Antonio', 'Frontier City', 'Paultons Park',
#        'Silverwood Theme Park', "Wet'n'Wild Gold Coast", 'Kongeparken',
#        'Family Kingdom Amusement Park', 'Wild Adventures', 'Everland',
#        'Wonderland Park (Texas)', 'Magic Kingdom', 'Tayto Park',
#        'Mason, Ohio, United States', 'Luna Park Melbourne',
#        "Holiday World & Splashin' Safari", 'Plopsaland De Panne',
#        'Thorpe Park Resort', 'Luna Park', 'Le Pal', 'Busch Gardens Tampa',
#        'Fraispertuis City', 'Parque de Atracciones de Madrid',
#        'Skara Sommarland', 'Adventureland (New York)', 'Elitch Gardens',
#        'Canobie Lake Park', 'Sesame Place', 'Calaway Park', 'Bellewaerde',
#        'Kolmården Wildlife Park', 'OCT East', 'Quassy Amusement Park',
#        "ZDT's Amusement Park"], dtype=object)

# %%
df_deduped.head()
# Out:
#                       coaster_name                  length  \
# 696    10 Inversion Roller Coaster    2,788.8 ft (850.0 m)
# 886         Abyss (roller coaster)        630 m (2,070 ft)
# 1057                       Abyssus  4,317.6 ft (1,316.0 m)
# 828   Accelerator (roller coaster)          180 m (590 ft)
# 936       Acrobat (roller coaster)  3,349.8 ft (1,021.0 m)
#
#                      speed            location     status     opening_date  \
# 696       45 mph (72 km/h)  Chimelong Paradise  Operating             2006
# 886       85 km/h (53 mph)     Adventure World  Operating  1 November 2013
# 1057  62.1 mph (99.9 km/h)        Energylandia  Operating    July 14, 2021
# 828       60 km/h (37 mph)       Drayton Manor  Operating    21 April 2011
# 936   55.9 mph (90.0 km/h)  Nagashima Spa Land  Operating    July 18, 2015
#
#                             type          manufacturer  \
# 696                        Steel               Intamin
# 886         Steel – Euro-Fighter            Gerstlauer
# 1057            Steel – Launched                Vekoma
# 828   Steel – Junior – Boomerang                Vekoma
# 936               Steel – Flying  Bolliger & Mabillard
#
#                     height_restriction                       model  \
# 696              54–77 in (137–196 cm)  Looping Coaster (Colossus)
# 886                 125 cm (4 ft 1 in)       Euro-Fighter – Custom
# 1057               120 cm (3 ft 11 in)            Shockwave 1320m+
# 828                 100 cm (3 ft 3 in)            Family Boomerang
# 936   135–198 cm (4 ft 5 in–6 ft 6 in)      Flying Coaster (Manta)
#
#                  height  inversions       lift_launch_system          cost  \
# 696    98.4 ft (30.0 m)        10.0                      NaN           NaN
# 886        30 m (98 ft)         3.0          Chain lift hill  A$12 million
# 1057  126.3 ft (38.5 m)         4.0                      LSM   €11,000,000
# 828        20 m (66 ft)         0.0  Booster Wheel Lift Hill    £2,100,000
# 936   141.1 ft (43.0 m)         4.0          Chain lift hill           NaN
#
#                                                  trains park_section  \
# 696   Single train with 7 cars. Riders are arranged ...          NaN
# 886   4 trains with a single car. Riders are arrange...          NaN
# 1057  3 trains with 4 cars. Riders are arranged 2 ac...   Aqualantis
# 828                                                 NaN  Aerial Park
# 936                                                 NaN          NaN
#
#        duration               capacity g_force              designer  \
# 696        1:32  1,300 riders per hour     NaN        Werner Stengel
# 886   2 minutes                    NaN     4.5                   NaN
# 1057        NaN   1000 riders per hour     4.5  Benjamin Bloemendaal
# 828         NaN    750 riders per hour       3        Meticulous ltd
# 936        3:00                    NaN     NaN                   NaN
#
#      max_vertical_angle             drop track_layout  year_introduced  \
# 696                 NaN              NaN          NaN             2006
# 886                100°  30.5 m (100 ft)       Custom             2013
# 1057                NaN              NaN          NaN             2021
# 828                 NaN              NaN          NaN             2011
# 936                 NaN              NaN          NaN             2015
#
#       latitude  longitude type_main  length(m)  speed(km/h)
# 696    23.0044   113.3269     Steel      850.0         72.0
# 886   -32.0955   115.8170     Steel      630.0         85.0
# 1057   49.9992    19.4011     Steel     1316.0         99.9
# 828    52.6108    -1.7134     Steel      180.0         60.0
# 936        NaN        NaN     Steel     1021.0         90.0

# %% [markdown]
# ----------------------

# %% [markdown]
# - Some opening_date are having None values or just have the year values
#
# - For such rows we get the date from the wiki
#
# - and we replace the \xa0 value by space to clean the values

# %%
def get_opening_date_by_coaster_name(row):
    opening_date = str(row["opening_date"])
    if opening_date == None or len(opening_date) == 4:
        date = get_field_from_wiki_by_coaster_name("opening_date", row['coaster_name'])
        row['opening_date'] = date
    else:
        date = opening_date.replace("\xa0", " ")
        row['opening_date'] = date
    return row

# %%
df_deduped.loc[:, 'opening_date'] = df_deduped.apply(lambda x: get_opening_date_by_coaster_name(x), axis=1)

# %% [markdown]
# ### The date fields have lot of extra data like [1] and [ 1 ] etc which we need to remove and also finally convert them into DateTime format

# %%
def convert_date(date):
    if date == None:
        return None
    orig_date = date
    try:
        date = date.replace("[1]", "").replace("[2]", "").replace("[ 1 ]", "").replace("[ 2 ]", "").replace(",", "").strip()
        date = date.split(";")[0]
        parts = date.split(" ")
        if len(parts) > 3:
            date = parts[0] + " " + parts[1] + " " +parts[2][:4]
        if date == None:
            return None
        res = pd.to_datetime(date)
        return res
    except:
        match = re.search(r"\d{4}", orig_date)
        if match:
            date = match.group()
            res = pd.to_datetime(date)
        elif orig_date and len(orig_date) > 4:
            date = orig_date[:4]
            print(orig_date, date)
            res = pd.to_datetime(date)
        else:
            res = None
        return res

# %%
df_deduped['opening_date'] = df_deduped['opening_date'].map(lambda x: convert_date(str(x)))

# %%
list(df_deduped['opening_date'].unique())
# Out:
# [numpy.datetime64('NaT'),
#  numpy.datetime64('2013-11-01T00:00:00.000000000'),
#  numpy.datetime64('2021-07-14T00:00:00.000000000'),
#  numpy.datetime64('2011-04-21T00:00:00.000000000'),
#  numpy.datetime64('2015-07-18T00:00:00.000000000'),
#  numpy.datetime64('2018-03-24T00:00:00.000000000'),
#  numpy.datetime64('1991-04-13T00:00:00.000000000'),
#  numpy.datetime64('1999-03-20T00:00:00.000000000'),
#  numpy.datetime64('1997-03-22T00:00:00.000000000'),
#  numpy.datetime64('2014-04-12T00:00:00.000000000'),
#  numpy.datetime64('1981-05-23T00:00:00.000000000'),
#  numpy.datetime64('2008-06-20T00:00:00.000000000'),
#  numpy.datetime64('1991-03-23T00:00:00.000000000'),
#  numpy.datetime64('2009-05-23T00:00:00.000000000'),
#  numpy.datetime64('1999-03-30T00:00:00.000000000'),
#  numpy.datetime64('2002-03-22T00:00:00.000000000'),
#  numpy.datetime64('2014-06-01T00:00:00.000000000'),
#  numpy.datetime64('1988-06-22T00:00:00.000000000'),
#  numpy.datetime64('1996-06-30T00:00:00.000000000'),
#  numpy.datetime64('2003-04-12T00:00:00.000000000'),
#  numpy.datetime64('1988-03-01T00:00:00.000000000'),
#  numpy.datetime64('2014-04-18T00:00:00.000000000'),
#  numpy.datetime64('2015-07-01T00:00:00.000000000'),
#  numpy.datetime64('2005-04-16T00:00:00.000000000'),
#  numpy.datetime64('2002-04-06T00:00:00.000000000'),
#  numpy.datetime64('2002-04-20T00:00:00.000000000'),
#  numpy.datetime64('2000-04-14T00:00:00.000000000'),
#  numpy.datetime64('2010-03-18T00:00:00.000000000'),
#  numpy.datetime64('2001-06-16T00:00:00.000000000'),
#  numpy.datetime64('2008-05-04T00:00:00.000000000'),
#  numpy.datetime64('1997-01-03T00:00:00.000000000'),
#  numpy.datetime64('1923-08-23T00:00:00.000000000'),
#  numpy.datetime64('1999-04-02T00:00:00.000000000'),
#  numpy.datetime64('2011-10-08T00:00:00.000000000'),
#  numpy.datetime64('2006-05-24T00:00:00.000000000'),
#  numpy.datetime64('2009-04-04T00:00:00.000000000'),
#  numpy.datetime64('1964-05-23T00:00:00.000000000'),
#  numpy.datetime64('2007-08-31T00:00:00.000000000'),
#  numpy.datetime64('2011-04-02T00:00:00.000000000'),
#  numpy.datetime64('2000-04-08T00:00:00.000000000'),
#  numpy.datetime64('2004-07-27T00:00:00.000000000'),
#  numpy.datetime64('2000-05-21T00:00:00.000000000'),
#  numpy.datetime64('2001-02-08T00:00:00.000000000'),
#  numpy.datetime64('2020-07-03T00:00:00.000000000'),
#  numpy.datetime64('2015-07-02T00:00:00.000000000'),
#  numpy.datetime64('1993-08-23T00:00:00.000000000'),
#  numpy.datetime64('1999-05-30T00:00:00.000000000'),
#  numpy.datetime64('1980-03-22T00:00:00.000000000'),
#  numpy.datetime64('1973-03-31T00:00:00.000000000'),
#  numpy.datetime64('2000-05-05T00:00:00.000000000'),
#  numpy.datetime64('1969-05-24T00:00:00.000000000'),
#  numpy.datetime64('2011-05-27T00:00:00.000000000'),
#  numpy.datetime64('2013-05-25T00:00:00.000000000'),
#  numpy.datetime64('2008-06-28T00:00:00.000000000'),
#  numpy.datetime64('2016-06-17T00:00:00.000000000'),
#  numpy.datetime64('1996-05-11T00:00:00.000000000'),
#  numpy.datetime64('2001-04-13T00:00:00.000000000'),
#  numpy.datetime64('2015-05-23T00:00:00.000000000'),
#  numpy.datetime64('1994-05-01T00:00:00.000000000'),
#  numpy.datetime64('1927-06-26T00:00:00.000000000'),
#  numpy.datetime64('2019-03-23T00:00:00.000000000'),
#  numpy.datetime64('1976-05-15T00:00:00.000000000'),
#  numpy.datetime64('2001-05-18T00:00:00.000000000'),
#  numpy.datetime64('1993-04-03T00:00:00.000000000'),
#  numpy.datetime64('1988-04-01T00:00:00.000000000'),
#  numpy.datetime64('2013-12-22T00:00:00.000000000'),
#  numpy.datetime64('2007-06-09T00:00:00.000000000'),
#  numpy.datetime64('2006-07-09T00:00:00.000000000'),
#  numpy.datetime64('1940-05-17T00:00:00.000000000'),
#  numpy.datetime64('2015-05-24T00:00:00.000000000'),
#  numpy.datetime64('1995-01-01T00:00:00.000000000'),
#  numpy.datetime64('2017-09-22T00:00:00.000000000'),
#  numpy.datetime64('1967-06-16T00:00:00.000000000'),
#  numpy.datetime64('2011-05-28T00:00:00.000000000'),
#  numpy.datetime64('2012-04-29T00:00:00.000000000'),
#  numpy.datetime64('2017-05-05T00:00:00.000000000'),
#  numpy.datetime64('2007-04-01T00:00:00.000000000'),
#  numpy.datetime64('2019-07-25T00:00:00.000000000'),
#  numpy.datetime64('2009-04-18T00:00:00.000000000'),
#  numpy.datetime64('1994-07-01T00:00:00.000000000'),
#  numpy.datetime64('2008-02-07T00:00:00.000000000'),
#  numpy.datetime64('2009-08-16T00:00:00.000000000'),
#  numpy.datetime64('2000-03-29T00:00:00.000000000'),
#  numpy.datetime64('1998-08-07T00:00:00.000000000'),
#  numpy.datetime64('2003-09-27T00:00:00.000000000'),
#  numpy.datetime64('1995-05-02T00:00:00.000000000'),
#  numpy.datetime64('1983-07-16T00:00:00.000000000'),
#  numpy.datetime64('2021-05-29T00:00:00.000000000'),
#  numpy.datetime64('2004-03-27T00:00:00.000000000'),
#  numpy.datetime64('2019-05-10T00:00:00.000000000'),
#  numpy.datetime64('2012-03-31T00:00:00.000000000'),
#  numpy.datetime64('2004-04-16T00:00:00.000000000'),
#  numpy.datetime64('2006-07-19T00:00:00.000000000'),
#  numpy.datetime64('2014-02-18T00:00:00.000000000'),
#  numpy.datetime64('2009-04-10T00:00:00.000000000'),
#  numpy.datetime64('2018-05-10T00:00:00.000000000'),
#  numpy.datetime64('2002-12-26T00:00:00.000000000'),
#  numpy.datetime64('2009-04-09T00:00:00.000000000'),
#  numpy.datetime64('2011-08-06T00:00:00.000000000'),
#  numpy.datetime64('1989-01-01T00:00:00.000000000'),
#  numpy.datetime64('2006-04-07T00:00:00.000000000'),
#  numpy.datetime64('2001-06-18T00:00:00.000000000'),
#  numpy.datetime64('1999-04-18T00:00:00.000000000'),
#  numpy.datetime64('2008-05-24T00:00:00.000000000'),
#  numpy.datetime64('2004-03-15T00:00:00.000000000'),
#  numpy.datetime64('2009-05-14T00:00:00.000000000'),
#  numpy.datetime64('2014-07-05T00:00:00.000000000'),
#  numpy.datetime64('2010-11-04T00:00:00.000000000'),
#  numpy.datetime64('2014-03-22T00:00:00.000000000'),
#  numpy.datetime64('1993-03-20T00:00:00.000000000'),
#  numpy.datetime64('1993-04-09T00:00:00.000000000'),
#  numpy.datetime64('2014-03-29T00:00:00.000000000'),
#  numpy.datetime64('2016-02-24T00:00:00.000000000'),
#  numpy.datetime64('1984-01-01T00:00:00.000000000'),
#  numpy.datetime64('2013-10-05T00:00:00.000000000'),
#  numpy.datetime64('2007-04-06T00:00:00.000000000'),
#  numpy.datetime64('2016-06-25T00:00:00.000000000'),
#  numpy.datetime64('2013-06-08T00:00:00.000000000'),
#  numpy.datetime64('1996-07-01T00:00:00.000000000'),
#  numpy.datetime64('2013-06-22T00:00:00.000000000'),
#  numpy.datetime64('2007-06-05T00:00:00.000000000'),
#  numpy.datetime64('2019-06-24T00:00:00.000000000'),
#  numpy.datetime64('2015-03-28T00:00:00.000000000'),
#  numpy.datetime64('2018-07-07T00:00:00.000000000'),
#  numpy.datetime64('2002-03-16T00:00:00.000000000'),
#  numpy.datetime64('2007-07-17T00:00:00.000000000'),
#  numpy.datetime64('2013-05-11T00:00:00.000000000'),
#  numpy.datetime64('1978-06-17T00:00:00.000000000'),
#  numpy.datetime64('1999-05-08T00:00:00.000000000'),
#  numpy.datetime64('1998-12-08T00:00:00.000000000'),
#  numpy.datetime64('1924-05-17T00:00:00.000000000'),
#  numpy.datetime64('1925-07-04T00:00:00.000000000'),
#  numpy.datetime64('2017-04-13T00:00:00.000000000'),
#  numpy.datetime64('1971-05-29T00:00:00.000000000'),
#  numpy.datetime64('2013-05-31T00:00:00.000000000'),
#  numpy.datetime64('2006-05-13T00:00:00.000000000'),
#  numpy.datetime64('2014-06-19T00:00:00.000000000'),
#  numpy.datetime64('2000-02-11T00:00:00.000000000'),
#  numpy.datetime64('2006-04-01T00:00:00.000000000'),
#  numpy.datetime64('2002-03-29T00:00:00.000000000'),
#  numpy.datetime64('1998-05-23T00:00:00.000000000'),
#  numpy.datetime64('2011-12-23T00:00:00.000000000'),
#  numpy.datetime64('2007-05-18T00:00:00.000000000'),
#  numpy.datetime64('1982-03-27T00:00:00.000000000'),
#  numpy.datetime64('2009-04-03T00:00:00.000000000'),
#  numpy.datetime64('2013-05-14T00:00:00.000000000'),
#  numpy.datetime64('2019-06-13T00:00:00.000000000'),
#  numpy.datetime64('2011-12-08T00:00:00.000000000'),
#  numpy.datetime64('2019-03-28T00:00:00.000000000'),
#  numpy.datetime64('2018-05-18T00:00:00.000000000'),
#  numpy.datetime64('1999-01-01T00:00:00.000000000'),
#  numpy.datetime64('2014-07-08T00:00:00.000000000'),
#  numpy.datetime64('2014-04-26T00:00:00.000000000'),
#  numpy.datetime64('2004-09-18T00:00:00.000000000'),
#  numpy.datetime64('2007-03-09T00:00:00.000000000'),
#  numpy.datetime64('2009-08-19T00:00:00.000000000'),
#  numpy.datetime64('1994-05-27T00:00:00.000000000'),
#  numpy.datetime64('1993-01-01T00:00:00.000000000'),
#  numpy.datetime64('2010-06-26T00:00:00.000000000'),
#  numpy.datetime64('2005-05-07T00:00:00.000000000'),
#  numpy.datetime64('2017-05-26T00:00:00.000000000'),
#  numpy.datetime64('2018-07-14T00:00:00.000000000'),
#  numpy.datetime64('2009-05-20T00:00:00.000000000'),
#  numpy.datetime64('2018-05-25T00:00:00.000000000'),
#  numpy.datetime64('2015-04-25T00:00:00.000000000'),
#  numpy.datetime64('1993-07-30T00:00:00.000000000'),
#  numpy.datetime64('2009-04-25T00:00:00.000000000'),
#  numpy.datetime64('2010-03-27T00:00:00.000000000'),
#  numpy.datetime64('2010-04-02T00:00:00.000000000'),
#  numpy.datetime64('2017-04-07T00:00:00.000000000'),
#  numpy.datetime64('1987-06-11T00:00:00.000000000'),
#  numpy.datetime64('2012-06-01T00:00:00.000000000'),
#  numpy.datetime64('1995-06-17T00:00:00.000000000'),
#  numpy.datetime64('2021-06-13T00:00:00.000000000'),
#  numpy.datetime64('2008-12-26T00:00:00.000000000'),
#  numpy.datetime64('2007-03-01T00:00:00.000000000'),
#  numpy.datetime64('2010-07-01T00:00:00.000000000'),
#  numpy.datetime64('1998-04-17T00:00:00.000000000'),
#  numpy.datetime64('2002-05-23T00:00:00.000000000'),
#  numpy.datetime64('1980-03-01T00:00:00.000000000'),
#  numpy.datetime64('2015-05-30T00:00:00.000000000'),
#  numpy.datetime64('2013-07-10T00:00:00.000000000'),
#  numpy.datetime64('2000-04-01T00:00:00.000000000'),
#  numpy.datetime64('2019-04-28T00:00:00.000000000'),
#  numpy.datetime64('2006-05-06T00:00:00.000000000'),
#  numpy.datetime64('1997-06-27T00:00:00.000000000'),
#  numpy.datetime64('2003-03-22T00:00:00.000000000'),
#  numpy.datetime64('2005-05-21T00:00:00.000000000'),
#  numpy.datetime64('1992-05-16T00:00:00.000000000'),
#  numpy.datetime64('2007-04-27T00:00:00.000000000'),
#  numpy.datetime64('2021-05-08T00:00:00.000000000'),
#  numpy.datetime64('2011-04-16T00:00:00.000000000'),
#  numpy.datetime64('2000-06-01T00:00:00.000000000'),
#  numpy.datetime64('2021-06-12T00:00:00.000000000'),
#  numpy.datetime64('1993-04-20T00:00:00.000000000'),
#  numpy.datetime64('2007-04-28T00:00:00.000000000'),
#  numpy.datetime64('1985-07-20T00:00:00.000000000'),
#  numpy.datetime64('2002-05-18T00:00:00.000000000'),
#  numpy.datetime64('2017-07-01T00:00:00.000000000'),
#  numpy.datetime64('2012-05-06T00:00:00.000000000'),
#  numpy.datetime64('2000-05-13T00:00:00.000000000'),
#  numpy.datetime64('2016-06-13T00:00:00.000000000'),
#  numpy.datetime64('2014-05-24T00:00:00.000000000'),
#  numpy.datetime64('2000-05-01T00:00:00.000000000'),
#  numpy.datetime64('1987-04-18T00:00:00.000000000'),
#  numpy.datetime64('1950-01-01T00:00:00.000000000'),
#  numpy.datetime64('1952-04-01T00:00:00.000000000'),
#  numpy.datetime64('1978-06-06T00:00:00.000000000'),
#  numpy.datetime64('2021-10-23T00:00:00.000000000'),
#  numpy.datetime64('2002-06-06T00:00:00.000000000'),
#  numpy.datetime64('2016-03-24T00:00:00.000000000'),
#  numpy.datetime64('2001-04-06T00:00:00.000000000'),
#  numpy.datetime64('1999-08-07T00:00:00.000000000'),
#  numpy.datetime64('1989-05-06T00:00:00.000000000'),
#  numpy.datetime64('2016-06-10T00:00:00.000000000'),
#  numpy.datetime64('1998-04-18T00:00:00.000000000'),
#  numpy.datetime64('2008-03-19T00:00:00.000000000'),
#  numpy.datetime64('2009-05-22T00:00:00.000000000'),
#  numpy.datetime64('2012-05-26T00:00:00.000000000'),
#  numpy.datetime64('1959-06-14T00:00:00.000000000'),
#  numpy.datetime64('2007-05-26T00:00:00.000000000'),
#  numpy.datetime64('2020-06-20T00:00:00.000000000'),
#  numpy.datetime64('2019-07-04T00:00:00.000000000'),
#  numpy.datetime64('2000-03-18T00:00:00.000000000'),
#  numpy.datetime64('2014-06-14T00:00:00.000000000'),
#  numpy.datetime64('1996-04-30T00:00:00.000000000'),
#  numpy.datetime64('2018-04-28T00:00:00.000000000'),
#  numpy.datetime64('2007-09-30T00:00:00.000000000'),
#  numpy.datetime64('1999-05-22T00:00:00.000000000'),
#  numpy.datetime64('2017-06-23T00:00:00.000000000'),
#  numpy.datetime64('2021-06-02T00:00:00.000000000'),
#  numpy.datetime64('1978-05-21T00:00:00.000000000'),
#  numpy.datetime64('1996-05-16T00:00:00.000000000'),
#  numpy.datetime64('2008-05-01T00:00:00.000000000'),
#  numpy.datetime64('2009-07-04T00:00:00.000000000'),
#  numpy.datetime64('2008-12-23T00:00:00.000000000'),
#  numpy.datetime64('2007-04-13T00:00:00.000000000'),
#  numpy.datetime64('2019-05-30T00:00:00.000000000'),
#  numpy.datetime64('2017-04-15T00:00:00.000000000'),
#  numpy.datetime64('1994-03-19T00:00:00.000000000'),
#  numpy.datetime64('2003-04-05T00:00:00.000000000'),
#  numpy.datetime64('2002-09-28T00:00:00.000000000'),
#  numpy.datetime64('2011-04-22T00:00:00.000000000'),
#  numpy.datetime64('2019-10-25T00:00:00.000000000'),
#  numpy.datetime64('1988-05-21T00:00:00.000000000'),
#  numpy.datetime64('2013-10-01T00:00:00.000000000'),
#  numpy.datetime64('2001-04-07T00:00:00.000000000'),
#  numpy.datetime64('2020-06-13T00:00:00.000000000'),
#  numpy.datetime64('1998-03-14T00:00:00.000000000'),
#  numpy.datetime64('2015-03-21T00:00:00.000000000'),
#  numpy.datetime64('1989-09-17T00:00:00.000000000'),
#  numpy.datetime64('2020-07-02T00:00:00.000000000'),
#  numpy.datetime64('2013-06-05T00:00:00.000000000'),
#  numpy.datetime64('1993-04-24T00:00:00.000000000'),
#  numpy.datetime64('2013-03-15T00:00:00.000000000'),
#  numpy.datetime64('2012-04-07T00:00:00.000000000'),
#  numpy.datetime64('2014-01-25T00:00:00.000000000'),
#  numpy.datetime64('1991-03-09T00:00:00.000000000'),
#  numpy.datetime64('2006-04-08T00:00:00.000000000'),
#  numpy.datetime64('1992-08-11T00:00:00.000000000'),
#  numpy.datetime64('2007-05-05T00:00:00.000000000'),
#  numpy.datetime64('1991-05-10T00:00:00.000000000'),
#  numpy.datetime64('1985-06-15T00:00:00.000000000'),
#  numpy.datetime64('2020-06-24T00:00:00.000000000'),
#  numpy.datetime64('1999-05-28T00:00:00.000000000'),
#  numpy.datetime64('2008-05-22T00:00:00.000000000'),
#  numpy.datetime64('1990-05-25T00:00:00.000000000'),
#  numpy.datetime64('2009-05-02T00:00:00.000000000'),
#  numpy.datetime64('2016-06-04T00:00:00.000000000'),
#  numpy.datetime64('2015-04-08T00:00:00.000000000'),
#  numpy.datetime64('1981-04-12T00:00:00.000000000'),
#  numpy.datetime64('2017-06-11T00:00:00.000000000'),
#  numpy.datetime64('1975-05-03T00:00:00.000000000'),
#  numpy.datetime64('2007-02-10T00:00:00.000000000'),
#  numpy.datetime64('1999-05-01T00:00:00.000000000'),
#  numpy.datetime64('2005-07-21T00:00:00.000000000'),
#  numpy.datetime64('2016-06-30T00:00:00.000000000'),
#  numpy.datetime64('2018-06-14T00:00:00.000000000'),
#  numpy.datetime64('1994-05-07T00:00:00.000000000'),
#  numpy.datetime64('2011-04-01T00:00:00.000000000'),
#  numpy.datetime64('2008-05-17T00:00:00.000000000'),
#  numpy.datetime64('2007-05-12T00:00:00.000000000'),
#  numpy.datetime64('2015-06-06T00:00:00.000000000'),
#  numpy.datetime64('2002-03-23T00:00:00.000000000'),
#  numpy.datetime64('2005-04-01T00:00:00.000000000'),
#  numpy.datetime64('1971-06-05T00:00:00.000000000'),
#  numpy.datetime64('1997-05-01T00:00:00.000000000'),
#  numpy.datetime64('2008-09-11T00:00:00.000000000'),
#  numpy.datetime64('1932-05-01T00:00:00.000000000'),
#  numpy.datetime64('1921-07-15T00:00:00.000000000'),
#  numpy.datetime64('1994-04-15T00:00:00.000000000'),
#  numpy.datetime64('2015-05-09T00:00:00.000000000'),
#  numpy.datetime64('1992-03-21T00:00:00.000000000'),
#  numpy.datetime64('1966-07-23T00:00:00.000000000'),
#  numpy.datetime64('1987-06-07T00:00:00.000000000'),
#  numpy.datetime64('2019-08-09T00:00:00.000000000'),
#  numpy.datetime64('2008-04-25T00:00:00.000000000'),
#  numpy.datetime64('2020-10-01T00:00:00.000000000'),
#  numpy.datetime64('1996-05-25T00:00:00.000000000'),
#  numpy.datetime64('2009-03-14T00:00:00.000000000'),
#  numpy.datetime64('1920-07-03T00:00:00.000000000'),
#  numpy.datetime64('1978-08-19T00:00:00.000000000'),
#  numpy.datetime64('2002-06-17T00:00:00.000000000'),
#  numpy.datetime64('1980-05-16T00:00:00.000000000'),
#  numpy.datetime64('1976-04-10T00:00:00.000000000'),
#  numpy.datetime64('2012-05-12T00:00:00.000000000'),
#  numpy.datetime64('1978-04-22T00:00:00.000000000'),
#  numpy.datetime64('1994-03-26T00:00:00.000000000'),
#  numpy.datetime64('1991-05-11T00:00:00.000000000'),
#  numpy.datetime64('2004-12-07T00:00:00.000000000'),
#  numpy.datetime64('2001-05-06T00:00:00.000000000'),
#  numpy.datetime64('1996-06-03T00:00:00.000000000'),
#  numpy.datetime64('2010-06-29T00:00:00.000000000'),
#  numpy.datetime64('2011-04-30T00:00:00.000000000'),
#  numpy.datetime64('2018-06-30T00:00:00.000000000'),
#  numpy.datetime64('2013-08-03T00:00:00.000000000'),
#  numpy.datetime64('1977-07-04T00:00:00.000000000'),
#  numpy.datetime64('1977-05-27T00:00:00.000000000'),
#  numpy.datetime64('1975-01-15T00:00:00.000000000'),
#  numpy.datetime64('1983-04-15T00:00:00.000000000'),
#  numpy.datetime64('2017-05-07T00:00:00.000000000'),
#  numpy.datetime64('1995-07-28T00:00:00.000000000'),
#  numpy.datetime64('2006-04-23T00:00:00.000000000'),
#  numpy.datetime64('2000-04-22T00:00:00.000000000'),
#  numpy.datetime64('2006-04-13T00:00:00.000000000'),
#  numpy.datetime64('2003-04-01T00:00:00.000000000'),
#  numpy.datetime64('2004-04-17T00:00:00.000000000'),
#  numpy.datetime64('2008-03-15T00:00:00.000000000'),
#  numpy.datetime64('1997-03-17T00:00:00.000000000'),
#  numpy.datetime64('2017-06-14T00:00:00.000000000'),
#  numpy.datetime64('2006-03-15T00:00:00.000000000'),
#  numpy.datetime64('1984-05-26T00:00:00.000000000'),
#  numpy.datetime64('2019-07-13T00:00:00.000000000'),
#  numpy.datetime64('2004-07-02T00:00:00.000000000'),
#  numpy.datetime64('2000-08-01T00:00:00.000000000'),
#  numpy.datetime64('1999-03-06T00:00:00.000000000'),
#  numpy.datetime64('1997-05-30T00:00:00.000000000'),
#  numpy.datetime64('2008-07-05T00:00:00.000000000'),
#  numpy.datetime64('2008-07-18T00:00:00.000000000'),
#  numpy.datetime64('2018-05-05T00:00:00.000000000'),
#  numpy.datetime64('2003-05-17T00:00:00.000000000'),
#  numpy.datetime64('2021-04-12T00:00:00.000000000'),
#  numpy.datetime64('2016-04-30T00:00:00.000000000'),
#  numpy.datetime64('2013-12-06T00:00:00.000000000'),
#  numpy.datetime64('2004-05-08T00:00:00.000000000'),
#  numpy.datetime64('1992-03-14T00:00:00.000000000'),
#  numpy.datetime64('2004-11-19T00:00:00.000000000'),
#  numpy.datetime64('2005-12-26T00:00:00.000000000'),
#  numpy.datetime64('1997-03-15T00:00:00.000000000'),
#  numpy.datetime64('2000-03-11T00:00:00.000000000'),
#  numpy.datetime64('2012-06-30T00:00:00.000000000'),
#  numpy.datetime64('2007-09-01T00:00:00.000000000'),
#  numpy.datetime64('2008-03-14T00:00:00.000000000'),
#  numpy.datetime64('1995-04-08T00:00:00.000000000'),
#  numpy.datetime64('2019-06-18T00:00:00.000000000'),
#  numpy.datetime64('2011-07-16T00:00:00.000000000'),
#  numpy.datetime64('2001-05-05T00:00:00.000000000'),
#  numpy.datetime64('1999-04-17T00:00:00.000000000'),
#  numpy.datetime64('2020-02-22T00:00:00.000000000'),
#  numpy.datetime64('1996-10-01T00:00:00.000000000'),
#  numpy.datetime64('1979-04-14T00:00:00.000000000'),
#  numpy.datetime64('1994-05-28T00:00:00.000000000'),
#  numpy.datetime64('2000-04-29T00:00:00.000000000'),
#  numpy.datetime64('1948-01-01T00:00:00.000000000'),
#  numpy.datetime64('2016-03-18T00:00:00.000000000'),
#  numpy.datetime64('2004-04-10T00:00:00.000000000'),
#  numpy.datetime64('1995-05-26T00:00:00.000000000'),
#  numpy.datetime64('1912-12-01T00:00:00.000000000'),
#  numpy.datetime64('1996-06-10T00:00:00.000000000'),
#  numpy.datetime64('1997-02-01T00:00:00.000000000'),
#  numpy.datetime64('2016-05-29T00:00:00.000000000'),
#  numpy.datetime64('2004-09-04T00:00:00.000000000'),
#  numpy.datetime64('2000-05-06T00:00:00.000000000'),
#  numpy.datetime64('1976-05-08T00:00:00.000000000'),
#  numpy.datetime64('1972-04-29T00:00:00.000000000'),
#  numpy.datetime64('1995-05-06T00:00:00.000000000'),
#  numpy.datetime64('1978-03-31T00:00:00.000000000'),
#  numpy.datetime64('1998-04-04T00:00:00.000000000'),
#  numpy.datetime64('2021-07-01T00:00:00.000000000'),
#  numpy.datetime64('2012-03-15T00:00:00.000000000'),
#  numpy.datetime64('1996-04-27T00:00:00.000000000'),
#  numpy.datetime64('1996-03-23T00:00:00.000000000'),
#  numpy.datetime64('2010-03-20T00:00:00.000000000'),
#  numpy.datetime64('2003-05-01T00:00:00.000000000'),
#  numpy.datetime64('1990-08-01T00:00:00.000000000'),
#  numpy.datetime64('1993-04-10T00:00:00.000000000'),
#  numpy.datetime64('2006-04-29T00:00:00.000000000'),
#  numpy.datetime64('2001-05-01T00:00:00.000000000'),
#  numpy.datetime64('1924-03-30T00:00:00.000000000'),
#  numpy.datetime64('2004-04-03T00:00:00.000000000'),
#  numpy.datetime64('2019-04-19T00:00:00.000000000'),
#  numpy.datetime64('2018-04-07T00:00:00.000000000'),
#  numpy.datetime64('2011-07-12T00:00:00.000000000'),
#  numpy.datetime64('1989-04-01T00:00:00.000000000'),
#  numpy.datetime64('2018-03-14T00:00:00.000000000'),
#  numpy.datetime64('2004-05-02T00:00:00.000000000'),
#  numpy.datetime64('2001-04-27T00:00:00.000000000'),
#  numpy.datetime64('1978-07-04T00:00:00.000000000'),
#  numpy.datetime64('1999-05-23T00:00:00.000000000'),
#  numpy.datetime64('1974-05-14T00:00:00.000000000'),
#  numpy.datetime64('2009-05-29T00:00:00.000000000'),
#  numpy.datetime64('1999-05-15T00:00:00.000000000'),
#  numpy.datetime64('2007-06-29T00:00:00.000000000'),
#  numpy.datetime64('2004-04-29T00:00:00.000000000'),
#  numpy.datetime64('2015-05-22T00:00:00.000000000'),
#  numpy.datetime64('1999-07-24T00:00:00.000000000'),
#  numpy.datetime64('1995-05-27T00:00:00.000000000'),
#  numpy.datetime64('2019-07-01T00:00:00.000000000'),
#  numpy.datetime64('2011-06-11T00:00:00.000000000'),
#  numpy.datetime64('2018-08-10T00:00:00.000000000'),
#  numpy.datetime64('2016-05-07T00:00:00.000000000'),
#  numpy.datetime64('1990-04-11T00:00:00.000000000'),
#  numpy.datetime64('2011-06-18T00:00:00.000000000'),
#  numpy.datetime64('1998-06-01T00:00:00.000000000'),
#  numpy.datetime64('1989-06-15T00:00:00.000000000'),
#  numpy.datetime64('2021-06-10T00:00:00.000000000'),
#  numpy.datetime64('2012-05-18T00:00:00.000000000'),
#  numpy.datetime64('2003-05-16T00:00:00.000000000'),
#  numpy.datetime64('2003-04-18T00:00:00.000000000'),
#  numpy.datetime64('1982-05-29T00:00:00.000000000'),
#  numpy.datetime64('1995-04-29T00:00:00.000000000'),
#  numpy.datetime64('1990-04-07T00:00:00.000000000'),
#  numpy.datetime64('1998-04-09T00:00:00.000000000'),
#  numpy.datetime64('1991-05-12T00:00:00.000000000'),
#  numpy.datetime64('1951-07-13T00:00:00.000000000'),
#  numpy.datetime64('2020-07-01T00:00:00.000000000'),
#  numpy.datetime64('2017-06-16T00:00:00.000000000'),
#  numpy.datetime64('2020-01-09T00:00:00.000000000'),
#  numpy.datetime64('2013-06-07T00:00:00.000000000'),
#  numpy.datetime64('2007-06-01T00:00:00.000000000'),
#  numpy.datetime64('2018-03-20T00:00:00.000000000'),
#  numpy.datetime64('2012-03-24T00:00:00.000000000'),
#  numpy.datetime64('1985-01-01T00:00:00.000000000'),
#  numpy.datetime64('1998-04-10T00:00:00.000000000'),
#  numpy.datetime64('1996-05-26T00:00:00.000000000'),
#  numpy.datetime64('2016-06-28T00:00:00.000000000'),
#  numpy.datetime64('2001-04-04T00:00:00.000000000'),
#  numpy.datetime64('2002-03-30T00:00:00.000000000'),
#  numpy.datetime64('1988-05-18T00:00:00.000000000'),
#  numpy.datetime64('2018-06-01T00:00:00.000000000'),
#  numpy.datetime64('2018-05-12T00:00:00.000000000'),
#  numpy.datetime64('2011-07-19T00:00:00.000000000'),
#  numpy.datetime64('2011-04-23T00:00:00.000000000'),
#  numpy.datetime64('1999-05-10T00:00:00.000000000'),
#  numpy.datetime64('1999-07-10T00:00:00.000000000'),
#  numpy.datetime64('1999-03-13T00:00:00.000000000'),
#  numpy.datetime64('2006-05-27T00:00:00.000000000'),
#  numpy.datetime64('2012-05-16T00:00:00.000000000'),
#  numpy.datetime64('2002-01-12T00:00:00.000000000'),
#  numpy.datetime64('2002-06-22T00:00:00.000000000'),
#  numpy.datetime64('2019-05-03T00:00:00.000000000'),
#  numpy.datetime64('2015-10-17T00:00:00.000000000'),
#  numpy.datetime64('1994-07-22T00:00:00.000000000'),
#  numpy.datetime64('2019-08-22T00:00:00.000000000'),
#  numpy.datetime64('1997-06-07T00:00:00.000000000')]

# %% [markdown]
# ### Again the type column has a lot of values wit this \xa0 which we need to clean

# %%
df_deduped.type.unique()
# Out:
# array(['Steel', 'Steel\xa0– Euro-Fighter', 'Steel\xa0– Launched',
#        'Steel\xa0– Junior\xa0– Boomerang', 'Steel\xa0– Flying',
#        'Steel\xa0– Mine Train', 'Steel\xa0– Inverted', 'Other',
#        'Steel\xa0– Powered\xa0– Virtual reality', 'Wood\xa0– Racing',
#        'Wood', 'Steel\xa0– Wild Mouse', 'Wood\xa0– Out and back',
#        'Steel\xa0– Inverted\xa0– Powered', 'Steel\xa0– Bobsled',
#        'Steel\xa0– Powered\xa0– Indoor', 'Steel\xa0– Junior',
#        'Steel\xa0– Dive Coaster', 'Steel\xa0– Floorless Coaster',
#        'Steel\xa0– Dueling\xa0– Launched',
#        'Steel\xa0– Family\xa0– Enclosed', 'Wood\xa0– Twister',
#        'Steel\xa0– Boomerang\xa0– Shuttle',
#        'Steel\xa0– Motorbike\xa0– Launched', 'Steel\xa0– Suspended',
#        'Steel\xa0– Indoor', 'Steel\xa0– Family', 'Steel\xa0– Shuttle',
#        'Steel\xa0– Spinning', 'Steel\xa0– Enclosed',
#        'Steel\xa0– Spinning\xa0– Enclosed',
#        'Steel\xa0– Dueling\xa0– Racing', 'Steel\xa0– 4th Dimension',
#        'Steel\xa0– 4th Dimension\xa0– Wing Coaster',
#        'Steel\xa0– Family\xa0– Inverted',
#        'Steel\xa0– Suspended Family Coaster',
#        'Steel\xa0– Launched\xa0– Euro-Fighter', 'Steel\xa0– spinning',
#        'Steel\xa0– Enclosed\xa0– Spinning',
#        'Steel\xa0– Flying\xa0– Launched',
#        'Steel\xa0– Spinning\xa0– Indoor',
#        'Steel\xa0– Launched\xa0– Dueling',
#        'Steel\xa0– Family\xa0– Launched', 'Steel\xa0– Wing Coaster',
#        'Wood\xa0– Bobsled', 'Steel\xa0– Stand-up', 'Steel\xa0– Kiddie',
#        'Steel\xa0– Launched\xa0– Enclosed', 'Steel\xa0– Single-rail',
#        'Steel\xa0– Launched\xa0– Motorbike',
#        'Steel\xa0– Inverted\xa0– Family', 'Wood\xa0– Family',
#        'Wood\xa0– Side friction', 'Wood\xa0– Racing\xa0– Dueling',
#        'Steel\xa0– Launched\xa0– Family',
#        'Steel\xa0– Powered\xa0– Dual-tracked',
#        'Steel\xa0– Launched\xa0– Shuttle', 'Wood\xa0– Steel',
#        'Steel\xa0– Family\xa0– Indoor',
#        'Steel\xa0– Spinning\xa0– Launched',
#        'Steel\xa0– Shuttle\xa0– Enclosed',
#        'Steel\xa0– Shuttle\xa0– Launched',
#        'Steel\xa0– Powered\xa0– Mine Train', 'Steel\xa0– Powered',
#        'Steel\xa0– Launched\xa0– Indoor',
#        'Steel\xa0– Wild Mouse\xa0– Enclosed',
#        'Steel\xa0– Shuttle\xa0– Boomerang', 'Steel\xa0– Mountain coaster',
#        'Steel\xa0– Dual-tracked\xa0– Enclosed',
#        'Steel\xa0– Euro-Fighter\xa0– Indoor',
#        'Steel\xa0– Inverted\xa0– Launched', 'Steel\xa0– Racing',
#        'Steel\xa0– Launched\xa0– Shuttle\xa0– Dueling',
#        'Steel\xa0– Wing Coaster\xa0– Launched', 'Steel\xa0– Pipeline',
#        'Wood\xa0– Terrain', 'Steel\xa0– Boomerang'], dtype=object)

# %%
df_deduped.loc[:, 'type'] = df_deduped.type.map(lambda x : x.split(" ")[0]).replace("–", "", regex=True).str.strip()

# %% [markdown]
# ### Now we have the cleeaned type values

# %%
df_deduped.type.value_counts()
# Out:
# Steel    492
# Wood     131
# Other     23
# Name: type, dtype: int64

# %%
df_deduped.type.unique()
# Out:
# array(['Steel', 'Other', 'Wood'], dtype=object)

# %%
df_deduped.manufacturer.isna().sum()
# Out:
# 24

# %%
df_deduped.head()
# Out:
#                       coaster_name                  length  \
# 696    10 Inversion Roller Coaster    2,788.8 ft (850.0 m)
# 886         Abyss (roller coaster)        630 m (2,070 ft)
# 1057                       Abyssus  4,317.6 ft (1,316.0 m)
# 828   Accelerator (roller coaster)          180 m (590 ft)
# 936       Acrobat (roller coaster)  3,349.8 ft (1,021.0 m)
#
#                      speed            location     status opening_date   type  \
# 696       45 mph (72 km/h)  Chimelong Paradise  Operating          NaT  Steel
# 886       85 km/h (53 mph)     Adventure World  Operating   2013-11-01  Steel
# 1057  62.1 mph (99.9 km/h)        Energylandia  Operating   2021-07-14  Steel
# 828       60 km/h (37 mph)       Drayton Manor  Operating   2011-04-21  Steel
# 936   55.9 mph (90.0 km/h)  Nagashima Spa Land  Operating   2015-07-18  Steel
#
#               manufacturer                height_restriction  \
# 696                Intamin             54–77 in (137–196 cm)
# 886             Gerstlauer                125 cm (4 ft 1 in)
# 1057                Vekoma               120 cm (3 ft 11 in)
# 828                 Vekoma                100 cm (3 ft 3 in)
# 936   Bolliger & Mabillard  135–198 cm (4 ft 5 in–6 ft 6 in)
#
#                            model             height  inversions  \
# 696   Looping Coaster (Colossus)   98.4 ft (30.0 m)        10.0
# 886        Euro-Fighter – Custom       30 m (98 ft)         3.0
# 1057            Shockwave 1320m+  126.3 ft (38.5 m)         4.0
# 828             Family Boomerang       20 m (66 ft)         0.0
# 936       Flying Coaster (Manta)  141.1 ft (43.0 m)         4.0
#
#            lift_launch_system          cost  \
# 696                       NaN           NaN
# 886           Chain lift hill  A$12 million
# 1057                      LSM   €11,000,000
# 828   Booster Wheel Lift Hill    £2,100,000
# 936           Chain lift hill           NaN
#
#                                                  trains park_section  \
# 696   Single train with 7 cars. Riders are arranged ...          NaN
# 886   4 trains with a single car. Riders are arrange...          NaN
# 1057  3 trains with 4 cars. Riders are arranged 2 ac...   Aqualantis
# 828                                                 NaN  Aerial Park
# 936                                                 NaN          NaN
#
#        duration               capacity g_force              designer  \
# 696        1:32  1,300 riders per hour     NaN        Werner Stengel
# 886   2 minutes                    NaN     4.5                   NaN
# 1057        NaN   1000 riders per hour     4.5  Benjamin Bloemendaal
# 828         NaN    750 riders per hour       3        Meticulous ltd
# 936        3:00                    NaN     NaN                   NaN
#
#      max_vertical_angle             drop track_layout  year_introduced  \
# 696                 NaN              NaN          NaN             2006
# 886                100°  30.5 m (100 ft)       Custom             2013
# 1057                NaN              NaN          NaN             2021
# 828                 NaN              NaN          NaN             2011
# 936                 NaN              NaN          NaN             2015
#
#       latitude  longitude type_main  length(m)  speed(km/h)
# 696    23.0044   113.3269     Steel      850.0         72.0
# 886   -32.0955   115.8170     Steel      630.0         85.0
# 1057   49.9992    19.4011     Steel     1316.0         99.9
# 828    52.6108    -1.7134     Steel      180.0         60.0
# 936        NaN        NaN     Steel     1021.0         90.0

# %% [markdown]
# ## We need to standardise the height_restriction values into centimeters to keep it easy for further use

# %%
def get_height_restriction(height_restriction):
    height_restriction = height_restriction.replace("\xa0", "").replace("[2]", "").replace("[3]", "").replace("[4]", "")
    res = re.search(r"(\d+–\d+\s*cm)", height_restriction)
    if res != None:
        return res[0].replace("(", "").replace(")", "").replace("–", ",").replace("cm", "").strip().split(",")[0]
    elif re.search(r"(\d+)\s*ft\s*(\d+)\s*in", height_restriction):
        match = re.search(r"(\d+)\s*ft\s*(\d+)\s*in", height_restriction)
        feet = match.group(1)
        inch = match.group(2)
        res = round(float(feet) * 30.48 + float(inch) * 2.54, 2)
        print(feet, inch, res)
        return res
    else:
        res = re.search(r"\d+\s*cm", height_restriction)
        if res != None:
            return res[0].replace("cm", "").strip()
        else:
            return height_restriction

# %%
df_deduped.loc[:, "height_restriction_clean"] = df_deduped.height_restriction.map(lambda x : get_height_restriction(str(x)))
# Out:
# 4 1 124.46
# 3 11 119.38
# 3 3 99.06
# 3 3 99.06
# 3 3 99.06
# 3 3 99.06
# 4 3 129.54
# 3 11 119.38
# 3 6 106.68
# 4 3 129.54
# 3 3 99.06
# 3 11 119.38
# 4 7 139.7
# 4 0 121.92
# 3 11 119.38
# 3 3 99.06
# 3 11 119.38
# 4 4 132.08
# 3 0 91.44
# 3 7 109.22
# 3 11 119.38
# 4 3 129.54
# 3 11 119.38
# 4 3 129.54
# 2 11 88.9
# 4 3 129.54
# 4 7 139.7
# 3 4 101.6
# 4 3 129.54
# 4 7 139.7
# 4 7 139.7
# 4 7 139.7
# 4 7 139.7
# 4 3 129.54
# 4 4 132.08
# 4 3 129.54
# 4 7 139.7
# 4 1 124.46
# 3 7 109.22
# 4 3 129.54
# 3 11 119.38
# 4 1 124.46
# 3 11 119.38
# 4 7 139.7
# 3 7 109.22
# 3 7 109.22
# 4 7 139.7
# 3 3 99.06
# 3 11 119.38
# 3 7 109.22
# 4 0 121.92
# 3 11 119.38
# 4 7 139.7
# 4 7 139.7
# 4 7 139.7
# 4 7 139.7
# 4 7 139.7
# 2 11 88.9
# 4 3 129.54
# 3 5 104.14
# 3 3 99.06
# 4 7 139.7
# 4 3 129.54
# 3 3 99.06
# 4 3 129.54
# 3 11 119.38
# 3 3 99.06
# 4 7 139.7
# 3 7 109.22
# 2 11 88.9
# 2 11 88.9
# 4 7 139.7
# 3 7 109.22
# 2 11 88.9
# 4 7 139.7
# 3 4 101.6
# 4 1 124.46
# 3 11 119.38
# 4 3 129.54
# 3 3 99.06
# 3 7 109.22
# 4 3 129.54
# 4 7 139.7
# 4 7 139.7
# 4 1 124.46
# 4 3 129.54
# 3 3 99.06
# 4 3 129.54
# 4 3 129.54
# 4 7 139.7
# 4 7 139.7
# 4 3 129.54
# 3 4 101.6
# 4 3 129.54
# 3 3 99.06
# 3 11 119.38
# 4 6 137.16
# 4 3 129.54
# 3 11 119.38
# 3 7 109.22
# 3 11 119.38
# 4 4 132.08
# 3 11 119.38
# 3 3 99.06
# 4 7 139.7
# 4 0 121.92
# 4 7 139.7
# 3 3 99.06
# 3 11 119.38
# 4 0 121.92
# 4 3 129.54
# 3 11 119.38
# 3 6 106.68
# 3 11 119.38
# 4 7 139.7

# %%
df_deduped[["height_restriction", "height_restriction_clean"]]
# Out:
#                     height_restriction height_restriction_clean
# 696              54–77 in (137–196 cm)                      137
# 886                 125 cm (4 ft 1 in)                   124.46
# 1057               120 cm (3 ft 11 in)                   119.38
# 828                 100 cm (3 ft 3 in)                    99.06
# 936   135–198 cm (4 ft 5 in–6 ft 6 in)                      135
# ...                                ...                      ...
# 364                     40 in (102 cm)                      102
# 1046                140 cm (4 ft 7 in)                    139.7
# 433                     48 in (122 cm)                      122
# 56                                 NaN                      nan
# 434                     48 in (122 cm)                      122
#
# [646 rows x 2 columns]

# %%
df_deduped['height_restriction_clean'].unique()
# Out:
# array(['137', 124.46, 119.38, 99.06, '135', '122', 'nan', '132', '112',
#        129.54, '120', '107', '130', '125', '117', '140', '91', '92', '84',
#        '104', 106.68, 139.7, 121.92, '99', 132.08, 91.44, 109.22, '109',
#        '102', 88.9, '110', 101.6, '127', '97', 104.14, '145', '142', '89',
#        137.16], dtype=object)

# %%
df_deduped['height_restriction_clean'] = df_deduped['height_restriction_clean'].astype(float)

# %% [markdown]
# Standardising height column into meters

# %%
def get_height(height):
    res = re.search(r"\(\d+.\d+\s*m\)", height)
    if res != None:
        # height contains 72 ft (22 m)
        return res[0].replace("(", "").replace(")", "").replace("m", "").replace(",", "").strip()
    else:
        res = re.search(r"\d+.?\d*\s*m", height)
        if res != None:
            # height contains 30 m (98 ft)
            return res[0].replace("(", "").replace(")", "").replace("m", "").replace(",", "").strip()
        else:
            # height contains only ft - 119.8 ft
            if "ft" in height:
                height = height.replace("ft", "")
                return str(round(float(height) * 0.3048, 2))
            return height

# %%
df_deduped['height_clean'] = df_deduped.height.map(lambda x: get_height(str(x)))

# %%
df_deduped[['height', 'height_clean']]
# Out:
#                  height height_clean
# 696    98.4 ft (30.0 m)         30.0
# 886        30 m (98 ft)           30
# 1057  126.3 ft (38.5 m)         38.5
# 828        20 m (66 ft)           20
# 936   141.1 ft (43.0 m)         43.0
# ...                 ...          ...
# 364                 NaN          nan
# 1046    62.8 m (206 ft)         62.8
# 433        90 ft (27 m)           27
# 56        15 ft (4.6 m)          4.6
# 434   116.5 ft (35.5 m)         35.5
#
# [646 rows x 2 columns]

# %%
df_deduped.height_clean.unique()
# Out:
# array(['30.0', '30', '38.5', '20', '43.0', '22', '19', '34', 'nan', '6',
#        '59', '33', '38.7', '25', '36.0', '39', '29', '52', '16', '13.5',
#        '22.0', '18', '8.5', '36', '27.8', '51.0', '51', '14.8', '32',
#        '35.9', '33.3', '42.7', '35', '70', '62', '43', '11', '26.0', '38',
#        '4.6', '24', '33.00', '14', '15', '37', '64', '63', '21', '2.4',
#        '13', '8.00', '31', '35.5', '26', '50.0', '17', '11.7', '61.6',
#        '32.0', '25.0', '17.50', '32.99', '69.0', '60', '65', '4', '23.8',
#        '45.1', '57', '15.5', '19.3', '28', '76.00', '27', '24.5', '46',
#        '14.9', '40', '23', '25.5', '61', '53', '13.0', '12', '11.8',
#        '20.0', '33.31', '6.1', '24.7', '19.6', '79', '49', '99', '45',
#        '38.1', '12.5', '33.0', '53.3', '50', '72', '47.17', '3.0', '4.0',
#        '7.3', '41', '35.0', '55', '8.0', '44', '3.3', '4.5', '77', '27.0',
#        '71', '93', '14.0', '40.0', '42', '31.0', '8', '139', '25.4', '47',
#        '28.0', '35.89', '39.9', '93.3', '7', '13.75', '9.1', '24.4',
#        '27.4', '94', '34.0', '9.8', '19.8', '42.5', '6.5', '87', '4.1',
#        '45.01', '7.0', '43.5', '24.0', '31.2', '21.0', '22.1', '25.9',
#        '15.01', '112', '29.7', '12.0', '18.4', '33.6', '18.9', '8.2',
#        '4.7', '11.0', '17.0', '18.5', '76', '36.5', '19.0', '73', '12.3',
#        '1200', '15.49', '22.7', '25.6', '62.5', '67', '97', '56', '67.0',
#        '126.5', '56.02', '52.0', '33.2', '40.6', '26.8', '48', '38.6',
#        '12.7', '80', '10', '30.6', '13.49', '29.26', '15.3', '75', '7.9',
#        '31.9', '16.5', '30.9', '25.7', '36.52', '47.0', '68', '20.76',
#        '21.2', '15.0', '5.8', '17.4', '18.3', '4.9', '62.8'], dtype=object)

# %%
df_deduped['height_clean'] = df_deduped.height_clean.astype(float)

# %% [markdown]
# Standardising all duration to seconds

# %%
def convert_duration_to_seconds(duration):
    origDuration = duration
    result = duration
    try:
        duration = duration.replace("~", "").replace("approx", "").strip().lower()
        duration = duration.replace("[1]", ":").replace("[2]", "").replace("[3]", "").strip()
        duration = duration.replace(".", ":").replace("and", "").strip()
        duration = duration.split("[")[0]
        if re.search(r"(\d+):(\d+)", duration):
            # duration 11:30
            duration = duration.replace("minutes", "").replace("minute", "").replace("mins", "").replace("min", "").strip()
            duration = re.search(r"(\d+):(\d+)\s*", duration)[0]
            parts = duration.split(":")
            result = int(parts[0]) * 60 + int(parts[1])
        elif re.search(r"(\d+)\s*min\s*(\d+)\s*sec", duration):
            # duration 1 min 30 sec
            match = re.search(r"(\d+)\s*min\s*(\d+)\s*sec", duration)
            minutes = int(match.group(1))
            seconds = int(match.group(2))
            result = (minutes * 60) + seconds
        elif re.search(r"(\d+)\s*minutes?\s*(\d+)\s*seconds?", duration):
            match = re.search(r"(\d+)\s*minutes?\s*(\d+)\s*seconds?", duration)
            minutes = int(match.group(1))
            seconds = int(match.group(2))
            result = (minutes * 60) + seconds
        elif "minutes" in duration or "minute" in duration:
            duration = duration.replace("minutes", "").replace("minute", "").replace(":", "").strip()
            result = int(duration) * 60
        elif "seconds" in duration or "secs" in duration or  "sec:" in duration:
            duration = duration.replace("seconds", "").replace("secs", "").replace("sec:", "").strip()
            result = int(duration)
        
#         print(duration, " => " ,result)
    except:
        print("in exception: ", origDuration, duration)
    return result

# %%
df_deduped.duration.map(lambda x: convert_duration_to_seconds(str(x))).unique()
# Out:
# in exception:  Under two minutes under two
# in exception:  7-8 minutes 7-8
# array([92, 120, 'nan', 180, 140, 167, 100, 190, 143, 130, 110, 135, 240,
#        82, 90, 44, 128, 138, 160, 75, 96, 122, 148, 60, 105, 102, 108, 68,
#        150, 156, 146, 52, 137, 170, 175, 145, 220, 84, 144, 51, 55, 115,
#        171, 223, 116, 210, 83, 106, 73, 45, 66, 273, 200, 118, 85, 42,
#        195, 139, 88, 112, 27, 63, 216, 77, 80, 67, 65, 300, 151, 99, 155,
#        161, 213, 32, 356, 172, 154, 142, 70, 28, 'Under two minutes', 174,
#        104, 208, 192, 40, 78, 153, 165, 127, 23, 36, 50, 103, 205, 87,
#        134, 117, 95, 101, 113, 98, 136, '66', 25, 58, 253, '2 min', 30,
#        76, 126, '7-8 minutes', 275, 69, 37, 43, 184, 250, 125, 56, 79,
#        217, 114, 93, 38, 133, 64, 94, 124, 62], dtype=object)

# %% [markdown]
# There are some values below for which we can only approximate the seconds value logically

# %%
df_deduped.loc[df_deduped["duration"] == "Under two minutes", "duration"] = 119

# %%
df_deduped.loc[df_deduped["duration"] == "7-8 minutes", "duration"] = 450

# %%
df_deduped.loc[df_deduped["duration"] == "2 min", "duration"] = 120

# %%
df_deduped['duration_clean'] = df_deduped.duration.map(lambda x: convert_duration_to_seconds(str(x)))

# %%
df_deduped['duration_clean'].unique()
# Out:
# array([92, 120, 'nan', 180, 140, 167, 100, 190, 143, 130, 110, 135, 240,
#        82, 90, 44, 128, 138, 160, 75, 96, 122, 148, 60, 105, 102, 108, 68,
#        150, 156, 146, 52, 137, 170, 175, 145, 220, 84, 144, 51, 55, 115,
#        171, 223, 116, 210, 83, 106, 73, 45, 66, 273, 200, 118, 85, 42,
#        195, 139, 88, 112, 27, 63, 216, 77, 80, 67, 65, 300, 151, 99, 155,
#        161, 213, 32, 356, 172, 154, 142, 70, 28, '119', 174, 104, 208,
#        192, 40, 78, 153, 165, 127, 23, 36, 50, 103, 205, 87, 134, 117, 95,
#        101, 113, 98, 136, '66', 25, 58, 253, '120', 30, 76, 126, '450',
#        275, 69, 37, 43, 184, 250, 125, 56, 79, 217, 114, 93, 38, 133, 64,
#        94, 124, 62], dtype=object)

# %%
df_deduped['duration_clean'] = df_deduped['duration_clean'].astype(float)

# %%
df_deduped.head()
# Out:
#                       coaster_name                  length  \
# 696    10 Inversion Roller Coaster    2,788.8 ft (850.0 m)
# 886         Abyss (roller coaster)        630 m (2,070 ft)
# 1057                       Abyssus  4,317.6 ft (1,316.0 m)
# 828   Accelerator (roller coaster)          180 m (590 ft)
# 936       Acrobat (roller coaster)  3,349.8 ft (1,021.0 m)
#
#                      speed            location     status opening_date   type  \
# 696       45 mph (72 km/h)  Chimelong Paradise  Operating          NaT  Steel
# 886       85 km/h (53 mph)     Adventure World  Operating   2013-11-01  Steel
# 1057  62.1 mph (99.9 km/h)        Energylandia  Operating   2021-07-14  Steel
# 828       60 km/h (37 mph)       Drayton Manor  Operating   2011-04-21  Steel
# 936   55.9 mph (90.0 km/h)  Nagashima Spa Land  Operating   2015-07-18  Steel
#
#               manufacturer                height_restriction  \
# 696                Intamin             54–77 in (137–196 cm)
# 886             Gerstlauer                125 cm (4 ft 1 in)
# 1057                Vekoma               120 cm (3 ft 11 in)
# 828                 Vekoma                100 cm (3 ft 3 in)
# 936   Bolliger & Mabillard  135–198 cm (4 ft 5 in–6 ft 6 in)
#
#                            model             height  inversions  \
# 696   Looping Coaster (Colossus)   98.4 ft (30.0 m)        10.0
# 886        Euro-Fighter – Custom       30 m (98 ft)         3.0
# 1057            Shockwave 1320m+  126.3 ft (38.5 m)         4.0
# 828             Family Boomerang       20 m (66 ft)         0.0
# 936       Flying Coaster (Manta)  141.1 ft (43.0 m)         4.0
#
#            lift_launch_system          cost  \
# 696                       NaN           NaN
# 886           Chain lift hill  A$12 million
# 1057                      LSM   €11,000,000
# 828   Booster Wheel Lift Hill    £2,100,000
# 936           Chain lift hill           NaN
#
#                                                  trains park_section  \
# 696   Single train with 7 cars. Riders are arranged ...          NaN
# 886   4 trains with a single car. Riders are arrange...          NaN
# 1057  3 trains with 4 cars. Riders are arranged 2 ac...   Aqualantis
# 828                                                 NaN  Aerial Park
# 936                                                 NaN          NaN
#
#        duration               capacity g_force              designer  \
# 696        1:32  1,300 riders per hour     NaN        Werner Stengel
# 886   2 minutes                    NaN     4.5                   NaN
# 1057        NaN   1000 riders per hour     4.5  Benjamin Bloemendaal
# 828         NaN    750 riders per hour       3        Meticulous ltd
# 936        3:00                    NaN     NaN                   NaN
#
#      max_vertical_angle             drop track_layout  year_introduced  \
# 696                 NaN              NaN          NaN             2006
# 886                100°  30.5 m (100 ft)       Custom             2013
# 1057                NaN              NaN          NaN             2021
# 828                 NaN              NaN          NaN             2011
# 936                 NaN              NaN          NaN             2015
#
#       latitude  longitude type_main  length(m)  speed(km/h)  \
# 696    23.0044   113.3269     Steel      850.0         72.0
# 886   -32.0955   115.8170     Steel      630.0         85.0
# 1057   49.9992    19.4011     Steel     1316.0         99.9
# 828    52.6108    -1.7134     Steel      180.0         60.0
# 936        NaN        NaN     Steel     1021.0         90.0
#
#       height_restriction_clean  height_clean  duration_clean
# 696                     137.00          30.0            92.0
# 886                     124.46          30.0           120.0
# 1057                    119.38          38.5             NaN
# 828                      99.06          20.0             NaN
# 936                     135.00          43.0           180.0

# %% [markdown]
# We will keep numerical columns as float type and other caategorical columns as string

# %%
df_deduped['length(m)'] = df_deduped['length(m)'].astype(float)

# %%
df_deduped['speed(km/h)'] = df_deduped['speed(km/h)'].astype(float)

# %%
df_deduped['status'] =df_deduped['status'].astype(str)

# %%
df_deduped['opening_date'] = df_deduped['opening_date'].astype("datetime64[ns]")

# %%
df_deduped['type'] = df_deduped['type'].astype(str)

# %%
df_deduped['height_restriction_clean'] = df_deduped['height_restriction_clean'].astype(float)

# %%
df_deduped['model'].unique()
# Out:
# array(['Looping Coaster (Colossus)', 'Euro-Fighter – Custom',
#        'Shockwave 1320m+', 'Family Boomerang', 'Flying Coaster (Manta)',
#        '320', 'Mine Train', 'Inverted Coaster – Custom', nan, 'Custom',
#        'Inverted Coaster', 'Wooden', 'Custom Looping Coaster',
#        'Hyper Coaster', 'Wild Mouse / Large Park',
#        'Suspended looping coaster', 'Muti-loop', 'Bobsleigh', 'Dragon',
#        'Junior Coaster (207m)', 'Wooden Coaster (Prefabricated Track)',
#        'Cyclone', 'Sitdown', 'Dive Coaster',
#        'Suspended Family Coaster (342m)', 'Inverted Coaster (Batman)',
#        'Floorless Coaster[1]', 'Flying Dutchman (1018m)', 'Hypercoaster',
#        'Sitdown Looping', 'Wooden Out and back coaster',
#        'Floorless Coaster / Medusa',
#        'Launched full-circuit dark ride / roller coaster',
#        'Suspended Looping Coaster (765m Extended w/ Helix)',
#        'Shuttle roller coaster', 'Motorbike Coaster (600m)',
#        'Looping Coaster', 'Jumbo V',
#        'Family Coasters/16ft Oval w/helix on left', 'Custom Looping',
#        'Family coaster', 'Wild Mouse (large park)', 'Boomerang',
#        'compact Inverted Coaster', 'Custom MK-900 M',
#        'Wooden Coaster (prefabricated\xa0track)', 'I-Box – Custom',
#        'Multi Inversion Coaster',
#        'Double Looping (with additional trackway curve)',
#        'Suspended Looping Coaster', 'Launch Coaster', 'Wacky Worm',
#        'Custom MK-900', 'El Loco', 'Flying Coaster', 'I-Box',
#        'Euro-Fighter (Custom)', 'Racing roller coaster', 'Sport Coaster',
#        'Sky Rocket - Indoor', 'Spike Dragster', '4th Dimension Coaster',
#        'Floorless Dive Coaster', 'Family Gravity Coaster 80STD',
#        'Sitting Coaster', '4D Free Spin', 'Xtended SC 3000',
#        'Suspended Family Coaster (453m)', 'Floorless Coaster',
#        'Sky Rocket II', 'Special Coaster Systems', 'Spinning Coaster',
#        'Spinning Coaster Model 420/4', '144a', 'Family Inverted Coaster',
#        'SLC (689m Standard)', 'Suspended Coaster', 'Wing Coaster',
#        'Suspended Family Coaster 342m', 'Wing Coaster (Intamin)',
#        'Powered', 'Accelerator Coaster', 'XL 1000',
#        'Space Warp Launch Coaster', 'Suspended Family Coaster (395m)',
#        'Wing Rider Coaster Accelerator Coaster', 'Infinity Coaster',
#        'Sit down', 'Stand-up Coaster', 'Wild Mouse (compact park)',
#        'Twister', 'Topper Track – Custom', 'Mega Coaster',
#        'Family gravity coaster 80STD', 'Force - 190',
#        'Motorbike roller coaster', 'I-Box Track', 'Tivoli - Large',
#        'Wooden Coaster', 'wood out-and-back', 'X-Car / Music',
#        'Out and Back roller coaster', 'Force - One', 'Mega coaster',
#        'Blitz Coaster', 'Launch Coaster (Custom)', 'Tower Speed Coaster',
#        'ZacSpin', 'Giga Coaster', 'Euro-Fighter (Iron Shark)', 'Tivoli',
#        'Raptor - Custom', 'Jet Star 2', 'Suspended Family Coaster (294m)',
#        'Water Coaster', 'SLC (Custom)', 'custom',
#        'Mine train roller coaster', 'Mega-lite', 'SLC Shenlin design',
#        'Inverted Coaster / Batman', 'Bermuda Blitz', 'Hyper coaster',
#        'Topper and I-Box Track', 'Hyper GT-X Coaster', 'Force – Custom',
#        'Custom steel', 'Little Dipper', 'ZL42', 'BigDipper',
#        'Suspended Looping Coaster (689m Standard)', 'Mad Mouse',
#        'Flying Coaster – Manta', 'Powered coaster',
#        'Compressed Air Launch', 'Floorless',
#        'Family MotorBike Launch Coaster', 'Custom MK-1200',
#        'Shuttle Loop - Flywheel', 'Motocoaster', 'Big Dipper',
#        'Junior Coaster', 'Family Coaster', 'Powered Coaster',
#        'Elevated Seating Coaster', 'LIM Coaster', 'MotoCoaster',
#        'PowerSplash', 'Double Loop Corkscrew', 'Racing',
#        'Euro-Fighter Model 320+', 'Intamin – Looping Coaster',
#        'Junior Boomerang', 'Raptor - Prototype (Mirror)',
#        'Inverted Coaster - Raptor', 'Wilde Maus Classic', 'Launched Loop',
#        'Zyklon', 'Blauer Enzian', 'Force - 281', 'Eurofighter',
#        'Scenic Railway', 'Bobsled coaster', 'Silver Arrow',
#        'Double Loop with Corkscrew', 'TL59', 'custom looping',
#        'Stand-up roller coaster', 'Shuttle Loop',
#        'Spinning Coaster / Sierra Sidewinder', 'Inverted coaster',
#        'Suspended Family Coaster', 'Indoor Roller Coaster',
#        'Flying Coaster – Custom', 'Mountain coaster',
#        'Looping Speedracer', 'Accelerator coaster', 'Xtended SC 2000',
#        'SC 2200[1]', 'Suspended Family Coaster (293m)',
#        'Twisted Impulse Coaster', 'Junior Coaster (85m)',
#        'Raptor – Custom', 'Reverse Freefall Coaster',
#        'Floorless Coaster - Custom', 'Half Pipe Roller Coaster',
#        'SLC (662m Prototype)', '1000', 'Euro-Fighter',
#        'LSM Blitz Coaster', 'Junior Coaster (Custom)',
#        'Wooden track coaster', 'Flying Coaster - Custom',
#        'Suspended Looping Coaster-Custom', 'Inverted Coaster – Batman',
#        'Sitting Coaster – Custom', 'Looping roller coaster',
#        'Custom design', 'Stand-Up Coaster', 'Xtreme Spinning Coaster',
#        'Indoor Freeform', 'Enigma', 'Multi Dimension Coaster',
#        'Mine train', 'Jet Star', 'Figure eight', 'Bobsled Coaster',
#        'Free Fly', 'e-Motion Coaster', 'Ultra Twister', 'IBox Track',
#        'Gerstlauer Euro-Fighter 320+', 'Suspended Swinging Coaster',
#        'Illusion', 'Family Launched Coaster Elevated Seating Coaster',
#        'Bobsled Coaster (Custom)', 'Corkscrew', 'Stand-Up',
#        'Family Launch Coaster', 'Tower Launch Coaster',
#        'Twister Coaster 420STD', 'Compact Wild Mouse', 'Wild Mouse',
#        "Children's coaster", 'Topper Track - Custom', 'Sit Down',
#        '4D Interactive Dark Ride', 'Raptor – Prototype',
#        'Junior Coaster (335m)', 'SkyLoop XT-150', 'LSM Launch'],
#       dtype=object)

# %%
df_deduped['height_clean'] = df_deduped['height_clean'].astype(float)

# %%
df_deduped['inversions'] = df_deduped['inversions'].astype(float)

# %%
df_deduped['lift_launch_system'].unique()
# Out:
# array([nan, 'Chain lift hill', 'LSM', 'Booster Wheel Lift Hill',
#        'Two chain lift hills', 'Chain', 'Chain Lift', 'Powered',
#        '1 chain lift hill', 'Chain lift', 'LSM launch', 'Chain Lift Hill',
#        'Linear induction motor (LIM)[1]', 'Tire lift hill',
#        'Two Chain lift hills', 'Elevator liftWheel lift', 'Chain-lift',
#        'Three chain lift hills', 'Vertical chain lift hill',
#        'Cable lift hill', 'LSM launch circuit coaster', '2 Chain Lifts',
#        'Drive tire', 'LSM Launch', 'Drive tire lift hill', 'Spiral lift',
#        'Vertical chain lift',
#        'Trains are powered, propelling themselves on uphill sections. Trains then freely roll over drops. Tires embedded in the track also move trains through certain sections.',
#        'Tire propelled launch, Chain lift hill',
#        'Tire propelled lift hill', 'Powered coaster',
#        'Hydraulic Launch Track', '3 linear synchronous motor launches',
#        'Hydraulic Launch', 'Linear motor launch',
#        'Linear synchronous motor', '1 Chain lift hill',
#        'Drive tire launch', '2 linear motors', 'chain lift hill',
#        'Chain lift hill[2]', 'Linear synchronous motor Launch',
#        'LSM-launch (x2)', 'Lift hill', 'chain', 'Two Drive Tire Lifts',
#        '2 friction wheel hydraulic launches',
#        'Linear synchronous motor launch', 'Hydraulic launch',
#        'Linear Synchronous Motor', 'Elevator Lift',
#        'Two LSM-launches Launch - 0-70 in 3 seconds', 'Onboard motors',
#        'Tire Propelled Launch', 'Cable-lift', 'Flywheel launch',
#        'Flywheel Launch', '2 Tire propelled launches',
#        'Booster Wheel Lift hill', 'Two Tire propelled launches',
#        'Friction Wheels', 'LIM Launch', 'Spiral Lift',
#        'Cable (two lifts)', 'Vertical Elevator Lift',
#        'Cable and Chain lift hill on both towers', 'Cable',
#        '3 friction wheel-powered lift hills',
#        'Electric Winch Launch / Booster wheels (second lift)',
#        'vertical Chain lift', 'Hydraulic launch track',
#        'One lift hill with two chains', 'LIM Launch Track', 'Cable lift',
#        'Linear motor launch, chain lift hill', 'LSM Launch Track',
#        '2 Chain lift hills', 'Propelled by a spinning propulsion system',
#        'LIM launch', 'Vertical Chain Lift Hill', 'Two LSM launches',
#        '2 chain lift systems, 2nd is vertical.', 'Vertical Chain lift',
#        '1 chain lift hill and 1 drive tire lift hill[1]',
#        '2 LSM Launches', 'tyre-driven lift-hill', 'friction drive',
#        'Hydraulic catch car launch', 'Chainlift'], dtype=object)

# %% [markdown]
# Cleaning the cost column by removing unneccessary values in the data

# %%
df_deduped['cost'] = df_deduped['cost'].str.replace("\xa0", "").replace("[1]", "").replace("[2]", "").replace("[3]", "").str.strip()

# %%
df_deduped['cost'].unique()
# Out:
# array([nan, 'A$12 million', '€11,000,000', '£2,100,000', '$5,000,000',
#        '$4,000,000', 'US$10.5 million', '$20 million', '€8,000,000',
#        '$10 million', 'US$7,000,000', '$5,000,000[1]', '$10,000,000',
#        'US$20 million', '$2.3 million', '€25 million', '£2,500,000',
#        '100 million SEK (=approx. $12,6 million)', 'US$24,000,000',
#        '€ 18 million[2]', '$9,500,000[2]', 'C$26 million est.',
#        '$25 million', '£25,000 (1922)', 'USD15,000,000', '$2.25 million',
#        '$200,000', '$3.044 million', 'US$6,000,000', 'US$60 million',
#        '$22 million', '$2,000,000', '£13,500,000', '2.5 Million',
#        '$175,000', '$26,000,000', '$1,750,000 USD', 'US$10 million',
#        '$7,000,000', 'AU$30 million($30million in 2018 dollars[1])',
#        '$9,000,000', '€4,000,000', '€ 20 million', 'CA$9 million[1]',
#        '$7,000,000[1]', '75 million DKK (€10 M)',
#        '3,500,000,000 Yen ($31,601,283 USD)', '€2,187,000',
#        '$3,000,000 USD', 'US$100,000,000', 'US$12,100,000',
#        '$15,000,000[1]', '€15,000,000 ($USD19.9million)',
#        '£1 million Rebuild', '$40,000,000', 'US$6 million', '€15,000,000',
#        '$30,000,000', '€13,000,000', '£12 million', '$30 million',
#        '$3,400,000', '$50,000', '€5,000,000', '$1,200,000 USD',
#        '$10,000,000[1]', '$18,700,000', '$20,000,000', 'US$13,000,000',
#        '$15,600,000 USD', 'USD $300 million[2]', '¥2,800,000,000',
#        'approx. 239,000,000 SEK', '$4,000,000 USD', '$50 million[1]',
#        'US$ 45,000,000[2]', '$13,000,000 USD', '£16,250,000',
#        'US$ 23,000,000', '$25 million[1][2]', 'US$10 million[1]',
#        '$50,000 USD', '$500,000', '£28 million', '$2,100,000',
#        '2.5 billion yen', '€7,000,000', '$4,600,000',
#        'About 3 million euros.', '€25,000,000[1]', '€12,000,000',
#        '£6,000,000', 'USD 7,850,000', '$14,000,000[1]', '12 Million Euro',
#        'US$28,000,000', '$12,500,000[1]', 'US$ 8,000,000',
#        '$50,000,000[1]', 'US$21,000,000', '$15,000,000',
#        '$15,000,000 USD', '$7,500,000', 'A$10,000,000[1]', '$1.2M est.',
#        'US$25,000,000', '£15,000,000', '$6,000,000',
#        '450 million SEK (= approx. €44.3million)[1]', 'US$20,000,000',
#        '$3.4million', '£4 million', '$17.5 million', '€6,000,000',
#        '£10 million', '£8 million', '$6 Million USA', '€22,000,000',
#        '$30 Million', '$35,000,000 DKK (2012)[1]', 'US$2,000,000[1]',
#        'US$10 million($11.1million in 2020 dollars[1])',
#        'About $14 million for the ride and about $9.5 million for the Egyptian themed area',
#        'US$14,000,000', '$4.6 million', '$1,500,000', '$8 million',
#        '€8,500,000', '€ 9,4 million', '€16,000,000', '$75,000',
#        '$25,000,000[1]', '¥8 billion', '$4,300,000',
#        '$11,500,000 - $12,000,000', '$6 million', '$6,500,000 USD',
#        '£1,000,000', '£8,000,000', 'VND 25 billions', 'VND 20 billions',
#        'VND 30 billions', '$1.2 Million', 'US$12,000,000', '$1,000,000',
#        'GB£300,000 (equivalent to £850,047 in 2019)', '£13.5 million',
#        'A$13,000,000[1]', 'US$2.5 million – US$3 million',
#        '$3,000,000 (1976)', '$1,500,000 USD', '$13.5 million',
#        '$4,500,000', 'US$16,000,000', '$5 million[1]', '$3 million',
#        '€7.5 million', '£3,000,000', 'USD 3,000,000', '£3,500,000',
#        '$2,500,000', '£12 Million', '$4 million', '$52,000,000 USD',
#        'US$10,000,000', '$8,500,000 USD', '£813,000', 'AU$20 million',
#        '$12,500,000', 'A$16,000,000', 'Approx: $12,000,000',
#        '$6,000,000 USD[2]',
#        '$8,000,000 USD($12.4million in 2020 dollars[1])', '$3.2 million',
#        'JPY$10,000,000,000', '$5,500,000 USD', '$21,000,000',
#        '$10 million[1]', 'US$3,000,000', '$9 million', '~ 26.000.000 €',
#        '$1,200,000', 'US$2,000,000', '$2.8 million', '$14 million',
#        '€17,500,000[1]', '£18,000,000', 'US$6.5 Million',
#        '£15,000,000[1]', '$37,000,000', '$2.7M est.', 'US$9 million',
#        '$7 million', '€7,800,000', '€3,000,000',
#        '$26 million($26.8million in 2020 dollars[1])', 'SEK35 million[1]',
#        '€6,500,000[2]', 'US$ 3,000,000', '€5 million', '$6.5 million',
#        '$8,000,000 USD', '€ 12 million', '$5.5 million[1]',
#        '48 million FIM (1951);[1]1.62 million EUR (in 2021 euros, inflation-adjusted)[2]',
#        '€7,500,000', '$18,000,000', '$3.5 million', '£16,000,000',
#        '$20,000,000($22.5million in 2020 dollars[1])', '$9,500,000 USD',
#        'US$5,000,000', '1.2M',
#        '110 million SEK ($11,990,000 USD as of August 2018)',
#        'US$14 million', '€ 10,000,000', '90,000,000 RMB', 'US$4 million',
#        '$12–15 million[1]',
#        '$45,000,000 USD to build (2002)$10,000,000 USD to renovate (2008)[1]',
#        '$13,000,000'], dtype=object)

# %%
df_deduped['park_section'] = df_deduped['park_section'].str.replace("\xa0", "").str.strip()

# %%
df_deduped['park_section'] = df_deduped['park_section'].astype(str)

# %%
df_deduped['park_section'].unique()
# Out:
# array(['nan', 'Aqualantis', 'Aerial Park', 'South End', 'Oktoberfest',
#        'Crossroads', 'Austria', 'Rhinefeld', 'County Fair',
#        "1904 World's Fair", 'Jungle X-Pedition', 'The Underground',
#        'Festa Italia', 'Candy Apple Grove',
#        'ARTHUR - In the Minimoys Kingdom', 'Nickland', 'The Old West',
#        'Action Zone', 'DC Super Heroes World', 'Gotham City',
#        'Sci-Fi City', 'Frontier Adventures', 'Deep in Africa', 'Iceland',
#        'Nickelodeon Land', 'Main Midway', 'Energy', 'Kiddie Land',
#        'Africa', 'Pixar Pier', 'Chocolatetown', 'North Midway',
#        'The Lost World', '2nd Level', 'Bugs Bunny World',
#        'Carolina Boardwalk', 'DC Universe', 'Frontier Town',
#        'Crown Colony Plaza', 'The Boardwalk', 'Egypt', 'Mexico',
#        'Land der Vergessenen', 'Screampunk District', 'Lost City',
#        'South Midway', 'The Hollow', 'Exotic', 'Blue Ridge Junction',
#        'Gemini Midway', 'Planet Snoopy', 'Wuze Town',
#        'Worlds of Pixar, Toon Studio', 'North End', 'Peachtree Square',
#        'USA Section', 'Canada', 'RuigRijk', 'Asiana', 'Rivertown',
#        'Medieval Faire', 'Dragon Island', 'Land of the Dragons',
#        'Wildwood Grove', 'Far Far Away',
#        'DreamWorks Experience- Madagascar Madness', 'Russia', 'France',
#        'Asia', 'Berlin- Rookburgh', 'Pioneer Frontier', 'Southeast',
#        'Camp Snoopy', "Hugo's Hill Street", 'Wilderness Pass',
#        'Orleans Place', 'Grande World Exposition of 1890',
#        'Transsilvanien', 'Extreme Zone', 'Six Flags Plaza',
#        'Mediterrània', 'Thrill Zone', 'Avalon', 'Forbidden Valley',
#        'Lakeside Midway', 'Ghost Town', 'The Movie District',
#        'Celebration Plaza', 'Shangri-La', 'Goliath Plaza', 'Speed Zone',
#        'Paradise Gardens Park', 'Looney Tunes Movie Town',
#        'Aquitaine (France)', 'Old Virginia',
#        "Sesame Street's Forest of Fun",
#        'The Wizarding World of Harry Potter- Hogsmeade', 'Lakefront',
#        'The Wizarding World of Harry Potter- Diagon Alley', 'Hell Cat',
#        'Hollywood', 'Production Central', "Rowdy's Ridge",
#        'Adventureland', 'New France', 'Millennium Midway',
#        'Crackaxle Canyon', 'Fiesta Village', 'Ruigrijk', 'Sea of Legends',
#        'Goodtimes Square', 'Lost Maya', 'The Golden Kingdom',
#        'Exotic World', 'The Swiss Village', 'Lost Kingdom Reserve',
#        'Congo', 'Midway America', 'Jukebox Junction',
#        'Looney Tunes Seaport', 'Transilvania', 'Scotland', 'Zero Zone',
#        'Sea of Mystery', 'Sea of Shallows', 'Fantasyland', 'Anderrijk',
#        'Carousel Plaza', 'Sky', 'Pueblo Vaquero', 'Main Street',
#        'Frontier Canada', 'Tyrolen', 'Timber Canyon', 'Festival City',
#        'The Jungle', 'Texas', 'Samurai Summit', 'Americana',
#        'Adventure Seaport', 'X-Sector', 'Space Section', 'CBeebies Land',
#        'Area 72', 'Outlaw Gulch', "The Great Barn at Wilson's Farm",
#        'Geopolis', 'Amazing Amazon', 'Hometown Square', 'Lost Kennywood',
#        'Rockville', 'Ghost Town- Wild Water Wilderness',
#        'La Grèce Antique', 'Southwest Territory', 'Lost River Delta',
#        'Klugheim', 'Mexicana', 'Dark Forest', 'Gateway to the West',
#        'B Area', 'Đại Cung Lạc Cảnh Hồ', "Mariner's Landing Pier",
#        'Katanga Canyon', 'Boomtown', 'Surfside Pier', 'Old Town',
#        'Pantopia', 'Illinois', 'China', 'Stanleyville', 'Tower',
#        'Action Park', 'KidZville', 'Universe of Starship',
#        'Toy Story Land', 'Tomorrowland', 'Discoveryland', 'Spaceport',
#        'W.A.B Plaza', 'The Towers', 'Orient',
#        'Yukon Territory- Camp Cartoon', 'Amity', 'Ghosttown',
#        'Steelers Country', 'Tornado Springs', 'Kidzopolis',
#        'Rollercoaster Alley', 'Pueblo Mexicano', 'Spassburg',
#        'European Adventure', "Craftsmen's Valley",
#        'Fantasyland- Storybook Circus', 'Britannia', 'Fest Area',
#        'Adventure Pier', "Fourth of July- Holidog's FunTown",
#        'Marvel Super Hero Island', 'DC Super Friends', 'Halloween',
#        'Baja Ridge', 'Coney Mall', 'Metropolis', 'Swarm Island',
#        'Thanksgiving', 'The Dock Yard', 'LaQua', 'International Festival',
#        'Valley Road', 'Cartoon Village', 'Land of Legends', 'Wilderness',
#        'Wild Woods', 'Streets of New York', 'Jurassic Park', 'Reizenrijk',
#        'Carousel Park', 'Mutiny Bay', 'Timbertown',
#        'International Festival- Wonder Mountain',
#        "Woody Woodpecker's KidZone", 'Hollywood The Main Street',
#        'Dragon Zone'], dtype=object)

# %%
df_deduped['duration_clean'] = df_deduped.duration_clean.astype(float)

# %%
df_deduped.duration_clean.unique()
# Out:
# array([ 92., 120.,  nan, 180., 140., 167., 100., 190., 143., 130., 110.,
#        135., 240.,  82.,  90.,  44., 128., 138., 160.,  75.,  96., 122.,
#        148.,  60., 105., 102., 108.,  68., 150., 156., 146.,  52., 137.,
#        170., 175., 145., 220.,  84., 144.,  51.,  55., 115., 171., 223.,
#        116., 210.,  83., 106.,  73.,  45.,  66., 273., 200., 118.,  85.,
#         42., 195., 139.,  88., 112.,  27.,  63., 216.,  77.,  80.,  67.,
#         65., 300., 151.,  99., 155., 161., 213.,  32., 356., 172., 154.,
#        142.,  70.,  28., 119., 174., 104., 208., 192.,  40.,  78., 153.,
#        165., 127.,  23.,  36.,  50., 103., 205.,  87., 134., 117.,  95.,
#        101., 113.,  98., 136.,  25.,  58., 253.,  30.,  76., 126., 450.,
#        275.,  69.,  37.,  43., 184., 250., 125.,  56.,  79., 217., 114.,
#         93.,  38., 133.,  64.,  94., 124.,  62.])

# %% [markdown]
# Cleaning the capacity_rider_per_hour the same way we had done before for other columns

# %%
df_deduped['capacity_rider_per_hr'] = df_deduped.capacity.str.replace(" riders per hour", "") \
                                        .str.replace(",", "") \
                                        .str.replace("[1]", "") \
                                        .str.replace("[2]", "") \
                                        .str.replace("[3]", "") \
                                        .str.replace("max.", "") \
                                        .str.replace("~", "") \
                                        .str.strip()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17020\3614371917.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_deduped['capacity_rider_per_hr'] = df_deduped.capacity.str.replace(" riders per hour", "") \

# %%
df_deduped['capacity_rider_per_hr'].unique()
# Out:
# array(['00', nan, '000', '750', '600', '80', '800', '850', '400', '960',
#        '780', '60', '650', '040', '545', '50', '500', '450 []', '760',
#        '70', '950', '900', '440', '550', '050', '480-70', '0', '060',
#        '008', '65', '758', '470', '700', '560', '45', '480', '640', '080',
#        '5', '000[]', '746[]', '450', '44', '890', '670', '50[]', '4',
#        '06', '680', '8', '596[]', '75', '90',
#        '057 ( rockets) 74 (0 rockets) 440 (9 rockets)', '845', '460',
#        '860', '400[]', '40', '975', 'cars - 8 riders each - 70',
#        '700-800', '660', '905', '848', '886', '95', '85', '600[]', '9'],
#       dtype=object)

# %%
df_deduped.loc[df_deduped['capacity_rider_per_hr'] == "480-720", "capacity_rider_per_hr"] = "600"

# %%
df_deduped.loc[df_deduped['capacity_rider_per_hr'] == "2057 (11 rockets) 1741 (10 rockets) 1440 (9 rockets)", "capacity_rider_per_hr"] = "2057"

# %%
df_deduped.loc[df_deduped['capacity_rider_per_hr'] == "3 cars - 8 riders each - 720", "capacity_rider_per_hr"] = "720"

# %%
df_deduped.loc[df_deduped['capacity_rider_per_hr'] == "700-800", "capacity_rider_per_hr"] = "750"

# %%
import pandas as pd

# Assuming df_deduped is your DataFrame

# Step 1: Clean the data
df_deduped['capacity_rider_per_hr'] = df_deduped['capacity_rider_per_hr'].str.replace('[]', '', regex=False)

# Step 2: Convert to numeric, forcing errors to NaN
df_deduped['capacity_rider_per_hr'] = pd.to_numeric(df_deduped['capacity_rider_per_hr'], errors='coerce')

# Now you can work with the column as float

# %%
df_deduped['g_force'].unique()
# Out:
# array([nan, '4.5', '3', '3.8', '3.7', '4.3', '5.1', '4.1', '2.2', '4.9',
#        '4', '4G', '3.5', '2.5', '4.2', '1', '2.4', '5.2',
#        '-1,5g and 4,5g', '4.9 (Back Seat)4.0 (Front Seat)',
#        '4.5 G (Positive)', '3.75', '4.7', '0.2-2', '1.2', '4.4', '5',
#        '2.9', '4.3 g', '3.6', '3.0', '3.2', '1.5', '2.1', '4.8[2]', '4.0',
#        '3.26 G', '4[1]', '3.1', '3.4', '3.9', '4.18[4]', '4.8', '2.6',
#        '3.5[2]', '3.7 [2]', 'Between 3 and 4 Gs', '2.75', '3.2[2]', '2.0',
#        '3.8 g', '5.9', '2.3', '0.8', '3.3', '3 Gs[2]', '4.2 & -1', '4.6',
#        '4.8[1]', '2.4[2]', '4 g', '3.5 g', '4Gs'], dtype=object)

# %% [markdown]
# Cleaning g_force column of the DataFrame

# %%
df_deduped['g_force_clean'] = df_deduped['g_force'] \
            .str.replace("[1]","") \
            .str.replace("[2]","") \
            .str.replace("[3]","") \
            .str.replace("[4]","") \
            .str.replace("Gs","") \
            .str.replace("g","")  \
            .str.replace("G","")  \
            .str.strip()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17020\1679334538.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_deduped['g_force_clean'] = df_deduped['g_force'] \

# %% [markdown]
# ## Cleaning ambiguous values in g_force_clean by using average or maximum values logically

# %%
df_deduped.loc[df_deduped['g_force_clean'] == '4.9 (Back Seat)4.0 (Front Seat)', 'g_force_clean'] = "4.5"
df_deduped.loc[df_deduped['g_force_clean'] == '4.5  (Positive)', 'g_force_clean'] = "4.5"
df_deduped.loc[df_deduped['g_force_clean'] == 'Between 3 and 4', 'g_force_clean'] = "3.5"
df_deduped.loc[df_deduped['g_force_clean'] == '-1,5 and 4,5', 'g_force_clean'] = "4.5"
df_deduped.loc[df_deduped['g_force_clean'] == '0.2-2', 'g_force_clean'] = "2"
df_deduped.loc[df_deduped['g_force_clean'] == '4.2 & -1', 'g_force_clean'] = "4"

# Step 1: Replace empty strings with NaN
df_deduped['g_force_clean'].replace('', pd.NA, inplace=True)

# Step 2: Convert to numeric, forcing errors to NaN
df_deduped['g_force_clean'] = pd.to_numeric(df_deduped['g_force_clean'], errors='coerce')

# Now you can check the result
print(df_deduped['g_force_clean'])
# Out:
# 696     NaN
# 886     0.5
# 1057    0.5
# 828     NaN
# 936     NaN
#        ...
# 364     NaN
# 1046    NaN
# 433     NaN
# 56      NaN
# 434     5.0
# Name: g_force_clean, Length: 646, dtype: float64

# %%
df_deduped['designer'].unique()
# Out:
# array(['Werner Stengel', nan, 'Benjamin Bloemendaal', 'Meticulous ltd',
#        'Ing.-Büro Stengel GmbH',
#        'Curtis D. SummersJames FigleyLeonard Wright', 'Ron Toomer',
#        'Jeff Pike', 'Don Rosser / Bill Cobb',
#        'Ingenieurbüro Stengel GmbH', 'Vekoma', 'TOGO', 'John A. Miller',
#        'John C. Allen', 'Charlie Paige', 'Frank F. HooverJohn C. Allen',
#        'The Gravity Group, LLC', 'Art Engineering[1]',
#        'Dennis McNultyLarry Bill', 'Walt Disney Imagineering',
#        'Dal Freeman (Lagoon)', 'Chance Rides', 'Zierer', 'Ride Tek',
#        'Alan Schilke', 'Ingenieur Büro Stengel GmbH',
#        'Herbert Paul Schmeck', 'Vernon Keenan', 'Edward A. Vettel',
#        'Dennis McNulty, Larry Bill', 'The Gravity Group',
#        'Karel Willemen', 'Frederick Church', 'HUSS Park Attractions',
#        'John Wardley (layout) Ing.-Büro Stengel GmbH (mechanical role)',
#        'Franz Mack', 'Reverchon Industries', 'Jack Rouse Associates',
#        'Herschend Enterprises', 'Peter Clerx', 'Blauer Enzian',
#        'John Fetterman', 'Morgan', 'John Wardley', 'Curtis D. Summers',
#        'Frank Prior, Frederick Church', 'Frank Prior, Fredrick Church',
#        'Don Rosser, John C. Allen, William Cobb', 'Universal Creative',
#        'National Amusement Devices', 'Dennis McNulty Larry Bill',
#        'Mack Rides GmbH & Co. KG', 'Jeff PikeSkyline Design, LLC',
#        'Sea World', 'RCS GmbH', 'Don Rosser and Bill Cobb', 'Imaginvest',
#        'William Cobb & Associates', 'Edward Joy Morris',
#        'Werner Stengel[3]', 'Werner Stengel, Anton Schwarzkopf',
#        'The Allan Herschell Company', 'Steve Okamoto', 'WED Enterprises',
#        'Robert-Jaap JansenKarel Willemen', 'Joe Draves',
#        'John Wardley, Dennis McNulty, Larry Bill', 'Erich Heidrich',
#        'Skyline Design', 'John Wardley & Werner Stengel & Jordan Forster',
#        'Charles Paige', 'Arrow Dynamics',
#        'Anton Schwarzkopf, Werner Stengel', 'Herbert Paul Schmeck, 1947',
#        'Andy Vettel (1968)John A. Miller (1924)', 'Jora Vision',
#        'Walt Disney ImagineeringSansei Technologies',
#        'Larry Bill, Dennis McNulty', 'F.lli Pinfari S.r.l',
#        'Warner Bros. Movie World', 'Werner Stengel Mark Golding',
#        'Walt Disney ImagineeringWerner Stengel', 'Stengel Engineering',
#        'Dennis McNulty, Larry Bill, John Wardley', 'John Allen',
#        'Dustin Sloane, Skyline Attractions', 'Al CollinsJeff Gramke',
#        'Dennis McNulty',
#        'Custom Coasters, Inc., Larry Bill, Dennis McNulty',
#        'Mike Graham, Korey Kiepert, Larry Bill, Chad Miller, Will Koch',
#        'Curtis D. SummersJohn Fetterman',
#        'Harry C. Baker, Harry G Traver', 'Mike Boodley', 'Gary Norton',
#        'William Cobb', 'Alison Brittle, Eden Carpenter, and Gary Norton',
#        'John Fetterman, 1999; from John Allen\'s 1964 "Mister Twister" design',
#        'John Pierce', 'Werner Stengel, Wendelin Stückl', 'Six Flags',
#        'Ron Toomer[1]', 'Ton van de Ven', 'Valdemar Lebech[3]',
#        'SeaWorld Parks & Entertainment', 'Maurer Söhne',
#        'Skyline Design LLC', 'Corbin Stengal', 'Clair HainMike Boodley',
#        'Herbert Paul Schmeck and Dinn Corporation', 'Triotech',
#        'Alan SchilkeRenato Manzoni'], dtype=object)

# %% [markdown]
# Cleaning the designer column

# %%
df_deduped['designer_clean'] = df_deduped['designer'] \
    .str.replace("[1]", "") \
    .str.replace("[2]", "") \
    .str.replace("[3]", "") \
    .str.replace(r"\(?\d+\)?", "", regex=True) \
    .str.strip()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17020\184381698.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_deduped['designer_clean'] = df_deduped['designer'] \

# %%
df_deduped['designer_clean'].unique()
# Out:
# array(['Werner Stengel', nan, 'Benjamin Bloemendaal', 'Meticulous ltd',
#        'Ing.-Büro Stengel GmbH',
#        'Curtis D. SummersJames FigleyLeonard Wright', 'Ron Toomer',
#        'Jeff Pike', 'Don Rosser / Bill Cobb',
#        'Ingenieurbüro Stengel GmbH', 'Vekoma', 'TOGO', 'John A. Miller',
#        'John C. Allen', 'Charlie Paige', 'Frank F. HooverJohn C. Allen',
#        'The Gravity Group, LLC', 'Art Engineering[]',
#        'Dennis McNultyLarry Bill', 'Walt Disney Imagineering',
#        'Dal Freeman (Lagoon)', 'Chance Rides', 'Zierer', 'Ride Tek',
#        'Alan Schilke', 'Ingenieur Büro Stengel GmbH',
#        'Herbert Paul Schmeck', 'Vernon Keenan', 'Edward A. Vettel',
#        'Dennis McNulty, Larry Bill', 'The Gravity Group',
#        'Karel Willemen', 'Frederick Church', 'HUSS Park Attractions',
#        'John Wardley (layout) Ing.-Büro Stengel GmbH (mechanical role)',
#        'Franz Mack', 'Reverchon Industries', 'Jack Rouse Associates',
#        'Herschend Enterprises', 'Peter Clerx', 'Blauer Enzian',
#        'John Fetterman', 'Morgan', 'John Wardley', 'Curtis D. Summers',
#        'Frank Prior, Frederick Church', 'Frank Prior, Fredrick Church',
#        'Don Rosser, John C. Allen, William Cobb', 'Universal Creative',
#        'National Amusement Devices', 'Dennis McNulty Larry Bill',
#        'Mack Rides GmbH & Co. KG', 'Jeff PikeSkyline Design, LLC',
#        'Sea World', 'RCS GmbH', 'Don Rosser and Bill Cobb', 'Imaginvest',
#        'William Cobb & Associates', 'Edward Joy Morris',
#        'Werner Stengel[]', 'Werner Stengel, Anton Schwarzkopf',
#        'The Allan Herschell Company', 'Steve Okamoto', 'WED Enterprises',
#        'Robert-Jaap JansenKarel Willemen', 'Joe Draves',
#        'John Wardley, Dennis McNulty, Larry Bill', 'Erich Heidrich',
#        'Skyline Design', 'John Wardley & Werner Stengel & Jordan Forster',
#        'Charles Paige', 'Arrow Dynamics',
#        'Anton Schwarzkopf, Werner Stengel', 'Herbert Paul Schmeck,',
#        'Andy Vettel John A. Miller', 'Jora Vision',
#        'Walt Disney ImagineeringSansei Technologies',
#        'Larry Bill, Dennis McNulty', 'F.lli Pinfari S.r.l',
#        'Warner Bros. Movie World', 'Werner Stengel Mark Golding',
#        'Walt Disney ImagineeringWerner Stengel', 'Stengel Engineering',
#        'Dennis McNulty, Larry Bill, John Wardley', 'John Allen',
#        'Dustin Sloane, Skyline Attractions', 'Al CollinsJeff Gramke',
#        'Dennis McNulty',
#        'Custom Coasters, Inc., Larry Bill, Dennis McNulty',
#        'Mike Graham, Korey Kiepert, Larry Bill, Chad Miller, Will Koch',
#        'Curtis D. SummersJohn Fetterman',
#        'Harry C. Baker, Harry G Traver', 'Mike Boodley', 'Gary Norton',
#        'William Cobb', 'Alison Brittle, Eden Carpenter, and Gary Norton',
#        'John Fetterman, ; from John Allen\'s  "Mister Twister" design',
#        'John Pierce', 'Werner Stengel, Wendelin Stückl', 'Six Flags',
#        'Ron Toomer[]', 'Ton van de Ven', 'Valdemar Lebech[]',
#        'SeaWorld Parks & Entertainment', 'Maurer Söhne',
#        'Skyline Design LLC', 'Corbin Stengal', 'Clair HainMike Boodley',
#        'Herbert Paul Schmeck and Dinn Corporation', 'Triotech',
#        'Alan SchilkeRenato Manzoni'], dtype=object)

# %%
df_deduped['max_vertical_angle'].unique()
# Out:
# array([nan, '100°', '97°', '79°', '55°', '65°', '45°', '70°', '87°',
#        '33°', '75°', '46°', '59°', '77.3°', '116°', '53°', '61°', '80°',
#        '60°', '47°', '58.1°', '120°', '50°', '78°', '52°', '95°', '74°',
#        '90°', '87.5°', '89°', '82°', '81°', '51°',
#        '40 degrees at bottom of first drop°', '3°', '85°', '64°',
#        '120.5[4]°', '96°', '62°', '68°', '25°', '42°', '73°', '66°',
#        '54°', '112°', '36°', '85[1]°', '27°', '35°', '29°', '77.4°',
#        '53.3°', '40°', '68.5°', '56°', '111°', '72°', '58°', '77°',
#        '121.5°', '121°', '101°', '57.3°', '113.1°', '83°', '63°', '88.5°'],
#       dtype=object)

# %% [markdown]
# ### We dont want "°" in the max_vetical_angle column as it is understood that these values represent angle so these values can be removed for easy searching later

# %%
# Step 1: Clean the data
df_deduped['max_vertical_angle_clean'] = (
    df_deduped['max_vertical_angle']
    .str.replace("°", "", regex=False)
    .str.replace("[1]", "", regex=False)
    .str.replace("[4]", "", regex=False)
)

# Step 2: Replace specific string cases
df_deduped.loc[df_deduped['max_vertical_angle_clean'] == '40 degrees at bottom of first drop', 'max_vertical_angle_clean'] = "40"

# Step 3: Extract numeric values using regex
df_deduped['max_vertical_angle_clean'] = df_deduped['max_vertical_angle_clean'].str.extract('(\d+)')

# Step 4: Convert to numeric, forcing errors to NaN
df_deduped['max_vertical_angle_clean'] = pd.to_numeric(df_deduped['max_vertical_angle_clean'], errors='coerce')

# Now you can check the result
print(df_deduped['max_vertical_angle_clean'])
# Out:
# 696       NaN
# 886     100.0
# 1057      NaN
# 828       NaN
# 936       NaN
#         ...
# 364      40.0
# 1046     90.0
# 433       NaN
# 56        NaN
# 434       NaN
# Name: max_vertical_angle_clean, Length: 646, dtype: float64

# %%
df_deduped['max_vertical_angle_clean'].unique()
# Out:
# array([ nan, 100.,  97.,  79.,  55.,  65.,  45.,  70.,  87.,  33.,  75.,
#         46.,  59.,  77., 116.,  53.,  61.,  80.,  60.,  47.,  58., 120.,
#         50.,  78.,  52.,  95.,  74.,  90.,  89.,  82.,  81.,  51.,  40.,
#          3.,  85.,  64.,  96.,  62.,  68.,  25.,  42.,  73.,  66.,  54.,
#        112.,  36.,  27.,  35.,  29.,  56., 111.,  72., 121., 101.,  57.,
#        113.,  83.,  63.,  88.])

# %%
df_deduped['drop'].unique()
# Out:
# array([nan, '30.5\xa0m (100\xa0ft)', '70\xa0ft (21\xa0m)',
#        '170\xa0ft (52\xa0m)', '147\xa0ft (44.8\xa0m)',
#        '80\xa0ft (24\xa0m)', '144\xa0ft (44\xa0m)',
#        '87.3\xa0ft (26.6\xa0m)', '210\xa0ft (64\xa0m)',
#        '50\xa0ft (15\xa0m)', '92\xa0ft (28\xa0m)', '24.9\xa0m (82\xa0ft)',
#        '150\xa0ft (46\xa0m)', '37.5\xa0m (123\xa0ft)',
#        '103\xa0ft (31\xa0m)', '69\xa0m (226\xa0ft)',
#        '132\xa0ft (40\xa0m)', '72\xa0ft (22\xa0m)',
#        '98.43\xa0ft (30.00\xa0m)', '115\xa0ft (35\xa0m)',
#        '108\xa0ft (33\xa0m)', '66\xa0ft (20\xa0m)', '6\xa0ft (1.8\xa0m)',
#        '65\xa0ft (20\xa0m)', '34\xa0ft (10\xa0m)', '20\xa0ft (6.1\xa0m)',
#        '130\xa0ft (40\xa0m)', '48.5\xa0m (159\xa0ft)',
#        '128\xa0ft (39\xa0m)', '97\xa0ft (30\xa0m)', '81\xa0ft (25\xa0m)',
#        '78\xa0ft (24\xa0m)', '25\xa0ft (7.6\xa0m)', '30\xa0m (98\xa0ft)',
#        '100\xa0ft (30\xa0m)', '75\xa0ft (23\xa0m)',
#        '59.4\xa0m (195\xa0ft)', '215\xa0ft (66\xa0m)',
#        '179\xa0ft (55\xa0m)', '23\xa0m (75\xa0ft)',
#        '23.2\xa0m (76\xa0ft)', '49.1\xa0m (161\xa0ft)',
#        '20\xa0m (66\xa0ft)', '21.5\xa0m (71\xa0ft)',
#        '135\xa0ft (41\xa0m)', '82\xa0ft (25\xa0m)', '105\xa0ft (32\xa0m)',
#        '168\xa0ft (51\xa0m)', '35\xa0ft (11\xa0m)', '30\xa0ft (9.1\xa0m)',
#        '91\xa0ft (28\xa0m)', '13\xa0ft (4.0\xa0m)', '230\xa0ft (70\xa0m)',
#        '41.9\xa0m (137\xa0ft)', '320\xa0ft (98\xa0m)',
#        '164\xa0ft (50\xa0m)', '118\xa0ft (36.0\xa0m)',
#        '101\xa0ft (31\xa0m)', '12\xa0m (39\xa0ft)', '60\xa0ft (18\xa0m)',
#        '103.3\xa0ft (31.5\xa0m)', '111.8\xa0ft (34.1\xa0m)',
#        '170.6\xa0ft (52.0\xa0m)', '180\xa0ft (55\xa0m)',
#        '255\xa0ft (78\xa0m)', '175\xa0ft (53\xa0m)',
#        '46.31\xa0m (151.9\xa0ft)', '32.9\xa0m (108\xa0ft)',
#        '89\xa0ft (27\xa0m)', '124\xa0ft (38\xa0m)', '205\xa0ft (62\xa0m)',
#        '140\xa0ft (43\xa0m)', '17\xa0ft (5.2\xa0m)', '56\xa0ft (17\xa0m)',
#        '43\xa0m (141\xa0ft)', '98\xa0ft (30\xa0m)', '82\xa0m (269\xa0ft)',
#        '180.5\xa0ft (55.0\xa0m)', '131.25\xa0ft (40.01\xa0m)',
#        '211\xa0ft (64\xa0m)', '300\xa0ft (91.4\xa0m)',
#        '74\xa0ft (23\xa0m)', '171\xa0ft (52\xa0m)', '45\xa0ft (14\xa0m)',
#        '122\xa0ft (37\xa0m)', '24\xa0m (79\xa0ft)', '141\xa0ft (43\xa0m)',
#        '147.8\xa0ft (45.0\xa0m)', '44\xa0ft (13\xa0m)',
#        '418\xa0ft (127\xa0m)', '111.75\xa0ft (34.06\xa0m)',
#        '9\xa0ft (2.7\xa0m)', '93.3\xa0m (306\xa0ft)',
#        '90\xa0ft (27.4\xa0m)', '165\xa0ft (50\xa0m)',
#        '114\xa0ft (35\xa0m)', '194.7\xa0ft (59.3\xa0m)',
#        '200\xa0ft (61\xa0m)', '113\xa0ft (34\xa0m)', '54\xa0ft (16\xa0m)',
#        '172\xa0ft (52\xa0m)', '26.5\xa0m (87\xa0ft)',
#        '300\xa0ft (91\xa0m)', '110\xa0ft (34\xa0m)',
#        '80.5\xa0ft (24.5\xa0m)', '137\xa0ft (42\xa0m)',
#        '42.4\xa0m (139\xa0ft)', '31.7\xa0m (104\xa0ft)',
#        '28\xa0m (92\xa0ft)', '147\xa0ft (45\xa0m)',
#        '85[1]\xa0ft (26\xa0m)', '54.8\xa0m (180\xa0ft)',
#        '9.8\xa0ft (3.0\xa0m)', '99\xa0ft (30\xa0m)',
#        '162\xa0ft (49\xa0m)', '114.8\xa0ft (35.0\xa0m)',
#        '123\xa0ft (37\xa0m)', '40\xa0ft (12\xa0m)', '228\xa0ft (69\xa0m)',
#        '90\xa0ft (27\xa0m)', '85.9\xa0ft (26.2\xa0m)',
#        '22\xa0m (72\xa0ft)', '81\xa0ft (24.7\xa0m)',
#        '208\xa0ft (63\xa0m)', '102\xa0ft (31\xa0m)',
#        '119\xa0ft (36\xa0m)', '120\xa0ft (37\xa0m)',
#        '91.4\xa0ft (27.9\xa0m)', '47\xa0ft (14\xa0m)',
#        '41\xa0ft (12\xa0m)', '67\xa0ft (20\xa0m)', '38\xa0ft (12\xa0m)',
#        '51\xa0ft (16\xa0m)', '36\xa0ft (11\xa0m)', '10\xa0m (33\xa0ft)',
#        '116.5\xa0ft (35.5\xa0m)', '78\xa0m (256\xa0ft)',
#        '39\xa0ft (12\xa0m)', '109\xa0ft (33\xa0m)', '67\xa0m (220\xa0ft)',
#        '37\xa0ft (11\xa0m)', '104.3\xa0ft (31.8\xa0m)',
#        '212\xa0ft (65\xa0m)', '26\xa0ft (7.9\xa0m)',
#        '18.0\xa0ft (5.5\xa0m)', '205[1]\xa0ft (62\xa0m)',
#        '93.5\xa0m (307\xa0ft)', '40\xa0m (130\xa0ft)',
#        '221\xa0ft (67\xa0m)', '328.1\xa0ft (100.0\xa0m)',
#        '163\xa0ft (50\xa0m)', '25\xa0m (82\xa0ft)',
#        '45.99\xa0m (150.9\xa0ft)', '138\xa0ft (42\xa0m)',
#        '42\xa0m (138\xa0ft)', '111\xa0ft (34\xa0m)', '87\xa0ft (27\xa0m)',
#        '31\xa0m (102\xa0ft)', '95\xa0ft (29\xa0m)',
#        '81.2\xa0ft (24.7\xa0m)', '88\xa0ft (27\xa0m)',
#        '104.9\xa0ft (32.0\xa0m)', '83\xa0ft (25\xa0m)',
#        '82.17\xa0ft (25.0\xa0m)', '85\xa0ft (26\xa0m)',
#        '146\xa0ft (45\xa0m)', '98.4\xa0ft (30.0\xa0m)',
#        '154\xa0ft (47\xa0m)', '32\xa0ft (9.8\xa0m)',
#        '66\xa0m (217\xa0ft)', '112\xa0ft (34\xa0m)',
#        '32\xa0m (105\xa0ft)', '30.7\xa0m (101\xa0ft)',
#        '89.6\xa0ft (27.3\xa0m)', '116.1 ft', '214\xa0ft (65\xa0m)',
#        '62\xa0ft (19\xa0m)', '26\xa0m (85\xa0ft)',
#        '67.2\xa0ft (20.5\xa0m)', '72.2\xa0ft (22.0\xa0m)',
#        '196\xa0ft (60\xa0m)', '85.2\xa0ft (26.0\xa0m)',
#        '23.8\xa0m (78\xa0ft)', '49\xa0m (161\xa0ft)',
#        '155\xa0ft (47\xa0m)', '131\xa0ft (40\xa0m)',
#        '104\xa0ft (32\xa0m)', '8\xa0ft (2.4\xa0m)',
#        '19.4\xa0m (64\xa0ft)', '74.7\xa0m (245\xa0ft)',
#        '58\xa0ft (18\xa0m)'], dtype=object)

# %% [markdown]
# Cleaning the "\xa" values from the drop column

# %%
df_deduped['drop'].str.replace("\xa0", "").unique()
# Out:
# array([nan, '30.5m (100ft)', '70ft (21m)', '170ft (52m)', '147ft (44.8m)',
#        '80ft (24m)', '144ft (44m)', '87.3ft (26.6m)', '210ft (64m)',
#        '50ft (15m)', '92ft (28m)', '24.9m (82ft)', '150ft (46m)',
#        '37.5m (123ft)', '103ft (31m)', '69m (226ft)', '132ft (40m)',
#        '72ft (22m)', '98.43ft (30.00m)', '115ft (35m)', '108ft (33m)',
#        '66ft (20m)', '6ft (1.8m)', '65ft (20m)', '34ft (10m)',
#        '20ft (6.1m)', '130ft (40m)', '48.5m (159ft)', '128ft (39m)',
#        '97ft (30m)', '81ft (25m)', '78ft (24m)', '25ft (7.6m)',
#        '30m (98ft)', '100ft (30m)', '75ft (23m)', '59.4m (195ft)',
#        '215ft (66m)', '179ft (55m)', '23m (75ft)', '23.2m (76ft)',
#        '49.1m (161ft)', '20m (66ft)', '21.5m (71ft)', '135ft (41m)',
#        '82ft (25m)', '105ft (32m)', '168ft (51m)', '35ft (11m)',
#        '30ft (9.1m)', '91ft (28m)', '13ft (4.0m)', '230ft (70m)',
#        '41.9m (137ft)', '320ft (98m)', '164ft (50m)', '118ft (36.0m)',
#        '101ft (31m)', '12m (39ft)', '60ft (18m)', '103.3ft (31.5m)',
#        '111.8ft (34.1m)', '170.6ft (52.0m)', '180ft (55m)', '255ft (78m)',
#        '175ft (53m)', '46.31m (151.9ft)', '32.9m (108ft)', '89ft (27m)',
#        '124ft (38m)', '205ft (62m)', '140ft (43m)', '17ft (5.2m)',
#        '56ft (17m)', '43m (141ft)', '98ft (30m)', '82m (269ft)',
#        '180.5ft (55.0m)', '131.25ft (40.01m)', '211ft (64m)',
#        '300ft (91.4m)', '74ft (23m)', '171ft (52m)', '45ft (14m)',
#        '122ft (37m)', '24m (79ft)', '141ft (43m)', '147.8ft (45.0m)',
#        '44ft (13m)', '418ft (127m)', '111.75ft (34.06m)', '9ft (2.7m)',
#        '93.3m (306ft)', '90ft (27.4m)', '165ft (50m)', '114ft (35m)',
#        '194.7ft (59.3m)', '200ft (61m)', '113ft (34m)', '54ft (16m)',
#        '172ft (52m)', '26.5m (87ft)', '300ft (91m)', '110ft (34m)',
#        '80.5ft (24.5m)', '137ft (42m)', '42.4m (139ft)', '31.7m (104ft)',
#        '28m (92ft)', '147ft (45m)', '85[1]ft (26m)', '54.8m (180ft)',
#        '9.8ft (3.0m)', '99ft (30m)', '162ft (49m)', '114.8ft (35.0m)',
#        '123ft (37m)', '40ft (12m)', '228ft (69m)', '90ft (27m)',
#        '85.9ft (26.2m)', '22m (72ft)', '81ft (24.7m)', '208ft (63m)',
#        '102ft (31m)', '119ft (36m)', '120ft (37m)', '91.4ft (27.9m)',
#        '47ft (14m)', '41ft (12m)', '67ft (20m)', '38ft (12m)',
#        '51ft (16m)', '36ft (11m)', '10m (33ft)', '116.5ft (35.5m)',
#        '78m (256ft)', '39ft (12m)', '109ft (33m)', '67m (220ft)',
#        '37ft (11m)', '104.3ft (31.8m)', '212ft (65m)', '26ft (7.9m)',
#        '18.0ft (5.5m)', '205[1]ft (62m)', '93.5m (307ft)', '40m (130ft)',
#        '221ft (67m)', '328.1ft (100.0m)', '163ft (50m)', '25m (82ft)',
#        '45.99m (150.9ft)', '138ft (42m)', '42m (138ft)', '111ft (34m)',
#        '87ft (27m)', '31m (102ft)', '95ft (29m)', '81.2ft (24.7m)',
#        '88ft (27m)', '104.9ft (32.0m)', '83ft (25m)', '82.17ft (25.0m)',
#        '85ft (26m)', '146ft (45m)', '98.4ft (30.0m)', '154ft (47m)',
#        '32ft (9.8m)', '66m (217ft)', '112ft (34m)', '32m (105ft)',
#        '30.7m (101ft)', '89.6ft (27.3m)', '116.1 ft', '214ft (65m)',
#        '62ft (19m)', '26m (85ft)', '67.2ft (20.5m)', '72.2ft (22.0m)',
#        '196ft (60m)', '85.2ft (26.0m)', '23.8m (78ft)', '49m (161ft)',
#        '155ft (47m)', '131ft (40m)', '104ft (32m)', '8ft (2.4m)',
#        '19.4m (64ft)', '74.7m (245ft)', '58ft (18m)'], dtype=object)

# %% [markdown]
# ### Now Standardising the drop column units to metres

# %%
df_deduped['drop_clean'] = df_deduped['drop'].str.extract(r'([\d,\.]+)\s*m').replace(',', '', regex=True)[0]

# %%
df_deduped['drop_clean'] = df_deduped['drop_clean'].astype(float)

# %% [markdown]
# Ensuring the other columns have proper values by checking out all of the unique values of the column

# %%
df_deduped['track_layout'].unique()
# Out:
# array([nan, 'Custom', 'Terrain', 'Out and back', 'Out and Back/Terrain',
#        'Wild Mouse', 'Loop', 'Inverted', 'Twister', 'Out and Back',
#        'Steel', 'Single Rail', 'Double figure 8[1]',
#        'Möbius Loop with one station', 'Intamin Tri Track', 'Figure 8',
#        'Modified Double Out and Back', 'Wood', 'Compact Twister',
#        'Water Coaster', 'Out & back', 'Figure Eight', 'Indoor',
#        'Double Out and Back',
#        '8 layers laminated wood strips with 1/4"x3" wide steel rail',
#        'Out-and-back', 'Single Helix (center)',
#        'Custom - Infinity Coaster', 'Double Figure Eight',
#        'Out and Back Helix and Twister', 'Pinfari TL-59',
#        'Terrain roller coaster', 'Terrain, Out and Back roller coaster',
#        'Terrain, Out and Back', 'Wooden out-and-back', 'Oval',
#        'Indoor-Spinning Glow', 'Dual-tracked', 'Shuttle Loop',
#        'Stacked Figure-8', 'L-shaped Out and Back',
#        'Terrain Mega Coaster', 'Terrain Wood Twister Out and Back',
#        'Möbius Loop', 'Terrain twister', 'Out and Back, Twister',
#        'Triple out and back', 'Continual', 'steel', 'Boomerang',
#        'steel twister', 'Compact', 'Out and BackTwister',
#        'Terrain / Twister', 'Double out and back', 'I-Box',
#        'Infinity Coaster - Custom', 'Infinity Coaster 1170',
#        'Modified Enigma', 'Twister roller coaster',
#        'Out and Back / Twister', 'Terrain[2]', 'Out and Back/Twister',
#        'Custom terrain design', 'Coney Island Cyclone (mirror image)',
#        'Wild mouse', 'Out and Back/Figure 8', 'Dual Overbank Figure 8'],
#       dtype=object)

# %%
df_deduped['year_introduced'].unique()
# Out:
# array([2006, 2013, 2021, 2011, 2015, 2018, 1991, 1999, 2010, 1984, 1997,
#        2014, 1981, 2008, 1989, 2009, 2002, 1978, 2003, 1988, 1995, 1996,
#        2005, 2000, 2001, 1923, 1958, 1964, 1998, 2007, 2004, 2020, 1967,
#        1993, 1980, 1973, 1969, 2016, 1983, 1946, 1951, 1994, 1927, 2019,
#        1976, 1979, 1940, 2017, 2012, 1992, 1929, 1987, 1972, 1924, 1925,
#        1971, 1982, 1920, 1985, 1902, 1950, 1952, 1959, 1928, 1933, 1990,
#        1910, 1975, 1932, 1921, 1938, 1974, 1966, 1956, 1977, 1912, 1986,
#        1968, 1941, 1930, 1934], dtype=int64)

# %%
df_deduped['latitude'].unique()
# Out:
# array([ 23.0044, -32.0955,  49.9992,  52.6108,      nan,  45.4716,
#         39.3445,  35.1003,  28.0379,  37.2328,  48.2617,  42.3646,
#         38.5125,  37.8392,  34.4213,  37.2348,  34.5213,  48.2639,
#         53.7901,  44.8542,  51.6198,  57.6933,  51.6242,  35.6255,
#         39.3457,  51.6482,  40.9862,  40.2282,  42.0353,  19.2952,
#          1.2541,  38.9103,  43.839 ,  36.1019,  53.7892,  40.1382,
#         40.8797,  50.7986,  48.2624,  53.7902,  41.4799,  45.4566,
#         29.5463,  40.9855,  39.1731,  51.3975,  41.6392,  33.8046,
#         40.2863,  40.9874,  52.5062,   1.2534,  36.1381,  34.4249,
#         35.1042,  42.0371,  41.4847,  28.0342,  33.845 ,  63.2298,
#         56.1358,  50.7987,  53.0231,  34.4278,  51.4032,  40.9836,
#         40.2864,  42.1077,  52.4404,  40.5742,  35.1011,  41.4836,
#         43.3474,  44.7996,  40.7898,  39.1723,  50.801 ,  39.1847,
#         48.8682,  39.866 ,  39.7808,  42.0403,  43.6161, -27.908 ,
#         33.7676,  33.7703,  30.5912,  50.8483,  51.648 ,  18.7647,
#         33.5718,  44.3389,  39.3421,  34.8755,  31.8245,  22.9996,
#         31.0979,  23.6181,  38.9892,  40.9675, -32.097 ,  43.8445,
#         41.0875,  43.0613,  41.651 ,  51.348 ,  35.7977,  52.1472,
#         51.1993,  55.6728,  35.4884,  36.1375,  50.566 ,  32.765 ,
#          1.255 , -27.8639,  54.0744,  48.2647,  40.8303,  43.5283,
#         44.7995,  49.32  ,  40.3894,  50.7999,  40.291 ,  35.101 ,
#         39.3432,  52.1477,  31.0973,  24.4864,  36.6703,  35.7947,
#         37.3981,  43.8412,  39.3476,  53.0262,  51.4052,  40.8784,
#         24.4842,  52.0544,  28.4662,  35.4859,  34.4232,  41.0847,
#         35.1055,  51.3997,  52.9859,  53.5236,  41.4806,  41.4863,
#         51.6195,  33.8426,  43.8438,  36.9647,  52.6244,  34.424 ,
#         37.3967,  39.865 ,  45.5278,  42.3661,  34.4269,  33.7692,
#         52.4386,  33.8063,  49.1314,  36.6704,  33.7658,  40.2869,
#         38.9075, -27.9073,  37.2344,  37.8375,  37.2361,  43.617 ,
#         28.4298,  22.2357,  35.0303,  33.8448,  40.1348,  28.4803,
#         57.6953,  39.802 ,  44.8006,  34.6666,  28.4749,  40.7903,
#         42.9272,  55.2599,  51.2531,  28.3303,  40.581 ,  39.9428,
#         53.7903,  40.8798,  59.3233,  23.6187,  35.1031,  37.2325,
#         41.4822,  29.2858,  40.3867,  43.2316,  33.8458,  40.1377,
#        -27.9568,  40.9869,  59.3231,  51.62  ,  51.6469,  53.1922,
#         32.7554,  39.868 ,  63.2309,  33.2617,  49.0377,  44.3383,
#         38.1943,  37.0225,  41.6423,  52.1466,  40.1392,  40.0295,
#         60.1883,  50.6977,  53.0247,  28.4111, -48.2617,  54.2117,
#         28.0397,  59.3226,  40.2935,  45.525 ,  45.5225,  40.2929,
#         38.1965,  40.1343,  53.026 ,  60.1878,  57.695 ,  41.6343,
#         41.4405,  37.2343,  51.7864,  35.0306,  40.7886,  52.4424,
#         51.6246,  44.7999,  41.4853,  28.4095,  39.172 ,  45.4578,
#         28.4119,  32.7671,  41.4852,  51.6481,  38.1406,  19.2945,
#         51.7807,  40.0287, -27.8628,  43.8392,  41.4817,  53.192 ,
#         32.7557,  59.3239,  43.3207,  33.8456, -23.0987,  28.0347,
#         42.9304,  54.209 ,  41.4228,  35.7956,  45.62  ,  52.9869,
#         51.4035,  35.143 ,  32.7564,  40.8061,  53.7908,  34.4222,
#         18.7664,  40.1356,  46.6718,  52.9866,  45.4582,  48.131 ,
#         39.3427,  57.27  ,  41.6491,  36.6681,  49.1342,  22.1016,
#         39.1753,  43.614 ,  35.8367,  40.389 ,  40.8783,  60.1875,
#         40.3889,  63.2307,  55.737 ,  29.5969,  33.8429,  42.9292,
#         39.1744,  50.6988,   1.2545,  34.3598,  49.1336,  40.3869,
#         37.8371,  51.5325,  42.3658,  35.6277,  50.7996,  37.3951,
#         33.3792,  41.479 ,  45.4571,  51.3487,  42.1093,  42.109 ,
#         44.8008,  53.7899,  33.8151,  52.985 ,  38.5155,  38.1371,
#         29.5991,  44.1161,  11.0433,  10.7605,  52.5928,  40.9849,
#         10.8607,  38.1967,  38.9858,  40.2602,  41.4826,  52.9897,
#         32.7585,  51.3494,  38.9894,  60.1872,  40.8056,  51.4026,
#         51.3853,  37.8405, -27.9078,  28.0375,  34.4286,  38.5164,
#         40.1544,  45.4567,  28.0367,  43.3422,  51.2861,  32.7589,
#         52.6125,  40.2899,  33.8444,  48.268 ,  43.8424,  40.1346,
#         40.3864,  31.4975,  28.3594,  35.7934,  34.6653,  33.811 ,
#         28.4192,  48.8741,  14.2819,  59.7482,  52.4406,  51.779 ,
#         40.9844,  52.9889,  39.1754,  44.8553,  42.3669,  41.0904,
#         51.6223,  51.405 ,  43.3513,  40.3892,  42.1081,  35.0312,
#         29.4553,  40.5789,  40.7909,  35.5838,  41.4862,  44.7978,
#         53.7888,  50.949 ,  38.1958, -27.9563,  40.2897,  29.5965,
#         47.9065,  42.0386,  34.425 ,  29.5952,  40.2277,  38.1386,
#        -27.9143,  58.7801,  33.6825,  30.7196,  37.2898,  38.1941,
#         40.8066,  60.1885,  35.4853,  40.579 ,  42.9294,  34.4219,
#         37.2347,  35.793 ,  29.4524,  35.2437,  28.4205,  39.3402,
#         38.5161,  43.3514,  53.5427,  34.6634,  38.9893,  39.3448,
#         38.9865,  29.4523,  37.393 ,  38.1189,  28.4712,  33.7678,
#         38.91  ,  38.1202,  41.6518,  34.4228,  54.0769,  39.3437,
#         38.1194,  34.4245,  51.081 ,  52.9872,  51.4056,  38.1213,
#         51.4036,  52.9847,  35.7063,  43.8427,  38.1956,  36.6684,
#         38.1242,  63.2306,  40.5735,  42.0389,  59.7472,  40.5798,
#         35.7967,  50.6971,  48.3242,  47.9044,  39.1728,  36.669 ,
#         43.8408,  32.7556,  40.2298,  41.6515,  40.4134,  40.2892,
#         58.41  ,  47.9053,  60.1881,  40.7525,  30.7181,  40.8771,
#         39.7464,  51.1997,  35.0285,  52.4428,  42.7962,  57.6932,
#         41.4813,  51.3473,  51.6221,  40.1852,  28.4713,  37.2315,
#         55.2611,  42.9283,  42.3681,  34.4208,  51.6522,  51.0875,
#         43.8419,  35.1036,  60.1886,  50.849 ,  34.4217,  43.234 ,
#         40.9839,  40.2925,  40.2598,  44.7986,  41.6408,  43.8441,
#         41.4856,  58.6653,  36.6686,  50.8002,  52.5075,  48.2614,
#         43.3436,  43.84  ,  19.2935,  29.5951,  22.6145,  31.0987,
#         41.5264,  40.5793,  43.3423,  28.4739,  34.5179,  42.3654,
#         34.421 ,  52.4392,  42.7953,  43.8402,  43.3434,  50.0019,
#         43.6167,  41.643 ])

# %%
df_deduped['longitude'].unique()
# Out:
# array([ 113.3269,  115.817 ,   19.4011,   -1.7134,       nan, -122.6623,
#         -84.2648,  -80.9409,  -82.4216,  -76.6476,    4.6149,  -87.9336,
#         -90.6772,  -77.4402, -118.5998,  -76.6413,  -93.0143,    7.7237,
#          -3.0559,  -93.2422,    6.976 ,   11.9961,    6.9754,  139.5181,
#         -84.2655,    5.0508, -111.8926,   -3.5924,  -72.6131,  -99.2065,
#         103.8223,  -76.7786,  -79.5406, -115.1736,   -3.0569,  -74.4323,
#         -76.5068,    6.8803,    7.7185,   -3.0539,  -82.6826,   10.7137,
#         -95.0173, -111.8923,  -94.4851,    5.9842,  -72.9245, -117.9218,
#         -76.659 , -111.8955,    1.7451,  103.824 , -115.1664, -118.5964,
#         -80.9436,  -72.6117,  -82.6904,  -82.42  , -118.0019,   22.8587,
#          10.1979,    6.8815,    9.8833, -118.5975,   -0.513 , -111.8951,
#         -76.6556,  -80.1568,    5.7615,  -73.9778,  -80.9426,  -82.6853,
#         -86.2789,  -93.4563,  -86.771 ,  -94.4889,    6.878 ,  117.4686,
#           2.7777,  116.4885, -105.054 ,  -72.6156,  -89.7897,  153.314 ,
#         -84.5519,  -84.5479,  114.3879,    2.9475,    5.0474,  -73.2805,
#        -112.1188,   12.2636,  -84.2674,  134.7637,  119.9955,  113.3233,
#         121.209 ,  120.5772,  -74.803 ,  -73.6739,  115.8181,  -79.5407,
#           1.1608,  -79.0804,  -93.5024,   -0.319 ,  -83.5312,    4.3785,
#           4.909 ,   12.5703,  138.7808, -115.1666,   12.401 , -117.224 ,
#         103.8222,  153.3169,   10.7814,    7.7197,   17.3398,  -70.4312,
#         -93.462 ,    8.295 ,  -79.8677,    6.8792,  -76.6552,  -80.9394,
#         -84.2693,    4.3792,  121.2087,   54.6042,  -93.3407,  -83.5301,
#        -121.9718,  -79.539 ,  -84.2652,    9.8796,   -0.5139,  -76.5051,
#          54.6124,    4.3496,  -81.4561,  138.777 , -118.5972,    1.1564,
#         -80.9425,    5.985 ,   -1.8821, -113.6211,  -82.679 ,  -82.6897,
#         -84.5506,    6.9765, -117.9981,  -79.546 , -122.0153,    6.5619,
#        -118.5985, -121.9749,  116.4846,  -73.5363,  -87.9311, -118.5969,
#         -84.55  ,    5.7614, -117.923 ,    2.5714,  -93.3366,  -84.5514,
#         -76.6531,  -76.772 ,  153.3136,  -76.6475,  -77.4471,  -76.6444,
#         -89.7893,  -81.5859,  114.1725,  136.7347, -118.0015,  -74.4397,
#         -81.47  ,   11.9908,  -74.9847,  -93.4578,  135.4338,  -81.4683,
#         -86.7706,  -78.3823,   11.8639,   12.3125,  -81.5147,  -75.5325,
#         -74.0721,   -3.0556,  -76.5018,   18.0953,  120.5758,  -77.4397,
#         -76.6486,  -82.6852,  -94.7895,  -79.8628,  -77.5432, -117.9992,
#         -74.4405,  153.4261, -111.8936,   18.0956,    6.9725,    5.0525,
#           0.3461,  -97.0673,  116.4874,   22.8555,  131.4281,    9.0544,
#          12.2668,  -85.7443,  -86.4017,  -72.9226,    4.379 ,  -74.4365,
#         -76.2173,   24.94  ,    4.585 ,    9.879 ,  -81.4583,    4.6142,
#          -0.8066,  -82.4231,   18.0964,  -76.6551,  -73.5333,  -73.5381,
#         -79.5424,  -76.6532,  -85.744 ,  -74.4434,    9.8818,   11.9925,
#         -80.3165,  -81.7577,  -76.646 ,   -1.155 ,  136.7323,  -86.77  ,
#           5.7663,    6.9733,  -93.4591,  -82.6861,  -81.4591,  -94.4906,
#          10.7125,  -81.4617, -117.228 ,  -82.6925, -122.2336,  -99.2112,
#          -4.8056,  -76.2186,  -79.5419,  -82.6881,    0.347 ,  -97.0702,
#          18.0961,   -2.0107, -117.999 ,  -47.0109,  -82.4175,  -78.3834,
#          -0.808 ,    2.1198,    5.5715,   -1.8828,   -0.5164, -106.5884,
#         -97.0731,  -74.0706,   -3.0544, -118.5983,   73.28  ,  -74.4444,
#           0.3703,   -1.8965,   10.7111,   11.549 ,  -84.2627,    9.6453,
#         -93.5006,  -93.34  ,    2.5663,  113.529 , -121.9732,  -89.7898,
#         129.28  ,  -79.866 ,  -76.5064,   24.9381,  -79.865 ,   22.8545,
#           9.1218,  -98.6083, -118.0013,  -78.3861,  -94.4837,    4.5903,
#         103.8245,  136.845 ,    5.0536,    2.5737,  -79.8619,  -77.4449,
#           0.7167,  -87.9371,  139.8808,    6.8828, -121.9737,  -86.9969,
#         -82.6818,   10.7119,   -0.3178,  -80.157 ,  -80.1565,  -93.4611,
#          -3.0551, -117.993 ,  -80.9428,   -1.8905,  -90.6738, -122.2345,
#         -98.613 ,  -71.1828,  106.6325,  106.6368,    1.7361,  106.8044,
#         -85.7476,  -74.8097,  -79.2814,  -82.6874,   -1.8856,  -97.0685,
#          -0.318 ,  -74.8034,   24.9392,  -74.071 ,   -0.5119,    1.3775,
#         -77.4422,  153.3111,  -82.4233,  -90.6761,  -83.1203,   10.7072,
#         -82.4244,  -86.2761,   -3.0089,  -97.0706,   -1.7161,  136.7308,
#         -76.6538, -117.9986, -117.9997,    7.72  ,  -79.5462,  -74.4419,
#         -79.8647,  120.0411,  -81.5607,  -83.5965,  -76.6536,  135.4357,
#        -117.9174,  -81.5772,    2.7793,  121.0954,   10.777 ,    5.7681,
#          -4.805 , -111.895 ,   -1.8946,  -94.4879,  -93.2425,    1.1566,
#           6.9729,   -0.5153,  -73.6927,  -79.8665,  -80.1589,  136.7301,
#         -98.6961,  -75.5381,  -86.7718,  -97.4405,  -82.6933,  -93.4517,
#          -3.0558,   -1.5505,  -85.7503,  153.4258,  -98.6099, -116.708 ,
#         153.3125,  -72.6114, -118.598 ,  -98.61  ,   -3.5906, -122.231 ,
#         153.3164,    5.8405,  -78.8917,  -83.3217,  127.2024,  -85.747 ,
#         -74.0712,   24.9391,  138.78  ,  -75.53  ,  -78.3849,  -76.6421,
#         -83.5279,  -98.699 , -101.8321,  -81.5784,  -84.266 ,   -3.0553,
#         -90.6789,  -73.6851,   -6.4628,  135.4305,  -74.8023,  -84.2686,
#         -74.8107,  -98.6965, -121.9714,  -86.9103,  -81.4684,  -84.551 ,
#         -76.776 ,  -86.914 ,  -93.5014,   10.78  ,  -84.2647,  -86.9152,
#         -84.5475, -118.6006,    2.5989,   -1.8953,   -0.5154,  -86.9115,
#          -0.5132,   -1.8904,  139.7533,  -79.5423,  -85.7475,  -93.3379,
#         -86.909 ,   22.8579,  -73.9826,  -72.6133,   10.7773,  -75.5355,
#         -83.5319,  -82.4249,    4.5871,    6.7295, -116.7094,  -94.4892,
#         -93.3377,  -79.5396,  -97.0742,   -3.5961,    2.5739,  -93.5025,
#          -3.748 ,  -76.6535,   13.55  , -116.7097,  -73.4197,  -84.5522,
#         -83.3243,  -76.5041, -105.0144,    4.9055,  136.7326,    5.7608,
#         -71.249 ,   11.9953,  -82.684 ,   -0.3156,    6.9752,  -74.8725,
#         -81.472 ,  -76.6449,   11.8634,  -78.3817,  -87.9372, -118.5953,
#        -114.3594,  -79.5435,  -80.9416,   24.9417, -118.5992,  -77.5429,
#         -81.4564, -111.8956,   -1.8886,  -76.6548,  -79.2799, -111.8945,
#         -93.4587,  -76.6558,  -72.9231,  -79.5432,  -82.6886,  -80.9388,
#          16.4664,  -93.3425,    6.8777,    1.7434,    7.7192,  -86.2775,
#         -79.54  ,  -99.2058,  -98.6085,  114.2968,  121.214 ,  -73.1509,
#         -82.689 ,  -75.5326,  -86.2807,  -81.4649,  -93.0151,  -87.9338,
#        -118.5929, -118.0008,    5.7639,  -71.2492,  -79.543 ,  -86.2809,
#          19.4031,  -89.7892,  -72.9229])

# %%
df_deduped
# Out:
#                       coaster_name                  length  \
# 696    10 Inversion Roller Coaster    2,788.8 ft (850.0 m)
# 886         Abyss (roller coaster)        630 m (2,070 ft)
# 1057                       Abyssus  4,317.6 ft (1,316.0 m)
# 828   Accelerator (roller coaster)          180 m (590 ft)
# 936       Acrobat (roller coaster)  3,349.8 ft (1,021.0 m)
# ...                            ...                     ...
# 364                  Zach's Zoomer                     NaN
# 1046        Zadra (roller coaster)      1,316 m (4,318 ft)
# 433          Zeus (roller coaster)        2,900 ft (880 m)
# 56                   Zipper Dipper                     NaN
# 434     Zoomerang (Lake Compounce)          935 ft (285 m)
#
#                      speed                        location     status  \
# 696       45 mph (72 km/h)              Chimelong Paradise  Operating
# 886       85 km/h (53 mph)                 Adventure World  Operating
# 1057  62.1 mph (99.9 km/h)                    Energylandia  Operating
# 828       60 km/h (37 mph)                   Drayton Manor  Operating
# 936   55.9 mph (90.0 km/h)              Nagashima Spa Land  Operating
# ...                    ...                             ...        ...
# 364                    NaN            Michigan's Adventure  Operating
# 1046     121 km/h (75 mph)                    Energylandia  Operating
# 433       60 mph (97 km/h)  Mt. Olympus Water & Theme Park  Operating
# 56                     NaN        Blackpool Pleasure Beach  Operating
# 434       47 mph (76 km/h)                  Lake Compounce  Operating
#
#      opening_date   type                   manufacturer  \
# 696           NaT  Steel                        Intamin
# 886    2013-11-01  Steel                     Gerstlauer
# 1057   2021-07-14  Steel                         Vekoma
# 828    2011-04-21  Steel                         Vekoma
# 936    2015-07-18  Steel           Bolliger & Mabillard
# ...           ...    ...                            ...
# 364    1994-07-22   Wood  Custom Coasters International
# 1046   2019-08-22  Other    Rocky Mountain Construction
# 433    1997-06-07   Wood  Custom Coasters International
# 56            NaT  Other                            NaN
# 434    1997-06-27  Steel                         Vekoma
#
#                     height_restriction                       model  \
# 696              54–77 in (137–196 cm)  Looping Coaster (Colossus)
# 886                 125 cm (4 ft 1 in)       Euro-Fighter – Custom
# 1057               120 cm (3 ft 11 in)            Shockwave 1320m+
# 828                 100 cm (3 ft 3 in)            Family Boomerang
# 936   135–198 cm (4 ft 5 in–6 ft 6 in)      Flying Coaster (Manta)
# ...                                ...                         ...
# 364                     40 in (102 cm)                         NaN
# 1046                140 cm (4 ft 7 in)                         NaN
# 433                     48 in (122 cm)                         NaN
# 56                                 NaN                         NaN
# 434                     48 in (122 cm)                   Boomerang
#
#                  height  inversions       lift_launch_system          cost  \
# 696    98.4 ft (30.0 m)        10.0                      NaN           NaN
# 886        30 m (98 ft)         3.0          Chain lift hill  A$12 million
# 1057  126.3 ft (38.5 m)         4.0                      LSM   €11,000,000
# 828        20 m (66 ft)         0.0  Booster Wheel Lift Hill    £2,100,000
# 936   141.1 ft (43.0 m)         4.0          Chain lift hill           NaN
# ...                 ...         ...                      ...           ...
# 364                 NaN         0.0          Chain Lift Hill           NaN
# 1046    62.8 m (206 ft)         3.0          Chain lift hill           NaN
# 433        90 ft (27 m)         NaN                      NaN           NaN
# 56        15 ft (4.6 m)         0.0                      NaN           NaN
# 434   116.5 ft (35.5 m)         3.0                      NaN           NaN
#
#                                                  trains      park_section  \
# 696   Single train with 7 cars. Riders are arranged ...               nan
# 886   4 trains with a single car. Riders are arrange...               nan
# 1057  3 trains with 4 cars. Riders are arranged 2 ac...        Aqualantis
# 828                                                 NaN       Aerial Park
# 936                                                 NaN               nan
# ...                                                 ...               ...
# 364   Single train with 5 cars. Riders are arranged ...               nan
# 1046  2 trains with 6 cars. Riders are arranged 2 ac...       Dragon Zone
# 433                                                 NaN               nan
# 56    Single train with 5 cars. Riders are arranged ...  Nickelodeon Land
# 434                                                 NaN               nan
#
#        duration               capacity g_force              designer  \
# 696        1:32  1,300 riders per hour     NaN        Werner Stengel
# 886   2 minutes                    NaN     4.5                   NaN
# 1057        NaN   1000 riders per hour     4.5  Benjamin Bloemendaal
# 828         NaN    750 riders per hour       3        Meticulous ltd
# 936        3:00                    NaN     NaN                   NaN
# ...         ...                    ...     ...                   ...
# 364        1:20    450 riders per hour     NaN                   NaN
# 1046       1:50  1,050 riders per hour       4                   NaN
# 433        1:25                    NaN     NaN                   NaN
# 56         1:00                    NaN     NaN         Charlie Paige
# 434        1:48    760 riders per hour     5.2                Vekoma
#
#      max_vertical_angle             drop track_layout  year_introduced  \
# 696                 NaN              NaN          NaN             2006
# 886                100°  30.5 m (100 ft)       Custom             2013
# 1057                NaN              NaN          NaN             2021
# 828                 NaN              NaN          NaN             2011
# 936                 NaN              NaN          NaN             2015
# ...                 ...              ...          ...              ...
# 364                 40°              NaN          NaN             1994
# 1046                90°              NaN          NaN             2019
# 433                 NaN     85 ft (26 m)          NaN             1997
# 56                  NaN              NaN          NaN             1934
# 434                 NaN              NaN          NaN             1997
#
#       latitude  longitude type_main  length(m)  speed(km/h)  \
# 696    23.0044   113.3269     Steel      850.0         72.0
# 886   -32.0955   115.8170     Steel      630.0         85.0
# 1057   49.9992    19.4011     Steel     1316.0         99.9
# 828    52.6108    -1.7134     Steel      180.0         60.0
# 936        NaN        NaN     Steel     1021.0         90.0
# ...        ...        ...       ...        ...          ...
# 364    43.3434   -86.2809      Wood        NaN          NaN
# 1046   50.0019    19.4031     Other     1316.0        121.0
# 433    43.6167   -89.7892      Wood      880.0         97.0
# 56     53.7902    -3.0539     Other        NaN          NaN
# 434    41.6430   -72.9229     Steel      285.0         76.0
#
#       height_restriction_clean  height_clean  duration_clean  \
# 696                     137.00          30.0            92.0
# 886                     124.46          30.0           120.0
# 1057                    119.38          38.5             NaN
# 828                      99.06          20.0             NaN
# 936                     135.00          43.0           180.0
# ...                        ...           ...             ...
# 364                     102.00           NaN            80.0
# 1046                    139.70          62.8           110.0
# 433                     122.00          27.0            85.0
# 56                         NaN           4.6            60.0
# 434                     122.00          35.5           108.0
#
#       capacity_rider_per_hr  g_force_clean        designer_clean  \
# 696                     0.0            NaN        Werner Stengel
# 886                     NaN            0.5                   NaN
# 1057                    0.0            0.5  Benjamin Bloemendaal
# 828                   750.0            NaN        Meticulous ltd
# 936                     NaN            NaN                   NaN
# ...                     ...            ...                   ...
# 364                   450.0            NaN                   NaN
# 1046                   50.0            NaN                   NaN
# 433                     NaN            NaN                   NaN
# 56                      NaN            NaN         Charlie Paige
# 434                   760.0            5.0                Vekoma
#
#       max_vertical_angle_clean  drop_clean
# 696                        NaN         NaN
# 886                      100.0        30.5
# 1057                       NaN         NaN
# 828                        NaN         NaN
# 936                        NaN         NaN
# ...                        ...         ...
# 364                       40.0         NaN
# 1046                      90.0         NaN
# 433                        NaN        26.0
# 56                         NaN         NaN
# 434                        NaN         NaN
#
# [646 rows x 37 columns]

# %% [markdown]
# `Converting the data to a csv file`

# %%
df_deduped.to_csv("enrichedRollerCoaster.csv")

# %% [markdown]
# -------------------

# %% [markdown]
# # Thank you! 😊🎉
